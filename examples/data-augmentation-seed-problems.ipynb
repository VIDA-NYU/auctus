# %% [markdown]
# ## Data Augmentation Seed Problems: NYU DataMart

# %% [markdown]
# The purpose of this notebook is to investigate if and how the NYU DataMart finds the companion datasets for the data augmentation seed problems.

# %% [markdown]
# It seems that the NYU Datamart currently has the expected companion dataset for 5 problems: `DA_fifa2018_manofmatch`, `DA_housing_burden`, `DA_medical_malpractice`, `DA_ny_taxi_demand`, and `DA_poverty_estimation`.

# %%
from d3m import container
import datamart
import datamart_nyu
from pathlib import Path
import time
import requests
import json

# %%
def print_results(results):
    print("\n-------------------")
    if not results:
        print("No results!")
        return
    for result in results:
        print(result.score())
        print(result.get_json_metadata()['metadata']['name'])
        if (result.get_augment_hint()):
            print("Left Columns: %s" %
                  str(result.get_json_metadata()['augmentation']['left_columns_names']))
            print("Right Columns: %s" %
                  str(result.get_json_metadata()['augmentation']['right_columns_names']))
        else:
            print(result.id())
        print("-------------------")

# %%
client = datamart_nyu.RESTDatamart('https://auctus.vida-nyu.org/api/v1')

# %%
# home directory for data augmentation seed datasets
# change this accordingly
home_dir = str(Path.home()) + '/projects/d3m/datasets/seed_datasets_data_augmentation/'

# %% [markdown]
# ### DA_college_debt

# %% [markdown]
# Loading the supplied data.

# %%
college_debt_file = home_dir + 'DA_college_debt/DA_college_debt_dataset/datasetDoc.json'
college_debt = container.Dataset.load('file://' + college_debt_file)

# %%
college_debt['learningData'].head()
# Out:
#   d3mIndex    UNITID                                             INSTNM  \
# 0        0  12268508          San Joaquin Valley College-Rancho Cordova
# 1        1    207564  Oklahoma State University Institute of Technology
# 2        2    420024                         Centura College-Chesapeake
# 3        3    164492                                 Anna Maria College
# 4        4    234085                        Virginia Military Institute
#
#   PCTFLOAN CONTROL STABBR  PCIP16 MD_EARN_WNE_P10 PPTUG_EF UGDS_WHITE  \
# 0                3     CA                   28300
# 1    0.475       1     OK     0.0           35300   0.2297     0.2953
# 2   0.8125       3     VA     0.0           21900   0.2315     0.2808
# 3   0.7465       2     MA     0.0           44800   0.2621     0.6518
# 4   0.4589       1     VA  0.0321           65700      0.0     0.7992
#
#   UGDS_BLACK UGDS_HISP UGDS_ASIAN SATMTMID SATVRMID SATWRMID    UGDS PREDDEG  \
# 0                                                                          0
# 1     0.0291    0.0647     0.0051                             2164.0       2
# 2     0.5665    0.0493        0.0                              203.0       2
# 3     0.1258    0.1022     0.0123                             1057.0       3
# 4     0.0607    0.0584      0.042    575.0    575.0           1713.0       3
#
#   DEBT_EARNINGS_RATIO
# 0                  49
# 1                  36
# 2                 127
# 3                  76
# 4                  53

# %% [markdown]
# Without keywords.

# %%
cursor = client.search_with_data(query=None, supplied_data=college_debt)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 6.1875 seconds
#
# -------------------
# No results!

# %% [markdown]
# With keywords.

# %%
query = datamart.DatamartQuery(
    keywords=['college scorecard', 'finance', 'debt', 'earnings'],  # from problemDoc.json
    variables=[]
)
cursor = client.search_with_data(query=query, supplied_data=college_debt)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 7.0491 seconds
#
# -------------------
# No results!

# %% [markdown]
# **Result:** Unfortunately, it doesn't look like there is any useful dataset in our DataMart to solve this problem.

# %% [markdown]
# ### DA_consumer_complaints

# %% [markdown]
# Loading the supplied data.

# %%
consumer_complaints_file = home_dir + 'DA_consumer_complaints/DA_consumer_complaints_dataset/datasetDoc.json'
consumer_complaints = container.Dataset.load('file://' + consumer_complaints_file)

# %%
consumer_complaints['learningData'].head()
# Out:
#   d3mIndex Complaint ID State ZIP code                                Company  \
# 0        0      2252221    CA    928XX                   Ditech Financial LLC
# 1        1      1554019    CA    90731  BANK OF AMERICA, NATIONAL ASSOCIATION
# 2        2      2379952    CA    951XX      PORTFOLIO RECOVERY ASSOCIATES INC
# 3        3      1363639    CA    900XX                   JPMORGAN CHASE & CO.
# 4        4      1644731    CA    94703                         CITIBANK, N.A.
#
#                         Consumer complaint narrative Date sent to company  \
# 0  In XX/XX/XXXX I fell behind on my mortgage. I ...             12/15/16
# 1                                               None             09/06/15
# 2  Repeatedly calling a family members phone numb...             03/13/17
# 3  I closed my Chase mileage card last year. At t...             05/06/15
# 4                                               None             11/09/15
#
#   relevance
# 0         1
# 1         2
# 2         2
# 3         0
# 4         0

# %% [markdown]
# Without keywords.

# %%
cursor = client.search_with_data(query=None, supplied_data=consumer_complaints)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 109.0335 seconds
#
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - ELL
# Left Columns: [['Date sent to company']]
# Right Columns: [['Advanced Regents Num']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - ELL
# Left Columns: [['Date sent to company']]
# Right Columns: [['Regents w/o Advanced Num']]
# -------------------
# 1.0
# HRA Facts
# Left Columns: [['Date sent to company']]
# Right Columns: [['Adult Protective Svs. Referrals Received']]
# -------------------
# 1.0
# 2008-2009 VADIR INCIDENTS
# Left Columns: [['Date sent to company']]
# Right Columns: [['Enrollment']]
# -------------------
# 1.0
# LPC Permit Application Information
# Left Columns: [['Date sent to company']]
# Right Columns: [['received_date']]
# -------------------
# 1.0
# IBRD Statement Of Loans - Historical Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['First Repayment Date']]
# -------------------
# 1.0
# IBRD Statement Of Loans - Historical Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['Last Repayment Date']]
# -------------------
# 1.0
# IBRD Statement Of Loans - Historical Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['Closed Date (Most Recent)']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - Classes of - Gender
# Left Columns: [['Date sent to company']]
# Right Columns: [['Total Regents Num']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - Classes of - Gender
# Left Columns: [['Date sent to company']]
# Right Columns: [['Regents w/o Advanced Num']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - Classes of - Gender
# Left Columns: [['Date sent to company']]
# Right Columns: [['Still Enrolled Num']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough  - Total Cohort
# Left Columns: [['Date sent to company']]
# Right Columns: [['Regents w/o Advanced Num']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough  - Total Cohort
# Left Columns: [['Date sent to company']]
# Right Columns: [['Local Num']]
# -------------------
# 1.0
# 2013 - 2014 School Quality Reports
# Left Columns: [['Date sent to company']]
# Right Columns: [['Most Recent Quality Review']]
# -------------------
# 1.0
# Cash Assistance Youth Engagement
# Left Columns: [['Date sent to company']]
# Right Columns: [['Total Head of Household, 21-24 Years Old']]
# -------------------
# 1.0
# 2016-17 Physical Education - PE Instruction - Borough Level
# Left Columns: [['Date sent to company']]
# Right Columns: [['# of students who are receiving less than the required amount of physical education instruction']]
# -------------------
# 1.0
# IDA Statement of Credits and Grants  - Latest Available Snapshot
# Left Columns: [['Date sent to company']]
# Right Columns: [['Effective Date (Most Recent)']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - Ethnicity
# Left Columns: [['Date sent to company']]
# Right Columns: [['Regents w/o Advanced Num']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - Ethnicity
# Left Columns: [['Date sent to company']]
# Right Columns: [['Still Enrolled Num']]
# -------------------
# 1.0
# DOF: Open Balance Summary
# Left Columns: [['Date sent to company']]
# Right Columns: [['Date Account Period Ends']]
# -------------------

# %% [markdown]
# With keywords.

# %%
query = datamart.DatamartQuery(
    keywords=['consumer', 'complaints', 'protect', 'unfair practices',
              'consumer financial protection bureau'],  # from problemDoc.json
    variables=[]
)
cursor = client.search_with_data(query=query, supplied_data=consumer_complaints)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 133.8705 seconds
#
# -------------------
# 20.0
# DOB Complaints Received
# Left Columns: [['Date sent to company']]
# Right Columns: [['Inspection Date']]
# -------------------
# 19.779541
# DOB Complaints Received
# Left Columns: [['Date sent to company']]
# Right Columns: [['Disposition Date']]
# -------------------
# 19.25926
# DOB Complaints Received
# Left Columns: [['Date sent to company']]
# Right Columns: [['Date Entered']]
# -------------------
# 18.88889
# Landmarks Complaints
# Left Columns: [['Date sent to company']]
# Right Columns: [['Date']]
# -------------------
# 17.8847
# DOHMH Indoor Environmental Complaints
# Left Columns: [['Date sent to company']]
# Right Columns: [['Date_Received']]
# -------------------
# 13.650794
# Metal Content of Consumer Products Tested by the NYC Health Department
# Left Columns: [['Date sent to company']]
# Right Columns: [['COLLECTION_DATE']]
# -------------------
# 10.784834
# Housing Maintenance Code Complaints
# Left Columns: [['Date sent to company']]
# Right Columns: [['ReceivedDate']]
# -------------------
# 10.731922
# Housing Maintenance Code Complaints
# Left Columns: [['Date sent to company']]
# Right Columns: [['StatusDate']]
# -------------------
# 8.8844795
# DCA Monthly Compliance Report Date for Process Servers
# Left Columns: [['Date sent to company']]
# Right Columns: [['Alternate Randomly Generated Audit Date']]
# -------------------
# 8.827161
# DCA Monthly Compliance Report Date for Process Servers
# Left Columns: [['Date sent to company']]
# Right Columns: [['Month/Year']]
# -------------------
# 8.699294
# DCA Monthly Compliance Report Date for Process Servers
# Left Columns: [['Date sent to company']]
# Right Columns: [['Randomly Generated Audit Date']]
# -------------------
# 8.17295
# EMS Incident Dispatch Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['FIRST_HOSP_ARRIVAL_DATETIME']]
# -------------------
# 8.169642
# EMS Incident Dispatch Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['FIRST_TO_HOSP_DATETIME']]
# -------------------
# 8.163029
# Fire Incident Dispatch Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['FIRST_ON_SCENE_DATETIME']]
# -------------------
# 8.162846
# EMS Incident Dispatch Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['FIRST_ASSIGNMENT_DATETIME']]
# -------------------
# 8.117468
# EMS Incident Dispatch Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['INCIDENT_DATETIME']]
# -------------------
# 8.117284
# EMS Incident Dispatch Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['INCIDENT_CLOSE_DATETIME']]
# -------------------
# 8.113059
# EMS Incident Dispatch Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['FIRST_ON_SCENE_DATETIME']]
# -------------------
# 8.111956
# EMS Incident Dispatch Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['FIRST_ACTIVATION_DATETIME']]
# -------------------
# 8.108833
# Fire Incident Dispatch Data
# Left Columns: [['Date sent to company']]
# Right Columns: [['FIRST_ACTIVATION_DATETIME']]
# -------------------

# %% [markdown]
# **Result:** Unfortunately, it doesn't look like there is any useful dataset in our DataMart to solve this problem. The datasets returned by the search do not involve any consumer complaint data -- only other types of complaint that semantically do not make sense. Which does not mean the augmentation would not improve the performance ...

# %% [markdown]
# ### DA_fifa2018_manofmatch

# %% [markdown]
# Loading the supplied data.

# %%
fifa2018_manofmatch_file = home_dir + 'DA_fifa2018_manofmatch/DA_fifa2018_manofmatch_dataset/datasetDoc.json'
fifa2018_manofmatch = container.Dataset.load('file://' + fifa2018_manofmatch_file)

# %%
fifa2018_manofmatch['learningData'].head()
# Out:
#   d3mIndex GameID        Date     Team        Opponent Ball Possession %  \
# 0        0     55  23-06-2018   Mexico  Korea Republic                59
# 1        1     40  21-06-2018  Denmark       Australia                49
# 2        2     19  17-06-2018   Mexico         Germany                40
# 3        3     31  19-06-2018  Senegal          Poland                43
# 4        4     98  30-06-2018  Uruguay        Portugal                39
#
#   Off-Target Blocked Offsides Saves Pass Accuracy % Passes  \
# 0          6       2        0     5              89    485
# 1          5       0        1     4              88    458
# 2          6       2        2     9              82    281
# 3          4       2        3     3              81    328
# 4          2       1        0     4              69    269
#
#   Distance Covered (Kms) Yellow & Red Man of the Match 1st Goal        Round  \
# 0                     97            0                1     26.0  Group Stage
# 1                    112            0                1      7.0  Group Stage
# 2                    106            0                0     35.0  Group Stage
# 3                    107            0                1     60.0  Group Stage
# 4                    106            0                1      7.0  Round of 16
#
#   PSO Goals in PSO Own goals
# 0  No            0
# 1  No            0
# 2  No            0
# 3  No            0
# 4  No            0

# %% [markdown]
# Without keywords.

# %%
cursor = client.search_with_data(query=None, supplied_data=fifa2018_manofmatch)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 8.4872 seconds
#
# -------------------
# 1.0
# Water Consumption And Cost (2013 - March 2019)
# Left Columns: [['Date']]
# Right Columns: [['Revenue Month']]
# -------------------
# 1.0
# Street Construction Permits
# Left Columns: [['Date']]
# Right Columns: [['ModifiedOn']]
# -------------------
# 1.0
# Housing New York Units by Building
# Left Columns: [['Date']]
# Right Columns: [['Project Start Date']]
# -------------------
# 1.0
# Housing Maintenance Code Complaints
# Left Columns: [['Date']]
# Right Columns: [['ReceivedDate']]
# -------------------
# 1.0
# Capital Projects
# Left Columns: [['Date']]
# Right Columns: [['Forecast Completion']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - ELL
# Left Columns: [['Date']]
# Right Columns: [['Advanced Regents Num']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - ELL
# Left Columns: [['Date']]
# Right Columns: [['Regents w/o Advanced Num']]
# -------------------
# 1.0
# HRA Facts
# Left Columns: [['Date']]
# Right Columns: [['Adult Protective Svs. Referrals Received']]
# -------------------
# 1.0
# 2008-2009 VADIR INCIDENTS
# Left Columns: [['Date']]
# Right Columns: [['Enrollment']]
# -------------------
# 1.0
# Parks Inspection Program – Inspections
# Left Columns: [['Date']]
# Right Columns: [['inspAddedDate']]
# -------------------
# 1.0
# Appeals Closed In 2016
# Left Columns: [['Date']]
# Right Columns: [['Expiration']]
# -------------------
# 1.0
# LPC Permit Application Information
# Left Columns: [['Date']]
# Right Columns: [['received_date']]
# -------------------
# 1.0
# M/WBE, LBE, and EBE Certified Business List
# Left Columns: [['Date']]
# Right Columns: [['DATEOFJOB2']]
# -------------------
# 1.0
# Housing New York Units by Project
# Left Columns: [['Date']]
# Right Columns: [['Project Completion Date']]
# -------------------
# 1.0
# Forestry Work Orders
# Left Columns: [['Date']]
# Right Columns: [['ClosedDate']]
# -------------------
# 1.0
# Street Construction Inspections and Corrective Action Requests
# Left Columns: [['Date']]
# Right Columns: [['InspectionDate']]
# -------------------
# 1.0
# Board of Standards and Appeals (BSA) Applications Status
# Left Columns: [['Date']]
# Right Columns: [['Date']]
# -------------------
# 1.0
# IBRD Statement Of Loans - Historical Data
# Left Columns: [['Date']]
# Right Columns: [['First Repayment Date']]
# -------------------
# 1.0
# IBRD Statement Of Loans - Historical Data
# Left Columns: [['Date']]
# Right Columns: [['Last Repayment Date']]
# -------------------
# 1.0
# IBRD Statement Of Loans - Historical Data
# Left Columns: [['Date']]
# Right Columns: [['Closed Date (Most Recent)']]
# -------------------

# %% [markdown]
# With keywords.

# %%
query = datamart.DatamartQuery(
    keywords=['sports', 'soccer', 'FIFA 2018', 'statistics',
              'match data', 'man of the match'],  # from problemDoc.json
    variables=[]
)
cursor = client.search_with_data(query=query, supplied_data=fifa2018_manofmatch)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 13.9716 seconds
#
# -------------------
# 58.96552
# FIFA 2018 game statistics data
# Left Columns: [['GameID']]
# Right Columns: [['GameID']]
# -------------------
# 54.545456
# FIFA 2018 game statistics data
# Left Columns: [['Off-Target']]
# Right Columns: [['On-Target']]
# -------------------
# 10.0
# Inmate Admissions
# Left Columns: [['Date']]
# Right Columns: [['ADMITTED_DT']]
# -------------------
# 10.0
# Inmate Discharges
# Left Columns: [['Date']]
# Right Columns: [['ADMITTED_DT']]
# -------------------
# 10.0
# Inmate Discharges
# Left Columns: [['Date']]
# Right Columns: [['DISCHARGED_DT']]
# -------------------
# 10.0
# Cash Assistance Youth Engagement
# Left Columns: [['Date']]
# Right Columns: [['Total Head of Household, 21-24 Years Old']]
# -------------------
# 10.0
# Total SNAP Recipients
# Left Columns: [['Date']]
# Right Columns: [['Month']]
# -------------------
# 10.0
# Inmate Admissions
# Left Columns: [['Date']]
# Right Columns: [['DISCHARGED_DT']]
# -------------------
# 10.0
# 2013-2014 School Quality Reports Results For Elementary, Middle and K-8 Schools
# Left Columns: [['Date']]
# Right Columns: [['Most Recent Quality Review']]
# -------------------
# 10.0
# 2013 - 2014 School Quality Reports Results for High Schools
# Left Columns: [['Date']]
# Right Columns: [['Most Recent Quality Review']]
# -------------------
# 10.0
# Cash Assistance Youth Engagement
# Left Columns: [['Date']]
# Right Columns: [['Lacking High School Degree or GED, 18-20 Years Old']]
# -------------------
# 10.0
# Daily Inmates In Custody
# Left Columns: [['Date']]
# Right Columns: [['ADMITTED_DT']]
# -------------------
# 5.530975
# Parks Special Events
# Left Columns: [['Date']]
# Right Columns: [['Date and Time']]
# -------------------
# 5.221238
# 2015 - 2016 School Quality Report Results for D75 Schools
# Left Columns: [['Date']]
# Right Columns: [['Quality Review - Dates of Review']]
# -------------------
# 5.221238
# 2014 - 2015 School Quality Report Results for D75 Schools
# Left Columns: [['Date']]
# Right Columns: [['Quality Review - Dates of Review']]
# -------------------
# 5.221238
# 2016 - 2017 School Quality Report Results for D75 Schools
# Left Columns: [['Date']]
# Right Columns: [['Quality Review - Dates of Review']]
# -------------------
# 4.0707974
# Summer Sports Experience
# Left Columns: [['Date']]
# Right Columns: [['Week Start Date']]
# -------------------
# 4.0707974
# Summer Sports Experience
# Left Columns: [['Date']]
# Right Columns: [['Week End Date']]
# -------------------
# 3.0088506
# Revenue Budget & Financial Plan -- Exec\Adpt\Prel
# Left Columns: [['Date']]
# Right Columns: [['Publication Date']]
# -------------------
# 2.0353987
# "Kids In Motion" Playground Programming
# Left Columns: [['Date']]
# Right Columns: [['Week Start Date']]
# -------------------

# %%
join_ = results[0].augment(supplied_data=fifa2018_manofmatch)

# %%
join_['learningData'].head()
# Out:
#   d3mIndex GameID        Date     Team        Opponent Ball Possession %  \
# 0        0     55  2018-06-23   Mexico  Korea Republic                59
# 1        1     40  2018-06-21  Denmark       Australia                49
# 2        2     19  2018-06-17   Mexico         Germany                40
# 3        3     31  2018-06-19  Senegal          Poland                43
# 4        4     98  2018-06-30  Uruguay        Portugal                39
#
#   Off-Target Blocked Offsides Saves      ...      Own goals Goal Scored  \
# 0          6       2        0     5      ...                          2
# 1          5       0        1     4      ...                          1
# 2          6       2        2     9      ...                          1
# 3          4       2        3     3      ...                          2
# 4          2       1        0     4      ...                          2
#
#   Attempts On-Target Corners Free Kicks Fouls Committed Yellow Card Red  \
# 0       13         5       5         24               7           0   0
# 1       10         5       3          5               7           2   0
# 2       12         4       1         11              15           2   0
# 3        8         2       3         11              15           2   0
# 4        6         3       2         14              13           0   0
#
#   Own goal Time
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 29 columns]

# %% [markdown]
# **Result:** We find the expected dataset!

# %% [markdown]
# ### DA_global_terrorism

# %%
global_terrorism_file = home_dir + 'DA_global_terrorism/DA_global_terrorism_dataset/datasetDoc.json'
global_terrorism = container.Dataset.load('file://' + global_terrorism_file)

# %%
global_terrorism['learningData'].head()
# Out:
#   d3mIndex  year      country  \
# 0        0  1971  Netherlands
# 1        1  1995     Paraguay
# 2        2  1981       Israel
# 3        3  1990   Yugoslavia
# 4        4  2006      Nigeria
#
#                                                group activity_level
# 0  Popular Front for the Liberation of Palestine ...              5
# 1                                           Strikers              5
# 2            Palestine Liberation Organization (PLO)              2
# 3                               Albanian Separatists              5
# 4  Movement for the Actualization of the Sovereig...              2

# %% [markdown]
# Without keywords.

# %%
cursor = client.search_with_data(query=None, supplied_data=global_terrorism)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 5.9535 seconds
#
# -------------------
# 0.93181825
# Quality of Goverance
# Left Columns: [['year']]
# Right Columns: [['year']]
# -------------------
# 0.93181825
# Quality of Governance Indicators
# Left Columns: [['year']]
# Right Columns: [['year']]
# -------------------
# 0.90909094
# DOHMH Tuberculosis Surveillance: Data from the Tuberculosis Control Annual Summary
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.84090906
# Water Consumption In The New York City
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.8181818
# NYC Independent Budget Office (IBO) Tax Revenue FY 1980 - FY 2014
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.6818182
# Annual Overweight Load (AOL) Permits
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.6363636
# Quality of Governance Abridged
# Left Columns: [['year']]
# Right Columns: [['year']]
# -------------------
# 0.47727275
# Home Care Caseload
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.45454547
# DOHMH and DEP Waterborne Disease Risk Assessment Program Annual Report Data: Percentage of interviewed cryptosporidiosis case-patients by type of tap water exposure before disease onset, by Immune Status
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.45454547
# DOHMH and DEP Waterborne Disease Risk Assessment Program Annual Report Data: Percentage of interviewed cryptosporidiosis case-patients reporting selected potential risk exposures before disease onset, by Immune Status
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.45454547
# Cash Assistance Recipients in NYC
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.45454547
# MSME Country Indicators - Historical Data
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.4318182
# Credited Job Placement Report
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.40909094
# Office of Planning and Performance Management (OPPM) - MA Trend
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.38636366
# MSME Country Indicators 2014
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.3409091
# DOHMH and DEP Waterborne Disease Risk Assessment Program Annual Report Data: Cryptosporidiosis by race/ethnicity and age group.
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.3409091
# DOHMH and DEP Waterborne Disease Risk Assessment Program Annual Report Data: Cryptosporidiosis by race/ethnicity and borough of residence
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.27272728
# Inventory of New York City Greenhouse Gas Emissions - Con Edison District Steam Emission Factors (2005-2016)
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.27272728
# Inventory of New York City Greenhouse Gas Emissions - Electricity Emission Factors (2005-2016)
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.25
# NYCDCP Manhattan Bike Counts - Off Street
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------

# %% [markdown]
# With keywords.

# %%
query = datamart.DatamartQuery(
    keywords=['global terrorism', 'terrorist events', 'domestic',
              'international', 'terrorism', 'national security',
              'conflict'],  # from problemDoc.json
    variables=[]
)
cursor = client.search_with_data(query=query, supplied_data=global_terrorism)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 7.2810 seconds
#
# -------------------
# 3.8636365
# MSME Country Indicators 2014
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.93181825
# Quality of Goverance
# Left Columns: [['year']]
# Right Columns: [['year']]
# -------------------
# 0.93181825
# Quality of Governance Indicators
# Left Columns: [['year']]
# Right Columns: [['year']]
# -------------------
# 0.90909094
# DOHMH Tuberculosis Surveillance: Data from the Tuberculosis Control Annual Summary
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.84090906
# Water Consumption In The New York City
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.8181818
# NYC Independent Budget Office (IBO) Tax Revenue FY 1980 - FY 2014
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.6818182
# Annual Overweight Load (AOL) Permits
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.6363636
# Quality of Governance Abridged
# Left Columns: [['year']]
# Right Columns: [['year']]
# -------------------
# 0.47727275
# Home Care Caseload
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.45454547
# DOHMH and DEP Waterborne Disease Risk Assessment Program Annual Report Data: Percentage of interviewed cryptosporidiosis case-patients by type of tap water exposure before disease onset, by Immune Status
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.45454547
# DOHMH and DEP Waterborne Disease Risk Assessment Program Annual Report Data: Percentage of interviewed cryptosporidiosis case-patients reporting selected potential risk exposures before disease onset, by Immune Status
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.45454547
# Cash Assistance Recipients in NYC
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.45454547
# MSME Country Indicators - Historical Data
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.4318182
# Credited Job Placement Report
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.40909094
# Office of Planning and Performance Management (OPPM) - MA Trend
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.3409091
# DOHMH and DEP Waterborne Disease Risk Assessment Program Annual Report Data: Cryptosporidiosis by race/ethnicity and age group.
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.3409091
# DOHMH and DEP Waterborne Disease Risk Assessment Program Annual Report Data: Cryptosporidiosis by race/ethnicity and borough of residence
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.27272728
# Inventory of New York City Greenhouse Gas Emissions - Con Edison District Steam Emission Factors (2005-2016)
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.27272728
# Inventory of New York City Greenhouse Gas Emissions - Electricity Emission Factors (2005-2016)
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------
# 0.25
# NYCDCP Manhattan Bike Counts - Off Street
# Left Columns: [['year']]
# Right Columns: [['Year']]
# -------------------

# %%
join_ = results[0].augment(supplied_data=global_terrorism)

# %%
join_['learningData'].head()
# Out:
#   d3mIndex  year      country  \
# 0        0  1971  Netherlands
# 1        1  1995     Paraguay
# 2        2  1981       Israel
# 3        3  1990   Yugoslavia
# 4        4  2006      Nigeria
#
#                                                group activity_level  \
# 0  Popular Front for the Liberation of Palestine ...              5
# 1                                           Strikers              5
# 2            Palestine Liberation Organization (PLO)              2
# 3                               Albanian Separatists              5
# 4  Movement for the Actualization of the Sovereig...              2
#
#   Source Code Code    Economy GNI per Capita, Atlas Method Population  \
# 0
# 1         2.0  IDN  Indonesia
# 2
# 3
# 4         3.0  LAO    Lao PDR                        510.0  5895930.0
#
#     ...    Value Added Source  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
#
#   Micro Enterprises Sector Distribution: Manufacturing  \
# 0
# 1
# 2
# 3
# 4
#
#   Micro Enterprises Sector Distribution: Trade  \
# 0
# 1
# 2
# 3
# 4
#
#   Micro Enterprises Sector Distribution: Services  \
# 0
# 1
# 2
# 3
# 4
#
#   Micro Enterprises Sector Distribution: Agri/Other  \
# 0
# 1
# 2
# 3
# 4
#
#   SME Sector Distribution: Manufacturing SME Sector Distribution: Trade  \
# 0
# 1
# 2
# 3
# 4
#
#   SME Sector Distribution: Services SME Sector Distribution: Agri/Other  \
# 0
# 1
# 2
# 3
# 4
#
#   Comments
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 84 columns]

# %% [markdown]
# **Result:** Maybe the first or second search results are useful? Not sure.

# %% [markdown]
# ### DA_housing_burden

# %%
housing_burden_file = home_dir + 'DA_housing_burden/DA_housing_burden_dataset/datasetDoc.json'
housing_burden = container.Dataset.load('file://' + housing_burden_file)

# %%
housing_burden['learningData'].head()
# Out:
#   d3mIndex RT       SERIALNO DIVISION SPORDER  PUMA REGION ST   ADJINC PWGTP  \
# 0        0  P  2017001026578        9       5  7701      4  6  1011189    79
# 1        1  P  2017000186978        9       1  6502      4  6  1011189    75
# 2        2  P  2017001070961        9       2  7902      4  6  1011189    53
# 3        3  P  2017000672057        9       5  3717      4  6  1011189    64
# 4        4  P  2017000011657        9       3  5303      4  6  1011189   138
#
#    ...   PWGTP72 PWGTP73 PWGTP74 PWGTP75 PWGTP76 PWGTP77 PWGTP78 PWGTP79  \
# 0  ...       102      26      66     134      32      28      80      77
# 1  ...       133      70      23      75      21     129      67      23
# 2  ...        15      86      49      57      53      60      17      14
# 3  ...        23      48     142      21      51      64      52      65
# 4  ...       116      43     198     130     116     168     161     112
#
#   PWGTP80 BURDEN
# 0      59      2
# 1      19      4
# 2      50      5
# 3      60      5
# 4      40      1
#
# [5 rows x 288 columns]

# %% [markdown]
# Without keywords.

# %%
cursor = client.search_with_data(query=None, supplied_data=housing_burden)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 608.3932 seconds
#
# -------------------
# 1.0
# California Housing Data
# Left Columns: [['DIVISION']]
# Right Columns: [['DIVISION']]
# -------------------
# 1.0
# psam_h06
# Left Columns: [['DIVISION']]
# Right Columns: [['DIVISION']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2014)
# Left Columns: [['SPORDER']]
# Right Columns: [['SPORDER']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2010)
# Left Columns: [['SPORDER']]
# Right Columns: [['SPORDER']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2011)
# Left Columns: [['SPORDER']]
# Right Columns: [['SPORDER']]
# -------------------
# 1.0
# California Housing Data
# Left Columns: [['REGION']]
# Right Columns: [['REGION']]
# -------------------
# 1.0
# 2006-07 Class Size - School-level Detail
# Left Columns: [['REGION']]
# Right Columns: [['REGION']]
# -------------------
# 1.0
# psam_h06
# Left Columns: [['REGION']]
# Right Columns: [['REGION']]
# -------------------
# 1.0
# California Housing Data
# Left Columns: [['ST']]
# Right Columns: [['ST']]
# -------------------
# 1.0
# psam_h06
# Left Columns: [['ST']]
# Right Columns: [['ST']]
# -------------------
# 1.0
# California Housing Data
# Left Columns: [['ADJINC']]
# Right Columns: [['ADJINC']]
# -------------------
# 1.0
# psam_h06
# Left Columns: [['ADJINC']]
# Right Columns: [['ADJINC']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2013)
# Left Columns: [['CIT']]
# Right Columns: [['CIT']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2012)
# Left Columns: [['CIT']]
# Right Columns: [['CIT']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2015)
# Left Columns: [['CIT']]
# Right Columns: [['CIT']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2016)
# Left Columns: [['CIT']]
# Right Columns: [['CIT']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2017)
# Left Columns: [['CIT']]
# Right Columns: [['CIT']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2014)
# Left Columns: [['CIT']]
# Right Columns: [['CIT']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2010)
# Left Columns: [['CIT']]
# Right Columns: [['CIT']]
# -------------------
# 1.0
# NYCgov Poverty Measure Data (2011)
# Left Columns: [['CIT']]
# Right Columns: [['CIT']]
# -------------------

# %% [markdown]
# With keywords.

# %%
query = datamart.DatamartQuery(
    keywords=['American Community Survey', 'ACS',
              'Public Use Microdata Sample', 'PUMS',
              '2017', 'California', 'government',
              'economics', 'housing', 'population'],  # from problemDoc.json
    variables=[]
)
cursor = client.search_with_data(query=query, supplied_data=housing_burden)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 488.5060 seconds
#
# -------------------
# 70.0
# psam_h06
# Left Columns: [['DIVISION']]
# Right Columns: [['DIVISION']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['REGION']]
# Right Columns: [['REGION']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['ST']]
# Right Columns: [['ST']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['ADJINC']]
# Right Columns: [['ADJINC']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FER']]
# Right Columns: [['FES']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['GCR']]
# Right Columns: [['ACR']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['SEX']]
# Right Columns: [['SMX']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['NOP']]
# Right Columns: [['NP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FAGEP']]
# Right Columns: [['FAGSP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FCITP']]
# Right Columns: [['FKITP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FCITWP']]
# Right Columns: [['FKITP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FCOWP']]
# Right Columns: [['FCONP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FDDRSP']]
# Right Columns: [['FBDSP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FDEARP']]
# Right Columns: [['FREFRP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FDEYEP']]
# Right Columns: [['FELEP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FDRATP']]
# Right Columns: [['FRWATP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FDRATP']]
# Right Columns: [['FWATP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FDRATP']]
# Right Columns: [['FRNTP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FDRATP']]
# Right Columns: [['FGRNTP']]
# -------------------
# 70.0
# psam_h06
# Left Columns: [['FDRATP']]
# Right Columns: [['FMRGTP']]
# -------------------

# %% [markdown]
# **Result:** We find the expected dataset!

# %% [markdown]
# ### DA_medical_malpractice

# %%
medical_malpractice_file = home_dir + 'DA_medical_malpractice/DA_medical_malpractice_dataset/datasetDoc.json'
medical_malpractice = container.Dataset.load('file://' + medical_malpractice_file)

# %%
medical_malpractice['learningData'].head()
# Out:
#   d3mIndex   SEQNO LICNFELD ORIGYEAR WORKSTAT ALGNNATR ALEGATN1 PTTYPE  \
# 0   404537  514456       10     2004       AZ       20      306      I
# 1   404538  514457       10     2004       PA        1      200      B
# 2   404540  514460      651     2004       SD      100      316      O
# 3   404554  514475      430     2004       NJ       60      334      O
# 4   404556  514477       30     2004       NH       60      306      O
#
#   PRACTAGE   PFIDX
# 0       30  32.737
# 1       50   42.09
# 2       50  58.926
# 3       20  77.633
# 4       50   1.871

# %% [markdown]
# Without keywords.

# %%
cursor = client.search_with_data(query=None, supplied_data=medical_malpractice)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 14.6827 seconds
#
# -------------------
# 1.0
# NPDB1807
# Left Columns: [['ORIGYEAR']]
# Right Columns: [['ORIGYEAR']]
# -------------------
# 1.0
# NPDB1807
# Left Columns: [['ALGNNATR']]
# Right Columns: [['ALGNNATR']]
# -------------------
# 0.8933495
# NPDB1807
# Left Columns: [['SEQNO']]
# Right Columns: [['SEQNO']]
# -------------------
# 0.82362723
# NPDB1807
# Left Columns: [['ALEGATN1']]
# Right Columns: [['ALEGATN1']]
# -------------------
# 0.7991968
# NPDB1807
# Left Columns: [['LICNFELD']]
# Right Columns: [['LICNFELD']]
# -------------------
# 0.6086957
# NPDB1807
# Left Columns: [['PRACTAGE']]
# Right Columns: [['PRACTAGE']]
# -------------------
# 0.40599
# NPDB1807
# Left Columns: [['ALEGATN1']]
# Right Columns: [['ALEGATN2']]
# -------------------

# %% [markdown]
# With keywords.

# %%
query = datamart.DatamartQuery(
    keywords=['practitioner', 'clinical', 'malpractice', 'practitioner data bank',
              'government', 'healthcare', 'Department of health and human services'],  # from problemDoc.json
    variables=[]
)
cursor = client.search_with_data(query=query, supplied_data=medical_malpractice)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 23.1732 seconds
#
# -------------------
# 50.0
# NPDB1807
# Left Columns: [['ORIGYEAR']]
# Right Columns: [['ORIGYEAR']]
# -------------------
# 50.0
# NPDB1807
# Left Columns: [['ALGNNATR']]
# Right Columns: [['ALGNNATR']]
# -------------------
# 44.667477
# NPDB1807
# Left Columns: [['SEQNO']]
# Right Columns: [['SEQNO']]
# -------------------
# 41.181362
# NPDB1807
# Left Columns: [['ALEGATN1']]
# Right Columns: [['ALEGATN1']]
# -------------------
# 39.95984
# NPDB1807
# Left Columns: [['LICNFELD']]
# Right Columns: [['LICNFELD']]
# -------------------
# 30.434784
# NPDB1807
# Left Columns: [['PRACTAGE']]
# Right Columns: [['PRACTAGE']]
# -------------------
# 20.2995
# NPDB1807
# Left Columns: [['ALEGATN1']]
# Right Columns: [['ALEGATN2']]
# -------------------

# %% [markdown]
# **Result:** We find the expected dataset!

# %% [markdown]
# ### DA_ny_taxi_demand

# %%
ny_taxi_demand_file = home_dir + 'DA_ny_taxi_demand/DA_ny_taxi_demand_dataset/datasetDoc.json'
ny_taxi_demand = container.Dataset.load('file://' + ny_taxi_demand_file)

# %%
ny_taxi_demand['learningData'].head()
# Out:
#   d3mIndex tpep_pickup_datetime num_pickups
# 0        0  2018-04-19 22:00:00         731
# 1        1  2018-06-30 20:00:00         183
# 2        2  2018-06-02 10:00:00         384
# 3        3  2018-04-17 13:00:00         648
# 4        4  2018-01-04 01:00:00           3

# %% [markdown]
# Without keywords.

# %%
cursor = client.search_with_data(query=None, supplied_data=ny_taxi_demand)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 4.0649 seconds
#
# -------------------
# 1.0
# Water Consumption And Cost (2013 - March 2019)
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Revenue Month']]
# -------------------
# 1.0
# Street Construction Permits
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['ModifiedOn']]
# -------------------
# 1.0
# Appeals Closed In 2017
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Expiration']]
# -------------------
# 1.0
# Housing New York Units by Building
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Project Start Date']]
# -------------------
# 1.0
# Housing Maintenance Code Complaints
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['ReceivedDate']]
# -------------------
# 1.0
# Capital Projects
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Forecast Completion']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - ELL
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Advanced Regents Num']]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - ELL
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Regents w/o Advanced Num']]
# -------------------
# 1.0
# HRA Facts
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Adult Protective Svs. Referrals Received']]
# -------------------
# 1.0
# 2008-2009 VADIR INCIDENTS
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Enrollment']]
# -------------------
# 1.0
# Parks Inspection Program – Inspections
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['inspAddedDate']]
# -------------------
# 1.0
# Appeals Closed In 2016
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Expiration']]
# -------------------
# 1.0
# LPC Permit Application Information
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['received_date']]
# -------------------
# 1.0
# M/WBE, LBE, and EBE Certified Business List
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['DATEOFJOB2']]
# -------------------
# 1.0
# Housing New York Units by Project
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Project Completion Date']]
# -------------------
# 1.0
# Street Construction Inspections and Corrective Action Requests
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['InspectionDate']]
# -------------------
# 1.0
# Board of Standards and Appeals (BSA) Applications Status
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Date']]
# -------------------
# 1.0
# IBRD Statement Of Loans - Historical Data
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['First Repayment Date']]
# -------------------
# 1.0
# IBRD Statement Of Loans - Historical Data
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Last Repayment Date']]
# -------------------
# 1.0
# IBRD Statement Of Loans - Historical Data
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Closed Date (Most Recent)']]
# -------------------

# %% [markdown]
# With keywords.

# %%
query = datamart.DatamartQuery(
    keywords=['transportation', 'city data', 'taxi',
              'yellow cab', 'pickup', 'LaGuardia airport',
              'weather', 'weather conditions', 'new york',
              'hourly'],  # from problemDoc.json
    variables=[]
)
cursor = client.search_with_data(query=query, supplied_data=ny_taxi_demand)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 8.4898 seconds
#
# -------------------
# 50.0
# Newyork Weather Data around Airport 2016-18
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['DATE']]
# -------------------
# 30.0
# ny_lga_weather_16_17_18
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['DATE']]
# -------------------
# 30.0
# Medallion  Vehicles - Authorized
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Last Date Updated']]
# -------------------
# 25.319695
# Trade Waste Hauler Licensees
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['CREATED']]
# -------------------
# 25.319695
# Trade Waste Hauler Licensees
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['EXPORT DATE']]
# -------------------
# 24.126173
# Medallion  Vehicles - Authorized
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Expiration Date']]
# -------------------
# 20.0
# Housing New York Units by Building
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Project Start Date']]
# -------------------
# 20.0
# Housing New York Units by Project
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Project Completion Date']]
# -------------------
# 20.0
# 2013 - 2014 School Quality Reports
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Most Recent Quality Review']]
# -------------------
# 20.0
# NYPD Complaint Data Historic
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['CMPLNT_FR_DT']]
# -------------------
# 20.0
# NYPD Complaint Data Historic
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['RPT_DT']]
# -------------------
# 20.0
# Evictions
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['EXECUTED_DATE']]
# -------------------
# 20.0
# Taxi Improvement Fund (TIF) Medallion Payments
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Payment Date']]
# -------------------
# 20.0
# Housing New York Units by Building
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Project Completion Date']]
# -------------------
# 20.0
# Handyman Work Order (HWO) Charges
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['HWOCreateDate']]
# -------------------
# 20.0
# Handyman Work Order (HWO) Charges
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['DateTransferDoF']]
# -------------------
# 20.0
# Housing New York Units by Project
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Project Start Date']]
# -------------------
# 20.0
# Legally Operating Businesses
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['License Creation Date']]
# -------------------
# 20.0
# NYPD Complaint Data Historic
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['CMPLNT_TO_DT']]
# -------------------
# 20.0
# Energy and Water Data Disclosure for Local Law 84 2014 (Data for Calendar Year 2013)
# Left Columns: [['tpep_pickup_datetime']]
# Right Columns: [['Street Number']]
# -------------------

# %%
join_ = results[0].augment(supplied_data=ny_taxi_demand)

# %%
join_['learningData'].head()
# Out:
#   d3mIndex tpep_pickup_datetime num_pickups              HOURLYSKYCONDITIONS  \
# 0        0  2018-04-19 22:00:00         731                        FEW:02 42
# 1        1  2018-06-30 20:00:00         183                       SCT:04 250
# 2        2  2018-06-02 10:00:00         384  FEW:02 40 FEW:02 150 SCT:04 200
# 3        3  2018-04-17 13:00:00         648              BKN:07 46 BKN:07 85
# 4        4  2018-01-04 01:00:00           3                        OVC:08 32
#
#   HOURLYDRYBULBTEMPC HOURLYRelativeHumidity HOURLYWindSpeed  \
# 0                5.0                   53.0            16.0
# 1               30.6                   43.0             5.0
# 2               28.3                   61.0             6.0
# 3                8.3                   44.0            17.0
# 4               -1.7                   45.0             8.0
#
#   HOURLYWindDirection HOURLYStationPressure
# 0                 310                 29.97
# 1                 180                 29.97
# 2                 070                  29.7
# 3                 260                  29.6
# 4                 020                 29.91

# %% [markdown]
# **Results:** We find the expected dataset!

# %% [markdown]
# ### DA_poverty_estimation

# %%
poverty_estimation_file = home_dir + 'DA_poverty_estimation/DA_poverty_estimation_dataset/datasetDoc.json'
poverty_estimation = container.Dataset.load('file://' + poverty_estimation_file)

# %%
poverty_estimation['learningData'].head()
# Out:
#   d3mIndex   FIPS State              Area RUCCode POVALL_2016
# 0        0  35005    NM     Chaves County       5       13974
# 1        1  13297    GA     Walton County       1       11385
# 2        2  13137    GA  Habersham County       6        6500
# 3        3  54017    WV  Doddridge County       9        1460
# 4        4  55055    WI  Jefferson County       4        7618

# %% [markdown]
# Without keywords.

# %%
cursor = client.search_with_data(query=None, supplied_data=poverty_estimation)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 1.7506 seconds
#
# -------------------
# 0.93730605
# Zillow Median Listing Prices 2017
# Left Columns: [['FIPS']]
# Right Columns: [['FIPS']]
# -------------------
# 0.9362234
# FIPS Population
# Left Columns: [['FIPS']]
# Right Columns: [['FIPS']]
# -------------------

# %% [markdown]
# With keywords.

# %%
query = datamart.DatamartQuery(
    keywords=['Government', 'Economics', 'Department of Agriculture',
              'USDA', 'economic research service', 'ERS', 'county-level',
              'socioeconomic indicators', 'poverty rate', 'education',
              'population', 'unemployment'],  # from problemDoc.json
    variables=[]
)
cursor = client.search_with_data(query=query, supplied_data=poverty_estimation)

# %%
start = time.time()
results = cursor.get_next_page()
print("Duration: %.4f seconds" % (time.time() - start))
print_results(results)
# Out:
# Duration: 6.9680 seconds
#
# -------------------
# 18.724468
# FIPS Population
# Left Columns: [['FIPS']]
# Right Columns: [['FIPS']]
# -------------------
# 0.93730605
# Zillow Median Listing Prices 2017
# Left Columns: [['FIPS']]
# Right Columns: [['FIPS']]
# -------------------

# %%
join_ = results[0].augment(supplied_data=poverty_estimation)

# %%
join_['learningData'].head()
# Out:
#   d3mIndex   FIPS State              Area RUCCode POVALL_2016 births_2017  \
# 0        0  35005    NM     Chaves County       5       13974       915.0
# 1        1  13297    GA     Walton County       1       11385      1181.0
# 2        2  13137    GA  Habersham County       6        6500       512.0
# 3        3  54017    WV  Doddridge County       9        1460        82.0
# 4        4  55055    WI  Jefferson County       4        7618       828.0
#
#   deaths_2017 population_2017 population_2010 Unnamed: 5
# 0       633.0           64866           65645
# 1       843.0           91600           83768
# 2       459.0           44567           43041
# 3        75.0            8560            8202
# 4       672.0           84832           83686

# %% [markdown]
# **Results:** We find the expected dataset!

# %% [markdown]
# ## REST API for DataMart
#
# This notebook showcases how to use the REST API for the DataMart system.
#
# For the augmentation, we use the FIFA 2018 Man of Match data, available here: https://gitlab.datadrivendiscovery.org/d3m/datasets/tree/master/seed_datasets_data_augmentation/DA_fifa2018_manofmatch
#
# The documentation for the REST API is available here: https://docs.auctus.vida-nyu.org/swagger/

# %%
from io import BytesIO
import json
import os
import pandas as pd
from pprint import pprint
from pathlib import Path
import requests
import zipfile

# %%
def print_results(results):
    if not results:
        return
    for result in results:
        print(result['metadata']['name'])
        print('Score: ', result['score'])
        if 'augmentation' in result:
            aug_type = result['augmentation']['type']
            print('Augmentation: %s' % aug_type)
            print("Left Columns: %s" %
                  str(result['augmentation']['left_columns_names']))
            print("Right Columns: %s" %
                  str(result['augmentation']['right_columns_names']))
            
        print("-------------------")

# %% [markdown]
# Initially, we have the supplied data.

# %%
# You can change this accordingly
fifa_manofmatch_dir = os.path.expanduser('~/projects/d3m/datasets/seed_datasets_data_augmentation/DA_fifa2018_manofmatch/DA_fifa2018_manofmatch_dataset')
fifa_manofmatch_file = os.path.join(fifa_manofmatch_dir, 'tables', 'learningData.csv')
fifa_manofmatch_table = pd.read_csv(fifa_manofmatch_file)

# %%
fifa_manofmatch_table.head()
# Out:
#   d3mIndex GameID        Date     Team        Opponent Ball Possession %  \
# 0        0     55  23-06-2018   Mexico  Korea Republic                59
# 1        1     40  21-06-2018  Denmark       Australia                49
# 2        2     19  17-06-2018   Mexico         Germany                40
# 3        3     31  19-06-2018  Senegal          Poland                43
# 4        4     98  30-06-2018  Uruguay        Portugal                39
#
#   Off-Target Blocked Offsides Saves Pass Accuracy % Passes  \
# 0          6       2        0     5              89    485
# 1          5       0        1     4              88    458
# 2          6       2        2     9              82    281
# 3          4       2        3     3              81    328
# 4          2       1        0     4              69    269
#
#   Distance Covered (Kms) Yellow & Red Man of the Match 1st Goal        Round  \
# 0                     97            0                1     26.0  Group Stage
# 1                    112            0                1      7.0  Group Stage
# 2                    106            0                0     35.0  Group Stage
# 3                    107            0                1     60.0  Group Stage
# 4                    106            0                1      7.0  Round of 16
#
#   PSO Goals in PSO Own goals
# 0  No            0
# 1  No            0
# 2  No            0
# 3  No            0
# 4  No            0

# %% [markdown]
# ### Searching for Datasets
#
# Let's use DataMart to search for datasets that can be used to augment the supplied one.

# %%
URL = 'https://auctus.vida-nyu.org'

# %%
url = URL + '/search'

# http://docs.python-requests.org/en/latest/user/quickstart/#post-a-multipart-encoded-file
with open(fifa_manofmatch_file, 'rb') as data:
    response = requests.post(
        url,
        files={
            'data': data,
        }
    )
if response.status_code == 400:
    try:
        print('Error: %s' % response.json()['error'])
    except (KeyError, ValueError):
        pass
response.raise_for_status()
query_results = response.json()['results']

# %%
print_results(query_results)
# Out:
# Water Consumption And Cost (2013 - March 2019)
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Revenue Month']]
# -------------------
# Board of Standards and Appeals (BSA) Applications Status
# Score:  0.1
# Augmentation: union
# Left Columns: [['Date'], ['Blocked']]
# Right Columns: [['Date'], ['Block']]
# -------------------
# Street Construction Permits
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['ModifiedOn']]
# -------------------
# FIFA 2018 game statistics data
# Score:  0.08125
# Augmentation: union
# Left Columns: [['GameID'], ['Off-Target']]
# Right Columns: [['GameID'], ['On-Target']]
# -------------------
# Housing New York Units by Building
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Project Start Date']]
# -------------------
# Housing Maintenance Code Complaints
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['ReceivedDate']]
# -------------------
# Capital Projects
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Forecast Completion']]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough - ELL
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Advanced Regents Num']]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough - ELL
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Regents w/o Advanced Num']]
# -------------------
# HRA Facts
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Adult Protective Svs. Referrals Received']]
# -------------------
# 2008-2009 VADIR INCIDENTS
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Enrollment']]
# -------------------
# Parks Inspection Program – Inspections
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['inspAddedDate']]
# -------------------
# Appeals Closed In 2016
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Expiration']]
# -------------------
# LPC Permit Application Information
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['received_date']]
# -------------------
# M/WBE, LBE, and EBE Certified Business List
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['DATEOFJOB2']]
# -------------------
# Housing New York Units by Project
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Project Completion Date']]
# -------------------
# Forestry Work Orders
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['ClosedDate']]
# -------------------
# Street Construction Inspections and Corrective Action Requests
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['InspectionDate']]
# -------------------
# Board of Standards and Appeals (BSA) Applications Status
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Date']]
# -------------------
# IBRD Statement Of Loans - Historical Data
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['First Repayment Date']]
# -------------------
# IBRD Statement Of Loans - Historical Data
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Last Repayment Date']]
# -------------------
# IBRD Statement Of Loans - Historical Data
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Closed Date (Most Recent)']]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough - Classes of - Gender
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Total Regents Num']]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough - Classes of - Gender
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Regents w/o Advanced Num']]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough - Classes of - Gender
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Still Enrolled Num']]
# -------------------
# Inmate Admissions
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['ADMITTED_DT']]
# -------------------
# Charges
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Violation Date']]
# -------------------
# Cooking Gas Consumption And Cost (2010 - Mar 2019)
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Service End Date']]
# -------------------
# Summary of DBP Quarterly Report
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Analysis Date HAA5 (µg/L) (b)']]
# -------------------
# Encroachments and Defacements
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['FollowUpInspectionDate']]
# -------------------
# Heating Oil Consumption And Cost (2010 - 2019)
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Service End Date']]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough  - Total Cohort
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Regents w/o Advanced Num']]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough  - Total Cohort
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Local Num']]
# -------------------
# DOF: Refund List - Real property Tax
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['PERIOD BEGIN']]
# -------------------
# License Applications
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['End Date']]
# -------------------
# Weights, Measures, and Other Tests
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Inspection Date']]
# -------------------
# Inmate Discharges
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['ADMITTED_DT']]
# -------------------
# Inmate Discharges
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['DISCHARGED_DT']]
# -------------------
# Bureau of Fire Prevention - Inspections
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['LAST_VISIT_DT']]
# -------------------
# Use of ARRA Stimulus Funds
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Contract End Date']]
# -------------------
# 2013 - 2014 School Quality Reports
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Most Recent Quality Review']]
# -------------------
# Benefits and Programs API (Historical)
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['date']]
# -------------------
# Borough Engineering Tracking System
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['DueDate']]
# -------------------
# Cash Assistance Youth Engagement
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Total Head of Household, 21-24 Years Old']]
# -------------------
# Total SNAP Recipients
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Month']]
# -------------------
# Street Construction Permits - Fee
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['CreatedOn']]
# -------------------
# 2016-17 Physical Education - PE Instruction - Borough Level
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['# of students who are receiving less than the required amount of physical education instruction']]
# -------------------
# IDA Statement of Credits and Grants  - Latest Available Snapshot
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Effective Date (Most Recent)']]
# -------------------
# Recoupment for Damaged City-owned Property
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['DateReceived']]
# -------------------
# Free Residential at-the-tap Lead and Copper Data
# Score:  1.0
# Augmentation: join
# Left Columns: [['Date']]
# Right Columns: [['Date Received']]
# -------------------

# %% [markdown]
# It is also possible to specify which column will be used for augmentation.

# %%
url = URL + '/search'
query={
    'variables': [
        {
            'type': 'tabular_variable',
            'columns': [1],  # GameID
            'relationship': 'contains'
        }
    ]
}

# http://docs.python-requests.org/en/latest/user/quickstart/#post-a-multipart-encoded-file
with open(fifa_manofmatch_file, 'rb') as data:
    response = requests.post(
        url,
        files={
            'data': data,
            'query': ('query.json', json.dumps(query), 'application/json'),
        }
    )
if response.status_code == 400:
    try:
        print('Error: %s' % response.json()['error'])
    except (KeyError, ValueError):
        pass
response.raise_for_status()
gameID_results = response.json()['results']

# %%
print_results(gameID_results)
# Out:
# FIFA 2018 game statistics data
# Score:  0.98275864
# Augmentation: join
# Left Columns: [['GameID']]
# Right Columns: [['GameID']]
# -------------------

# %% [markdown]
# ### Augmenting a Dataset

# %% [markdown]
# Let's try to do our augmentation for the previous first query result then.

# %%
url = URL + '/augment'
task = gameID_results[0]

# http://docs.python-requests.org/en/latest/user/quickstart/#post-a-multipart-encoded-file
with open(fifa_manofmatch_file, 'rb') as data:
    response = requests.post(
        url,
        files={
            'data': data,
            'task': ('task.json', json.dumps(task), 'application/json'),
        },
        stream=True,
    )
if response.status_code == 400:
    try:
        print('Error: %s' % response.json()['error'])
    except (KeyError, ValueError):
        pass
response.raise_for_status()
zip_ = zipfile.ZipFile(BytesIO(response.content), 'r')
learning_data = pd.read_csv(zip_.open('tables/learningData.csv'))
dataset_doc = json.load(zip_.open('datasetDoc.json'))
zip_.close()

# %%
learning_data.head()
# Out:
#    d3mIndex  GameID        Date     Team        Opponent  Ball Possession %  \
# 0         0      55  2018-06-23   Mexico  Korea Republic                 59
# 1         1      40  2018-06-21  Denmark       Australia                 49
# 2         2      19  2018-06-17   Mexico         Germany                 40
# 3         3      31  2018-06-19  Senegal          Poland                 43
# 4         4      98  2018-06-30  Uruguay        Portugal                 39
#
#    Off-Target  Blocked  Offsides  Saves      ...        Own goals  \
# 0           6        2         0      5      ...              NaN
# 1           5        0         1      4      ...              NaN
# 2           6        2         2      9      ...              NaN
# 3           4        2         3      3      ...              NaN
# 4           2        1         0      4      ...              NaN
#
#    Goal Scored  Attempts  On-Target  Corners  Free Kicks Fouls Committed  \
# 0            2        13          5        5          24               7
# 1            1        10          5        3           5               7
# 2            1        12          4        1          11              15
# 3            2         8          2        3          11              15
# 4            2         6          3        2          14              13
#
#   Yellow Card  Red  Own goal Time
# 0           0    0            NaN
# 1           2    0            NaN
# 2           2    0            NaN
# 3           2    0            NaN
# 4           0    0            NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# And we have our augmented data! Its corresponding datasetDoc JSON object is presented below.
#
# However, note that this datasetDoc JSON **does not** preserve the information from the supplied data's datasetDoc JSON. You need to use the Python DataMart API for that: https://gitlab.com/datadrivendiscovery/datamart-api/blob/master/datamart.py

# %%
pprint(dataset_doc, indent=2)
# Out:
# { 'about': { 'approximateSize': '59300 B',
#              'datasetID': 'e8a407b75568422eb33bb0338f1b989b',
#              'datasetName': 'e8a407b75568422eb33bb0338f1b989b',
#              'datasetSchemaVersion': '3.2.0',
#              'datasetVersion': '0.0',
#              'license': 'unknown',
#              'redacted': False},
#   'dataResources': [ { 'columns': [ { 'colIndex': 0,
#                                       'colName': 'd3mIndex',
#                                       'colType': 'integer',
#                                       'role': ['index']},
#                                     { 'colIndex': 1,
#                                       'colName': 'GameID',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 2,
#                                       'colName': 'Date',
#                                       'colType': 'dateTime',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 3,
#                                       'colName': 'Team',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 4,
#                                       'colName': 'Opponent',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 5,
#                                       'colName': 'Ball Possession %',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 6,
#                                       'colName': 'Off-Target',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 7,
#                                       'colName': 'Blocked',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 8,
#                                       'colName': 'Offsides',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 9,
#                                       'colName': 'Saves',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 10,
#                                       'colName': 'Pass Accuracy %',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 11,
#                                       'colName': 'Passes',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 12,
#                                       'colName': 'Distance Covered (Kms)',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 13,
#                                       'colName': 'Yellow & Red',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 14,
#                                       'colName': 'Man of the Match',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 15,
#                                       'colName': '1st Goal',
#                                       'colType': 'real',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 16,
#                                       'colName': 'Round',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 17,
#                                       'colName': 'PSO',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 18,
#                                       'colName': 'Goals in PSO',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 19,
#                                       'colName': 'Own goals',
#                                       'colType': 'real',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 20,
#                                       'colName': 'Goal Scored',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 21,
#                                       'colName': 'Attempts',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 22,
#                                       'colName': 'On-Target',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 23,
#                                       'colName': 'Corners',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 24,
#                                       'colName': 'Free Kicks',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 25,
#                                       'colName': 'Fouls Committed',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 26,
#                                       'colName': 'Yellow Card',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 27,
#                                       'colName': 'Red',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 28,
#                                       'colName': 'Own goal Time',
#                                       'colType': 'real',
#                                       'role': ['attribute']}],
#                        'isCollection': False,
#                        'resFormat': ['text/csv'],
#                        'resID': 'learningData',
#                        'resPath': 'tables/learningData.csv',
#                        'resType': 'table'}],
#   'qualities': [ { 'qualName': 'augmentation_info',
#                    'qualValue': { 'augmentation_type': 'join',
#                                   'nb_rows_after': 128,
#                                   'nb_rows_before': 128,
#                                   'new_columns': [ 'Corners',
#                                                    'Red',
#                                                    'Goal Scored',
#                                                    'Yellow Card',
#                                                    'Fouls Committed',
#                                                    'Attempts',
#                                                    'On-Target',
#                                                    'Free Kicks',
#                                                    'Own goal Time'],
#                                   'removed_columns': []},
#                    'qualValueType': 'dict'}]}

# %% [markdown]
# ## REST API for DataMart
#
# This notebook showcases how to use the REST API for the DataMart system. For the augmentation, we use the data about FIFA 2018 world cup games from MIT-LL, available here: https://gitlab.datadrivendiscovery.org/MIT-LL/phase_2/data_augmentation_track_seed/da_seed_fifa_2018_manofmatch_prediction/

# %%
from io import BytesIO
import json
import os
import pandas as pd
from pprint import pprint
import requests
import zipfile

# %% [markdown]
# Initially, we have the world cup data.

# %%
world_cup_data = pd.read_csv('data/fifa2018_manofmatch.csv')
world_cup_data.head()
# Out:
#    d3mIndex  GameID        Date     Team        Opponent  Ball Possession %  \
# 0         0      55  23-06-2018   Mexico  Korea Republic                 59
# 1         1      40  21-06-2018  Denmark       Australia                 49
# 2         2      19  17-06-2018   Mexico         Germany                 40
# 3         3      31  19-06-2018  Senegal          Poland                 43
# 4         4      98  30-06-2018  Uruguay        Portugal                 39
#
#    Off-Target  Blocked  Offsides  Saves  Pass Accuracy %  Passes  \
# 0           6        2         0      5               89     485
# 1           5        0         1      4               88     458
# 2           6        2         2      9               82     281
# 3           4        2         3      3               81     328
# 4           2        1         0      4               69     269
#
#    Distance Covered (Kms)  Yellow & Red  Man of the Match  1st Goal  \
# 0                      97             0                 1      26.0
# 1                     112             0                 1       7.0
# 2                     106             0                 0      35.0
# 3                     107             0                 1      60.0
# 4                     106             0                 1       7.0
#
#          Round PSO  Goals in PSO  Own goals
# 0  Group Stage  No             0        NaN
# 1  Group Stage  No             0        NaN
# 2  Group Stage  No             0        NaN
# 3  Group Stage  No             0        NaN
# 4  Round of 16  No             0        NaN

# %%
print('Size: %d rows' % world_cup_data.shape[0])
# Out:
# Size: 128 rows

# %% [markdown]
# ### Searching for Datasets
#
# Let's use DataMart to search for datasets that can be used to augment the world cup one.

# %%
url = 'https://datamart.d3m.vida-nyu.org/search'
data = 'data/fifa2018_manofmatch.csv'

# http://docs.python-requests.org/en/latest/user/quickstart/#post-a-multipart-encoded-file
with open(data, 'rb') as data_p:
    response = requests.post(
        url,
        files={
            'data': data_p,
        }
    )
response.raise_for_status()
query_results = response.json()['results']

# %%
print('There are %d query results!\n' % len(query_results))
for result in query_results[:5]: # top-5
    print(result['metadata']['name'])
    print('Score: ', result['score'])
    aug_type = 'Union' if 'union_columns' in result else 'Join'
    aug = result['union_columns'] if 'union_columns' in result else result['join_columns']
    print('%s:' % aug_type, aug)
    print('--------')
# Out:
# There are 363 query results!
#
# FIFA 2018 game statistics data
# Score:  1.0
# Join: [['GameID', 'GameID'], ['Yellow & Red', 'Yellow Card']]
# --------
# Parking Violations Issued - Fiscal Year 2017
# Score:  1.0
# Join: [['Date', 'Issue Date']]
# --------
# 2014 NYC Open Data Plan
# Score:  1.0
# Join: [['Date', 'Planned Release Date']]
# --------
# Historical DOB Permit Issuance
# Score:  1.0
# Join: [['Date', 'Job Start Date']]
# --------
# Wholesale Markets
# Score:  1.0
# Join: [['Date', 'EXPORT DATE']]
# --------

# %% [markdown]
# The first dataset seems relevant: it has a score 1.0 for join, and it also represents a FIFA dataset.

# %% [markdown]
# ### Augmenting a Dataset

# %% [markdown]
# Let's try to do our augmentation for the first query result then.

# %%
url = 'https://datamart.d3m.vida-nyu.org/augment'
data = 'data/fifa2018_manofmatch.csv'
task = query_results[0]

# http://docs.python-requests.org/en/latest/user/quickstart/#post-a-multipart-encoded-file
with open(data, 'rb') as data_p:
    response = requests.post(
        url,
        files={
            'data': data_p,
            'task': ('task.json', json.dumps(task), 'application/json'),
        },
        stream=True,
    )
response.raise_for_status()
zip_ = zipfile.ZipFile(BytesIO(response.content), 'r')
learning_data = pd.read_csv(zip_.open('tables/learningData.csv'))
dataset_doc = json.load(zip_.open('datasetDoc.json'))
zip_.close()

# %%
learning_data.head()
# Out:
#    GameID        Date     Team        Opponent  Ball Possession %  Off-Target  \
# 0      55  2018-06-23   Mexico  Korea Republic                 59           6
# 1      98  2018-06-30  Uruguay        Portugal                 39           2
# 2      81  2018-06-27  Germany  Korea Republic                 70          11
# 3      26  2018-06-18  Tunisia         England                 41           3
# 4      94  2018-06-28  England         Belgium                 48           7
#
#    Blocked  Offsides  Saves  Pass Accuracy %    ...     Own goals  \
# 0        2         0      5               89    ...           NaN
# 1        1         0      4               69    ...           NaN
# 2        9         1      3               88    ...           NaN
# 3        2         2      5               82    ...           NaN
# 4        5         3      3               88    ...           NaN
#
#    Goal Scored  Attempts  On-Target  Corners Free Kicks Fouls Committed  Red  \
# 0            2        13          5        5         24               7    0
# 1            2         6          3        2         14              13    0
# 2            0        26          6        9         16               7    0
# 3            1         6          1        2         11              14    0
# 4            0        13          1        7         15              11    0
#
#    Own goal Time  d3mIndex
# 0            NaN         0
# 1            NaN         1
# 2            NaN         2
# 3            NaN         3
# 4            NaN         4
#
# [5 rows x 28 columns]

# %%
print('Size: %d rows' % learning_data.shape[0])
# Out:
# Size: 25 rows

# %% [markdown]
# Note that the joined dataset has only **25 rows**, compared to the original **128 rows**. But if we take a look at the augmentation information, we are performing a _multi-join_, i.e., a join using two keys:

# %%
print(query_results[0]['join_columns'])
# Out:
# [['GameID', 'GameID'], ['Yellow & Red', 'Yellow Card']]

# %% [markdown]
# The second pair of columns may not seem right...

# %% [markdown]
# But can we perform a join using only column `GameID`? Of course! Let's first remove the second column from the list.

# %%
query_results[0]['join_columns'].pop()
print(query_results[0]['join_columns'])
# Out:
# [['GameID', 'GameID']]

# %% [markdown]
# Then we perform the augmentation again.

# %%
url = 'https://datamart.d3m.vida-nyu.org/augment'
data = 'data/fifa2018_manofmatch.csv'
task = query_results[0]

# http://docs.python-requests.org/en/latest/user/quickstart/#post-a-multipart-encoded-file
with open(data, 'rb') as data_p:
    response = requests.post(
        url,
        files={
            'data': data_p,
            'task': ('task.json', json.dumps(task), 'application/json'),
        },
        stream=True,
    )
response.raise_for_status()
zip_ = zipfile.ZipFile(BytesIO(response.content), 'r')
learning_data = pd.read_csv(zip_.open('tables/learningData.csv'))
dataset_doc = json.load(zip_.open('datasetDoc.json'))
zip_.close()

# %%
learning_data.head()
# Out:
#    GameID        Date     Team        Opponent  Ball Possession %  Off-Target  \
# 0      55  2018-06-23   Mexico  Korea Republic                 59           6
# 1      40  2018-06-21  Denmark       Australia                 49           5
# 2      19  2018-06-17   Mexico         Germany                 40           6
# 3      31  2018-06-19  Senegal          Poland                 43           4
# 4      98  2018-06-30  Uruguay        Portugal                 39           2
#
#    Blocked  Offsides  Saves  Pass Accuracy %    ...     Goal Scored  Attempts  \
# 0        2         0      5               89    ...               2        13
# 1        0         1      4               88    ...               1        10
# 2        2         2      9               82    ...               1        12
# 3        2         3      3               81    ...               2         8
# 4        1         0      4               69    ...               2         6
#
#    On-Target  Corners  Free Kicks Fouls Committed Yellow Card  Red  \
# 0          5        5          24               7           0    0
# 1          5        3           5               7           2    0
# 2          4        1          11              15           2    0
# 3          2        3          11              15           2    0
# 4          3        2          14              13           0    0
#
#    Own goal Time  d3mIndex
# 0            NaN         0
# 1            NaN         1
# 2            NaN         2
# 3            NaN         3
# 4            NaN         4
#
# [5 rows x 29 columns]

# %%
print('Size: %d rows' % learning_data.shape[0])
# Out:
# Size: 128 rows

# %% [markdown]
# And we have our final augmented data! Its corresponding datasetDoc JSON object is presented below.

# %%
pprint(dataset_doc, indent=2)
# Out:
# { 'about': { 'approximateSize': '59300 B',
#              'datasetID': '8700aa115ffe4a52ac7f9d7a395bdca5',
#              'datasetName': '8700aa115ffe4a52ac7f9d7a395bdca5',
#              'datasetSchemaVersion': '3.2.0',
#              'datasetVersion': '0.0',
#              'license': 'unknown',
#              'redacted': False},
#   'dataResources': [ { 'columns': [ { 'colIndex': 0,
#                                       'colName': 'GameID',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 1,
#                                       'colName': 'Date',
#                                       'colType': 'dateTime',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 2,
#                                       'colName': 'Team',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 3,
#                                       'colName': 'Opponent',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 4,
#                                       'colName': 'Ball Possession %',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 5,
#                                       'colName': 'Off-Target',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 6,
#                                       'colName': 'Blocked',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 7,
#                                       'colName': 'Offsides',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 8,
#                                       'colName': 'Saves',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 9,
#                                       'colName': 'Pass Accuracy %',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 10,
#                                       'colName': 'Passes',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 11,
#                                       'colName': 'Distance Covered (Kms)',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 12,
#                                       'colName': 'Yellow & Red',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 13,
#                                       'colName': 'Man of the Match',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 14,
#                                       'colName': '1st Goal',
#                                       'colType': 'real',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 15,
#                                       'colName': 'Round',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 16,
#                                       'colName': 'PSO',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 17,
#                                       'colName': 'Goals in PSO',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 18,
#                                       'colName': 'Own goals',
#                                       'colType': 'real',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 19,
#                                       'colName': 'Goal Scored',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 20,
#                                       'colName': 'Attempts',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 21,
#                                       'colName': 'On-Target',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 22,
#                                       'colName': 'Corners',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 23,
#                                       'colName': 'Free Kicks',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 24,
#                                       'colName': 'Fouls Committed',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 25,
#                                       'colName': 'Yellow Card',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 26,
#                                       'colName': 'Red',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 27,
#                                       'colName': 'Own goal Time',
#                                       'colType': 'real',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 28,
#                                       'colName': 'd3mIndex',
#                                       'colType': 'integer',
#                                       'role': ['index']}],
#                        'isCollection': False,
#                        'resFormat': ['text/csv'],
#                        'resID': '0',
#                        'resPath': 'tables/learningData.csv',
#                        'resType': 'table'}]}

# %% [markdown]
# ## REST API for DataMart
#
# This notebook showcases how to use the REST API for the DataMart system.
#
# For the augmentation, we use the FIFA 2018 Man of Match data, available here: https://gitlab.datadrivendiscovery.org/d3m/datasets/tree/master/seed_datasets_data_augmentation/DA_fifa2018_manofmatch
#
# The documentation for the REST API is available here: https://vida-nyu.gitlab.io/-/datamart/datamart-api/-/jobs/233008593/artifacts/pages/rest_api.html

# %%
from d3m import container
from io import BytesIO
import json
import os
import pandas as pd
from pprint import pprint
from pathlib import Path
import requests
import zipfile

# %%
def print_results(results):
    if not results:
        return
    for result in results:
        print(result['metadata']['name'])
        print('Score: ', result['score'])
        if 'augmentation' in result:
            aug_type = result['augmentation']['type']
            print('Augmentation: %s' % aug_type)
            left_columns = []
            for column_ in result['augmentation']['left_columns']:
                left_columns.append([])
                for column in column_:
                    left_columns[-1].append(column)
            print("Left Columns: %s" % str(left_columns))
            right_columns = []
            for column_ in result['augmentation']['right_columns']:
                right_columns.append([])
                for column in column_:
                    right_columns[-1].append(column)
            print("Right Columns: %s" % str(right_columns))
            
        print("-------------------")

# %% [markdown]
# Initially, we have the supplied data.

# %%
# You can change this accordingly
fifa_manofmatch_dir = str(Path.home()) + '/projects/d3m/datasets/seed_datasets_data_augmentation/' +\
                       'DA_fifa2018_manofmatch/DA_fifa2018_manofmatch_dataset/'
fifa_manofmatch_file = fifa_manofmatch_dir + 'datasetDoc.json'
fifa_manofmatch = container.Dataset.load('file://' + fifa_manofmatch_file)

# %%
fifa_manofmatch['learningData'].head()
# Out:
#   d3mIndex GameID        Date     Team        Opponent Ball Possession %  \
# 0        0     55  23-06-2018   Mexico  Korea Republic                59
# 1        1     40  21-06-2018  Denmark       Australia                49
# 2        2     19  17-06-2018   Mexico         Germany                40
# 3        3     31  19-06-2018  Senegal          Poland                43
# 4        4     98  30-06-2018  Uruguay        Portugal                39
#
#   Off-Target Blocked Offsides Saves Pass Accuracy % Passes  \
# 0          6       2        0     5              89    485
# 1          5       0        1     4              88    458
# 2          6       2        2     9              82    281
# 3          4       2        3     3              81    328
# 4          2       1        0     4              69    269
#
#   Distance Covered (Kms) Yellow & Red Man of the Match 1st Goal        Round  \
# 0                     97            0                1     26.0  Group Stage
# 1                    112            0                1      7.0  Group Stage
# 2                    106            0                0     35.0  Group Stage
# 3                    107            0                1     60.0  Group Stage
# 4                    106            0                1      7.0  Round of 16
#
#   PSO Goals in PSO Own goals
# 0  No            0
# 1  No            0
# 2  No            0
# 3  No            0
# 4  No            0

# %% [markdown]
# ### Searching for Datasets
#
# Let's use DataMart to search for datasets that can be used to augment the supplied one.

# %%
url = 'https://datamart.d3m.vida-nyu.org/search'
data = fifa_manofmatch_dir + 'tables/learningData.csv'

# http://docs.python-requests.org/en/latest/user/quickstart/#post-a-multipart-encoded-file
with open(data, 'rb') as data_p:
    response = requests.post(
        url,
        files={
            'data': data_p,
        }
    )
response.raise_for_status()
query_results = response.json()['results']

# %%
print_results(query_results)
# Out:
# FIFA 2018 game statistics data
# Score:  1.0
# Augmentation: join
# Left Columns: [[13]]
# Right Columns: [[8]]
# -------------------
# Housing New York Units by Building
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[19]]
# -------------------
# Recognized Shop Healthy Stores
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Contractor / Sub Contractor Change Order Report
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[10]]
# -------------------
# Cash Assistance Youth Engagement
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# City Clerk eLobbyist Data
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[14]]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough - ELL
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[21]]
# -------------------
# Street Construction Permits - Stipulations (Historical)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# Low Income Housing Tax Credits Awarded by HPD: Project-Level (9% Awards)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[13]]
# -------------------
# Corporate Procurement Contract Awards
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Parking Violations Issued - Fiscal Year 2017
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[23]]
# -------------------
# Parking Violations Issued - Fiscal Year 2015
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[17]]
# -------------------
# 2014 NYC Open Data Plan
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Charges
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# SCA Disqualified Firms
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# DEP - Cryptosporidium And Giardia Data Set
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# OATH Trials Division Case Status
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# NYC Parks Events Listing – Event Listing
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Appeals Closed In 2016
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# FY17 BID Trends Report Data
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[46]]
# -------------------
# Swim for Life
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[11]]
# -------------------
# Forestry Service Requests
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[33]]
# -------------------
# Forestry Work Orders
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[37]]
# -------------------
# Clergy Parking Permits
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# Wholesale Markets
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[20]]
# -------------------
# Self Hauler Registrants
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[19]]
# -------------------
# Order to Repair/Vacate Orders
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# DOHMH New York City Restaurant Inspection Results
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# NYC Council Constituent Services
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# LinkNYC Kiosk Status (Historical)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[22]]
# -------------------
# Asset Management Parks System (AMPS) - Work Orders
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[34]]
# -------------------
# Asset Management Parks System (AMPS) – Labor
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[10]]
# -------------------
# NYC Permitted Event Information - Historical
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# NYC Wi-Fi Hotspot Locations
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[15]]
# -------------------
# Current Reservoir Levels
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Housing New York Units by Project
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# Total SNAP Recipients
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough - Ethnicity
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[21]]
# -------------------
# Citywide HRA- Administered Medicaid Enrollees
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Fee Charges
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[18]]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough  - Total Cohort
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[18]]
# -------------------
# Summary of DBP Quarterly Report
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Low Income Housing Tax Credits Awarded by HPD: Project-Level (4% Awards)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[13]]
# -------------------
# IBRD Statement Of Loans - Historical Data
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[31]]
# -------------------
# Parking Violations Issued - Fiscal Year 2019
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[17]]
# -------------------
# World Bank (IBRD) Bonds (1947-Present)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# License Applications
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Use of ARRA Stimulus Funds
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[26]]
# -------------------
# Open Market Order (OMO) Charges
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[17]]
# -------------------
# Board of Standards and Appeals (BSA) Applications Status
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[12]]
# -------------------
# Property Exemption Detail
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[32]]
# -------------------
# Attendance 4PM Report
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Enforcement Fines
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Doing Business Search - People
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# 311 Web Content - Services
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[9]]
# -------------------
# LPC Permit Application Information
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[30]]
# -------------------
# Buildings Selected for the Alternative Enforcement Program (AEP)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# Civil Service List (Terminated)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[14]]
# -------------------
# Trade Waste Hauler Licensees
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[19]]
# -------------------
# Construction Demolition Registrants
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[19]]
# -------------------
# CATS Permits
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[18]]
# -------------------
# Street Hail Livery (SHL) Permits
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[9]]
# -------------------
# DOB Complaints Received
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[13]]
# -------------------
# Historical Driver Application Status
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[11]]
# -------------------
# DOB Stalled Construction Sites
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Inmate Admissions
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Work Order Management Module
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# Inmate Assault on Staff
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# OEM Emergency Notifications
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Asset Management Parks System (AMPS) – Transaction Details
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[30]]
# -------------------
# Borough Engineering Tracking System
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[12]]
# -------------------
# 2016-2017 Local Law 14 Health Data
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Street Construction Permits - Cranes
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# EMS Incident Dispatch Data
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[16]]
# -------------------
# Bureau of Fire Prevention - Inspections
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# Invoices for Open Market Order (OMO) Charges
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[11]]
# -------------------
# Capital Projects
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[13]]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough - Classes of - Gender
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[21]]
# -------------------
# 2005 - 2011 Graduation Outcomes - Borough - Classes of - SWD
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[21]]
# -------------------
# 2005 - 2011 Graduation Outcomes - Citywide - Ethnicity
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[20]]
# -------------------
# 2015 Open Data plan – Scheduled Releases
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# 2013 - 2014 School Quality Reports Results for High Schools
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# IBRD Statement of Loans - Latest Available Snapshot
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[32]]
# -------------------
# IFC Investment Services Projects
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[16]]
# -------------------
# MIGA Issued Projects
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[11]]
# -------------------
# 311 Service Requests from 2010 to Present
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[22]]
# -------------------
# Parking Violations Issued - Fiscal Year 2016
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[17]]
# -------------------
# LinkNYC Locations
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[11]]
# -------------------
# Facilities Database
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# Parking Violations Issued - Fiscal Year 2018
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[17]]
# -------------------
# Heating Oil Consumption And Cost (2010 - 2019)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[15]]
# -------------------
# Local Law 44 - Projects
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# 2003 Campaign Expenditures
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[18]]
# -------------------
# Lot Cleaning Dispositions
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[101]]
# -------------------
# Civil Service List (Active)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[12]]
# -------------------
# DOB Permit Issuance
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[27]]
# -------------------
# DOB NOW: Build – Approved Permits
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[26]]
# -------------------
# Multiple Dwelling Registrations
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[15]]
# -------------------
# Housing Litigations
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[9]]
# -------------------
# Asset Management Parks System (AMPS) – Comments
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# Street Construction Permits - Related Agency
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# 2010 - 2016 School Safety Report
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# Fire Incident Dispatch Data
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[21]]
# -------------------
# Housing Maintenance Code Complaints
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[14]]
# -------------------
# Doing Business Search - Entities
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# DOF ScoffTow Case Information
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[10]]
# -------------------
# 2013 - 2014 School Quality Reports
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# 2015-16 Health Education HS Level
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# Capital Project Detail Data - Milestones
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[11]]
# -------------------
# IDA Statement of Credits and Grants  - Latest Available Snapshot
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[29]]
# -------------------
# Afghanistan Reconstruction Trust Fund  (ARTF) - Project Allocations and Disbursements - BETA
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[25]]
# -------------------
# Afghanistan Reconstruction Trust Fund (ARTF) Project Results - BETA
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[11]]
# -------------------
# Parking Violations Issued - Fiscal Year 2014 (August 2013 – June 2014)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[17]]
# -------------------
# NYC Municipal Building Energy Benchmarking Results
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[13]]
# -------------------
# Benefits and Programs API (Historical)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[33]]
# -------------------
# HRA Facts
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[56]]
# -------------------
# Handyman Work Order (HWO) Charges
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[13]]
# -------------------
# Heating Gas Consumption And Cost (2010 - March 2019)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[15]]
# -------------------
# Steam Consumption And Cost (2010 - Mar 2019)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[15]]
# -------------------
# Cooking Gas Consumption And Cost (2010 - Mar 2019)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[15]]
# -------------------
# Traffic Signal and All-Way Stop Study Requests
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[30]]
# -------------------
# Civil Service List Certification
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[14]]
# -------------------
# Evictions
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# DOHMH Beach Water Quality Data
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# CEQR Project Milestones
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# Street Construction Permits
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[35]]
# -------------------
# Street Construction Inspections and Corrective Action Requests
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[26]]
# -------------------
# LinkNYC Kiosk Status
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[21]]
# -------------------
# Annual Overweight Load (AOL) Permits
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Intercity Bus Stop Permits
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[19]]
# -------------------
# Inmate Discharges
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Local Law 251 of 2017: NYC Open Data Plan Tracker
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Street Construction Permits - Fee
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Asset Management Parks System (AMPS) – Transactions
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[12]]
# -------------------
# DSNY Monthly Tonnage Data
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Complaint Problems
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[16]]
# -------------------
# Bureau of Fire Prevention - Active Violation Orders
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# FY03 – FY12 MMR Agency Performance Indicators
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# Risk Based Inspections (RBIS)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# DOF: Refund List - Real property Tax
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# Distribution Sites LCR Monitoring Results
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Free Residential at-the-tap Lead and Copper Data
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# DHS Data Dashboard
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Trust Fund Invasions
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# Appeals Closed In 2015
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# 2016-17 Physical Education - PE Instruction - Borough Level
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# 2008-2009 VADIR INCIDENTS
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# 2013-2014 School Quality Reports Results For Elementary, Middle and K-8 Schools
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# IDA Statement Of Credits and Grants - Historical Data
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[28]]
# -------------------
# IFC Advisory Services Projects
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# NYC Jobs
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[25]]
# -------------------
# NYCHA Development Data Book
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[18]]
# -------------------
# Energy and Water Data Disclosure for Local Law 84 2014 (Data for Calendar Year 2013)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# Inspections
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# DOB Certificate Of Occupancy
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Bus Breakdown and Delays
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[18]]
# -------------------
# Water Consumption And Cost (2013 - March 2019)
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[15]]
# -------------------
# Open Parking and Camera Violations
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Parks Inspection Program – Inspections
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[19]]
# -------------------
# BIC Issued Violations
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[13]]
# -------------------
# Housing Maintenance Code Violations
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[29]]
# -------------------
# Emergency Response Incidents
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# DOHMH Indoor Environmental Complaints
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[9]]
# -------------------
# Inspections
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# DOB Job Application Filings
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[85]]
# -------------------
# M/WBE, LBE, and EBE Certified Business List
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[29]]
# -------------------
# DHS Daily Report
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Medallion  Vehicles - Authorized
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[14]]
# -------------------
# Medallion Vehicles - Inactive
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[12]]
# -------------------
# Rodent Inspection
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[18]]
# -------------------
# Taxi Improvement Fund (TIF) Medallion Payments
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# .nyc Domain Registrations
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Encroachments and Defacements
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[19]]
# -------------------
# Recoupment for Damaged City-owned Property
# Score:  1.0
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# New York City Locations Providing Seasonal Flu Vaccinations
# Score:  1.0
# Augmentation: join
# Left Columns: [[5]]
# Right Columns: [[1]]
# -------------------
# Energy Usage From DOE Buildings
# Score:  1.0
# Augmentation: join
# Left Columns: [[6]]
# Right Columns: [[3]]
# -------------------
# Inmate Incidents - Inmate Fights
# Score:  0.9985250741995224
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# 2018 Green Taxi Trip Data
# Score:  0.9918879080973734
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Appeals Filed In 2016
# Score:  0.9911504451971346
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# 2018 For Hire Vehicles Trip Data
# Score:  0.9911504451971346
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Consumer Services Mediated Complaints
# Score:  0.9911504451971346
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# FIFA 2018 game statistics data
# Score:  0.9827586206896551
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Appeals Filed In 2018
# Score:  0.9823008903942692
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# NYC Business Acceleration Businesses Served and Jobs Created
# Score:  0.9823008903942692
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# Inmate Incidents - Slashing and Stabbing
# Score:  0.9741887984916425
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# 2018 Yellow Taxi Trip Data
# Score:  0.9701327525403293
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Appeals Closed In 2018
# Score:  0.9646017807885383
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# Traffic Volume Counts (2012-2013)
# Score:  0.9568965517241379
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Weights, Measures, and Other Tests
# Score:  0.9557522259856729
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Inclusionary Housing Properties
# Score:  0.9482758620689655
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Office of Mediation and Conflict Resolution Cases
# Score:  0.9469026711828076
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Interagency Coordination and Construction Permits Data (MOSYS)
# Score:  0.9380531163799422
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[40]]
# -------------------
# Daily Tasks Park Cleaning Records
# Score:  0.9328908760782706
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[13]]
# -------------------
# Vehicle Classification Counts (2012-2013)
# Score:  0.9310344827586207
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# 2006 - 2012 School Demographics and Accountability Snapshot
# Score:  0.9111111111111111
# Augmentation: join
# Left Columns: [[12]]
# Right Columns: [[7]]
# -------------------
# Daily Inmates In Custody
# Score:  0.9078171374701519
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Sidewalk Café Licenses and Applications
# Score:  0.9026548971684805
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[38]]
# -------------------
# Bid Tabulations
# Score:  0.9026548971684805
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# DOHMH Childcare Center Inspections
# Score:  0.9026548971684805
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[28]]
# -------------------
# Traffic Volume Counts (2014-2018)
# Score:  0.8706896551724138
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Landmarks Violations
# Score:  0.8672566779570188
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[9]]
# -------------------
# Entry Point LCR Monitoring Results
# Score:  0.8584071231541535
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# NYC Citywide Annualized Calendar Sales Update
# Score:  0.8584071231541535
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[20]]
# -------------------
# Medallion Drivers – Passenger Assistance Trained
# Score:  0.8584071231541535
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# Vehicle Classification Counts (2014-2018)
# Score:  0.853448275862069
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Shelter Repair Scorecard
# Score:  0.849557568351288
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# LCR South South Knowledge Exchange Activities
# Score:  0.8448275862068966
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Compliance at-the-tap Lead and Copper Data
# Score:  0.8407080135484226
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# Water and Sewer Permits
# Score:  0.83185856117096
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# Public Dataset Requests
# Score:  0.8318584587455572
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Forestry Inspections
# Score:  0.8266962184438856
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[18]]
# -------------------
# Election District Poll Sites
# Score:  0.8181818181818182
# Augmentation: join
# Left Columns: [[7]]
# Right Columns: [[3]]
# -------------------
# DCA Fines and Fees
# Score:  0.8152655434901845
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[9]]
# -------------------
# Drinking Water Quality Distribution Monitoring Data
# Score:  0.8141593491398263
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Staff Injuries - Class A Injuries
# Score:  0.810103303188513
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Landmarks Complaints
# Score:  0.8053097943369609
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Trade Waste Broker Registrants
# Score:  0.8053097943369609
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[14]]
# -------------------
# Film Permits
# Score:  0.8019912112858864
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# LinkNYC New Site Permit Applications
# Score:  0.7964601371086927
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[19]]
# -------------------
# HOME-STAT Monthly Dashboard
# Score:  0.7964601371086927
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Citywide Cash Assistance Cases
# Score:  0.7964601371086927
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Non-Public School Security Guard Reimbursement Program - Qualified Provider List
# Score:  0.7964601371086927
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# DOB NOW: Safety Boiler
# Score:  0.7964601371086927
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[13]]
# -------------------
# PATH and AFIC Monthly Eligibility Rate
# Score:  0.7876106847312301
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Vehicle Classification Counts (2011-2012)
# Score:  0.7844827586206896
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# HASA Facts
# Score:  0.7787611299283647
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# JobStat
# Score:  0.7787611299283647
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# NYPD Complaint Data Historic
# Score:  0.7787611299283647
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# Payments Received for DCA Fines and Fees
# Score:  0.7570059743713206
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[9]]
# -------------------
# Verified Locations for NYC City-Funded Social Service Contracts (Address Verification)
# Score:  0.7522123630943657
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Love Your Local Business List
# Score:  0.7413793103448276
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Bureau of Fire Prevention - Certificates of Fitness
# Score:  0.7345133559140377
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# 2017 - 2018 Schools NYPD Crime Data Report
# Score:  0.7327586206896551
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Newyork Weather Data around Airport 2016-18
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# NYPD Arrests Data (Historic)
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Parks Trails
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# License Revocations, Suspensions, Surrenders and Reinstatements
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# NYPD Shooting Incident Data (Historic)
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# FHV Base Aggregate Report - Historical
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Parks Special Events
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# TLC New Driver Application Status
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# ny_lga_weather_16_17_18
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# DCA Monthly Compliance Report Date for Process Servers
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Inclusionary Housing Transfers
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# E-Designations: CSV file
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Commissioner's Correspondence
# Score:  0.7256636986857694
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[17]]
# -------------------
# 2015 - 16 School Safety Report
# Score:  0.7155172413793104
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Public Design Commission Monthly Design Review
# Score:  0.7079645890800386
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Street Closures due to construction activities by Intersection
# Score:  0.6987464052524566
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# Appeals Filed In 2015
# Score:  0.6814160270968451
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# Appeals Closed In 2017
# Score:  0.6814159246714424
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# Appeals Filed In 2017
# Score:  0.6814159246714424
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# LinkNYC Kiosk Status (Historical)
# Score:  0.6814159246714424
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[16]]
# -------------------
# Historical IDA Income Statements Data
# Score:  0.6637168150657116
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Historical IDA Balance Sheets Data
# Score:  0.6637168150657116
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# IFC  Statement Of Cumulative Gross Commitments
# Score:  0.6637168150657116
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Over Dimensional Vehicle Permits (ODVP)
# Score:  0.6570796489635625
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# Street Closures due to construction activities by Block
# Score:  0.6544986312381296
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# Brooklyn Bridge Automated Pedestrian Counts Demonstration Project
# Score:  0.6445427796595031
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Proxy Voting Records
# Score:  0.6371681506571153
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[9]]
# -------------------
# Watershed Water Quality Data
# Score:  0.5840709242653256
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Commercial Bicycle Unit Inspections
# Score:  0.5807522387888483
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Published Audit List
# Score:  0.5752212670370574
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# FIFA 2018 game statistics data
# Score:  0.5681818181818182
# Augmentation: join
# Left Columns: [[6]]
# Right Columns: [[3]]
# -------------------
# Statistical Summary Period Attendance Reporting (PAR)
# Score:  0.5664766248574686
# Augmentation: join
# Left Columns: [[11]]
# Right Columns: [[9]]
# -------------------
# Traffic Volume Counts (2011-2012)
# Score:  0.5603448275862069
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Street Name Signs Work Orders
# Score:  0.5575222598567294
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Verified Locations for NYC City-Funded Social Service Contracts FY2018 (Contract)
# Score:  0.5398231502509986
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# Traffic Volume Counts (2014-2018)
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# NYPD Criminal Court Summons (Historic)
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# 2016 - 2017 School Quality Report Results for D75 Schools
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[26]]
# -------------------
# 2015 - 2016 School Quality Report Results for D75 Schools
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[21]]
# -------------------
# Bike Share Inspections
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# NYC Dog Licensing Dataset
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[14]]
# -------------------
# DSNY Salt Usage
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# 2015-2018 Historical Daily Attendance By School
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# 2014 - 2015 School Quality Report Results for D75 Schools
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[15]]
# -------------------
# Incidents Responded to by Fire Companies
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# Cash Assistance Recipients Since 1955
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Automated External Defibrillator (AED) Inventory
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Historical Medallion Drivers – Passenger Assistance Trained 2017
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# IEG World Bank Project Performance Ratings
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[17]]
# -------------------
# Harbor Water Quality
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# NYS Retail Food Store Inspections, Current Ratings
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# 2005 - 2018 Quality Review Ratings
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Electric Consumption And Cost (2010 - March 2019)
# Score:  0.5221238357944621
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[15]]
# -------------------
# Anticipated RFP
# Score:  0.5132744858424023
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Current RFP
# Score:  0.5132744858424023
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# Address Assignments
# Score:  0.5
# Augmentation: join
# Left Columns: [[13]]
# Right Columns: [[9]]
# -------------------
# 1995 Street Tree Census
# Score:  0.5
# Augmentation: join
# Left Columns: [[13]]
# Right Columns: [[15]]
# -------------------
# Rooftop Drinking Water Tank Inspection Results
# Score:  0.47787616420553786
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[12]]
# -------------------
# Expense Financial Plan - Exec
# Score:  0.47787616420553786
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# 2017 NYC Open Data Plan - List of Datasets Removed
# Score:  0.47787616420553786
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Newsrack Inspections
# Score:  0.47787616420553786
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[14]]
# -------------------
# World Bank Guarantees since FY2016
# Score:  0.47787616420553786
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# Active Projects - Infrastructure
# Score:  0.4336283901912108
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# DOB Cellular Antenna Filings
# Score:  0.4247787329629426
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[54]]
# -------------------
# Active Projects - Public Buildings
# Score:  0.4070797257826146
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# SBS ICAP Contract Opportunities - Historical
# Score:  0.3750000896222275
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[14]]
# -------------------
# DCAS Managed Building Energy Usage
# Score:  0.36363636363636365
# Augmentation: join
# Left Columns: [[7]]
# Right Columns: [[6]]
# -------------------
# DCAS Managed Building Fuel Usage
# Score:  0.36363636363636365
# Augmentation: join
# Left Columns: [[7]]
# Right Columns: [[6]]
# -------------------
# NYC Open Data Plan - Scheduled Releases 2016
# Score:  0.3274337325568259
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# 2016 NYC Open Data Plan
# Score:  0.3274337325568259
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# NYC Weather Data 2010-2018
# Score:  0.31858407532855765
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Historical Medallion Drivers – Passenger Assistance Trained 2014-2016
# Score:  0.3097345205256922
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# Enrollment Capacity And Utilization Reports - Target by Building
# Score:  0.3076923076923077
# Augmentation: join
# Left Columns: [[6]]
# Right Columns: [[11]]
# -------------------
# NYC Hourly Weather Data 2010-2018
# Score:  0.3045722802240207
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Revenue Budget & Financial Plan -- Exec\Adpt\Prel
# Score:  0.30088506814822963
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# City-owned and Leased Property (Local Law 48 of 2011)
# Score:  0.30000000000000004
# Augmentation: join
# Left Columns: [[11]]
# Right Columns: [[49]]
# -------------------
# Urban Park Ranger Animal Condition Response
# Score:  0.2887169302942897
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Quarterly Bond Update: Variable Bond Outstanding
# Score:  0.2743364037396334
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# Mayor’s Office of Operations: Demographic Survey
# Score:  0.2743363013142306
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[5]]
# -------------------
# 2018-2019 Daily Attendance
# Score:  0.2743363013142306
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# 2018 Open Data Plan: Future Releases
# Score:  0.2743363013142306
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Routes
# Score:  0.2743363013142306
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Asbestos Control Program (ACP7)
# Score:  0.2743363013142306
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[1]]
# -------------------
# Active Projects Under Construction
# Score:  0.21238952011957551
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[20]]
# -------------------
# "Kids In Motion" Playground Programming
# Score:  0.2035398628913073
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[3]]
# -------------------
# Speculation Watch List
# Score:  0.2035398628913073
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[10]]
# -------------------
# Swimming Beach Attendance
# Score:  0.2035398628913073
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# 2018 Open Data Plan: Removed Datasets
# Score:  0.2035398628913073
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Local Law 7-2018 Qualified Transactions
# Score:  0.2035398628913073
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[10]]
# -------------------
# Summer Sports Experience
# Score:  0.2035398628913073
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# 2017 NYC Open Data Plan - Scheduled Releases
# Score:  0.2035398628913073
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[4]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of City Meals on Wheels Administration Contracted Providers
# Score:  0.19469030808844187
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of Elderly Abuse and Crime Prevention Contracted Providers
# Score:  0.19469030808844187
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of Home Delivered Meals Contracted Providers
# Score:  0.19469030808844187
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# IDNYC Locations
# Score:  0.1896551724137931
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Scorecard Ratings
# Score:  0.18584075328557648
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# FY16 BID Trends Report Data
# Score:  0.18181818181818185
# Augmentation: join
# Left Columns: [[7]]
# Right Columns: [[1]]
# -------------------
# Mobile Telecommunication Franchise Poletop Installation Locations
# Score:  0.16814164367984563
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[18]]
# -------------------
# NYC Quarterly Bond Update: General Obligation, DASNY, and the NYCMW Rate Exchange Agreements
# Score:  0.1415929792712494
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Earthquake Data of Turkey in 1910-2017
# Score:  0.13999999999999993
# Augmentation: join
# Left Columns: [[12]]
# Right Columns: [[9]]
# -------------------
# NYC Free Tax Prep Sites
# Score:  0.132743424468384
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[26]]
# -------------------
# Application for State Aid
# Score:  0.11504431486265317
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# Board of Standards and Appeals (BSA) Applications Status
# Score:  0.1
# Augmentation: union
# Left Columns: [[2], [7]]
# Right Columns: [[12], [7]]
# -------------------
# Parks Inspection Program – Inspections
# Score:  0.1
# Augmentation: union
# Left Columns: [[2], [16]]
# Right Columns: [[5], [4]]
# -------------------
# Directory Of Business Improvement Districts
# Score:  0.09090909090909091
# Augmentation: join
# Left Columns: [[7]]
# Right Columns: [[16]]
# -------------------
# FIFA 2018 game statistics data
# Score:  0.08125
# Augmentation: union
# Left Columns: [[1], [6]]
# Right Columns: [[0], [3]]
# -------------------
# Outdoor Swimming Pool Attendance
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of Geriatric Mental Health Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of Case Management Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of Home Delivered Meals Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of Senior Center Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of Senior Center Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of Geriatric Mental Health Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of Homecare Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of NORC Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of Transportation Services Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of Home Care Agency Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of Elderly Abuse and Prevention Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of NY Connects Services Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of Transportation Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of City Meals on Wheels Administration Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of Case Management Agency Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of NY Connects Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of Care Giver Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of Legal Services Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Service Units by Month of Legal Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of Caregiver Resources Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Department for the Aging (DFTA) Reported Line Item Expenditures by Month of NORC Services Contracted Providers
# Score:  0.07964609565119152
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Buildings by Borough and Community District
# Score:  0.06194698604546069
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Individual Census by Borough, Community District, and Facility Type
# Score:  0.06194698604546069
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Associated Address by Borough and Community District
# Score:  0.06194698604546069
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Education & Wildlife Programs
# Score:  0.03539832163686446
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[2]]
# -------------------
# Property Valuation and Assessment Data Tax Class 1
# Score:  0.03409090909090909
# Augmentation: join
# Left Columns: [[7]]
# Right Columns: [[95]]
# -------------------
# Personal Income By AGI Range
# Score:  0.023255813953488372
# Augmentation: join
# Left Columns: [[5]]
# Right Columns: [[5]]
# -------------------
# Denied TW and Wholesale Market Companies
# Score:  0.017699212031133636
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# Enrollment Capacity And Utilization Reports - Target by Organization
# Score:  0.008849657228268222
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[12]]
# -------------------
# Enrollment Capacity And Utilization Reports - Target by Building
# Score:  0.008849657228268222
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[15]]
# -------------------
# DOE Building Space Usage
# Score:  0.008849657228268222
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[7]]
# -------------------
# Transportable Classroom Units- Buildings Only
# Score:  0.008849657228268222
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[16]]
# -------------------
# NYC Office of The Comptroller: Board of Education Retirement System (BERS) Holdings Data
# Score:  1.0242540281094227e-07
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[18]]
# -------------------
# Update to Submitted State Aid Projects
# Score:  1.0242540281094227e-07
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[6]]
# -------------------
# Transportable Classroom Units- Buildings & Schools
# Score:  1.0242540281094227e-07
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[8]]
# -------------------
# Youth Engagement Summary
# Score:  1.0242540281094227e-07
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------
# Youth Engagement By Category
# Score:  1.0242540281094227e-07
# Augmentation: join
# Left Columns: [[2]]
# Right Columns: [[0]]
# -------------------

# %% [markdown]
# The first dataset seems relevant: it has a score 1.0 for join, and it also represents a FIFA dataset.

# %% [markdown]
# It is also possible to specify which column will be used for augmentation.

# %%
url = 'https://datamart.d3m.vida-nyu.org/search'
data = fifa_manofmatch_dir + 'tables/learningData.csv'
query={
    'variables': [
        {
            'type': 'tabular_variable',
            'columns': [1],  # GameID
            'relationship': 'contains'
        }
    ]
}

# http://docs.python-requests.org/en/latest/user/quickstart/#post-a-multipart-encoded-file
with open(data, 'rb') as data_p:
    response = requests.post(
        url,
        files={
            'data': data_p,
            'query': ('query.json', json.dumps(query), 'application/json'),
        }
    )
response.raise_for_status()
gameID_results = response.json()['results']

# %%
print_results(gameID_results)
# Out:
# FIFA 2018 game statistics data
# Score:  0.9827586206896551
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Traffic Volume Counts (2012-2013)
# Score:  0.9568965517241379
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Inclusionary Housing Properties
# Score:  0.9482758620689655
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Vehicle Classification Counts (2012-2013)
# Score:  0.9310344827586207
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Traffic Volume Counts (2014-2018)
# Score:  0.8706896551724138
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Vehicle Classification Counts (2014-2018)
# Score:  0.853448275862069
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# LCR South South Knowledge Exchange Activities
# Score:  0.8448275862068966
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Vehicle Classification Counts (2011-2012)
# Score:  0.7844827586206896
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Love Your Local Business List
# Score:  0.7413793103448276
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# 2017 - 2018 Schools NYPD Crime Data Report
# Score:  0.7327586206896551
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# 2015 - 16 School Safety Report
# Score:  0.7155172413793104
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# Traffic Volume Counts (2011-2012)
# Score:  0.5603448275862069
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------
# IDNYC Locations
# Score:  0.1896551724137931
# Augmentation: join
# Left Columns: [[1]]
# Right Columns: [[0]]
# -------------------

# %% [markdown]
# ### Augmenting a Dataset

# %% [markdown]
# Let's try to do our augmentation for the previous first query result then.

# %%
url = 'https://datamart.d3m.vida-nyu.org/augment'
data = fifa_manofmatch_dir + 'tables/learningData.csv'
task = gameID_results[0]

# http://docs.python-requests.org/en/latest/user/quickstart/#post-a-multipart-encoded-file
with open(data, 'rb') as data_p:
    response = requests.post(
        url,
        files={
            'data': data_p,
            'task': ('task.json', json.dumps(task), 'application/json'),
        },
        stream=True,
    )
response.raise_for_status()
zip_ = zipfile.ZipFile(BytesIO(response.content), 'r')
learning_data = pd.read_csv(zip_.open('tables/learningData.csv'))
dataset_doc = json.load(zip_.open('datasetDoc.json'))
zip_.close()

# %%
learning_data.head()
# Out:
#    d3mIndex  GameID        Date     Team        Opponent  Ball Possession %  \
# 0         0      55  2018-06-23   Mexico  Korea Republic                 59
# 1         1      40  2018-06-21  Denmark       Australia                 49
# 2         2      19  2018-06-17   Mexico         Germany                 40
# 3         3      31  2018-06-19  Senegal          Poland                 43
# 4         4      98  2018-06-30  Uruguay        Portugal                 39
#
#    Off-Target  Blocked  Offsides  Saves      ...        Own goals  \
# 0           6        2         0      5      ...              NaN
# 1           5        0         1      4      ...              NaN
# 2           6        2         2      9      ...              NaN
# 3           4        2         3      3      ...              NaN
# 4           2        1         0      4      ...              NaN
#
#    Goal Scored  Attempts  On-Target  Corners  Free Kicks Fouls Committed  \
# 0            2        13          5        5          24               7
# 1            1        10          5        3           5               7
# 2            1        12          4        1          11              15
# 3            2         8          2        3          11              15
# 4            2         6          3        2          14              13
#
#   Yellow Card  Red  Own goal Time
# 0           0    0            NaN
# 1           2    0            NaN
# 2           2    0            NaN
# 3           2    0            NaN
# 4           0    0            NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# And we have our augmented data! Its corresponding datasetDoc JSON object is presented below.
#
# However, note that this datasetDoc JSON **does not** preserve the information from the supplied data's datasetDoc JSON. You need to use the Python DataMart API for that: https://gitlab.com/datadrivendiscovery/datamart-api/blob/master/datamart.py

# %%
pprint(dataset_doc, indent=2)
# Out:
# { 'about': { 'approximateSize': '59300 B',
#              'datasetID': '521ea6d741e94a61bdbe9c69b7bb7a38',
#              'datasetName': '521ea6d741e94a61bdbe9c69b7bb7a38',
#              'datasetSchemaVersion': '3.2.0',
#              'datasetVersion': '0.0',
#              'license': 'unknown',
#              'redacted': False},
#   'dataResources': [ { 'columns': [ { 'colIndex': 0,
#                                       'colName': 'd3mIndex',
#                                       'colType': 'integer',
#                                       'role': ['index']},
#                                     { 'colIndex': 1,
#                                       'colName': 'GameID',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 2,
#                                       'colName': 'Date',
#                                       'colType': 'dateTime',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 3,
#                                       'colName': 'Team',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 4,
#                                       'colName': 'Opponent',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 5,
#                                       'colName': 'Ball Possession %',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 6,
#                                       'colName': 'Off-Target',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 7,
#                                       'colName': 'Blocked',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 8,
#                                       'colName': 'Offsides',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 9,
#                                       'colName': 'Saves',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 10,
#                                       'colName': 'Pass Accuracy %',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 11,
#                                       'colName': 'Passes',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 12,
#                                       'colName': 'Distance Covered (Kms)',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 13,
#                                       'colName': 'Yellow & Red',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 14,
#                                       'colName': 'Man of the Match',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 15,
#                                       'colName': '1st Goal',
#                                       'colType': 'real',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 16,
#                                       'colName': 'Round',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 17,
#                                       'colName': 'PSO',
#                                       'colType': 'string',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 18,
#                                       'colName': 'Goals in PSO',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 19,
#                                       'colName': 'Own goals',
#                                       'colType': 'real',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 20,
#                                       'colName': 'Goal Scored',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 21,
#                                       'colName': 'Attempts',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 22,
#                                       'colName': 'On-Target',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 23,
#                                       'colName': 'Corners',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 24,
#                                       'colName': 'Free Kicks',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 25,
#                                       'colName': 'Fouls Committed',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 26,
#                                       'colName': 'Yellow Card',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 27,
#                                       'colName': 'Red',
#                                       'colType': 'integer',
#                                       'role': ['attribute']},
#                                     { 'colIndex': 28,
#                                       'colName': 'Own goal Time',
#                                       'colType': 'real',
#                                       'role': ['attribute']}],
#                        'isCollection': False,
#                        'resFormat': ['text/csv'],
#                        'resID': 'learningData',
#                        'resPath': 'tables/learningData.csv',
#                        'resType': 'table'}],
#   'qualities': [ { 'qualName': 'augmentation_info',
#                    'qualValue': { 'augmentation_type': 'join',
#                                   'nb_rows_after': 128,
#                                   'nb_rows_before': 128,
#                                   'new_columns': [ 'Own goal Time',
#                                                    'Red',
#                                                    'Attempts',
#                                                    'Yellow Card',
#                                                    'On-Target',
#                                                    'Corners',
#                                                    'Fouls Committed',
#                                                    'Goal Scored',
#                                                    'Free Kicks'],
#                                   'removed_columns': []},
#                    'qualValueType': 'dict'}]}

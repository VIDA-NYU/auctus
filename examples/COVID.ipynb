# %%
import io
import json
import pandas
from pprint import pprint
import requests
import zipfile

# %%
# Pretty-print results
def print_results(results):
    if not results:
        return
    for result in results:
        print(result['metadata']['name'])
        print('ID: ', result['id'])
        print('Score: ', result['score'])
        # Print augmentation information if provided
        if 'augmentation' in result and result['augmentation']['type'] != 'none':
            aug_type = result['augmentation']['type']
            print('Augmentation: %s' % aug_type)
            print("Left Columns: %s" %
                  str(result['augmentation']['left_columns_names']))
            print("Right Columns: %s" %
                  str(result['augmentation']['right_columns_names']))
            
        print("-------------------")

# %%
URL = 'https://auctus.vida-nyu.org/api/v1'

# %%
# REST API documentation: https://docs.auctus.vida-nyu.org/restapi.html
# Query and result schemas: https://docs.auctus.vida-nyu.org/schemas.html

# %%
# Search for COVID data via keywords
query = {
    'keywords': ['covid'],
}
response = requests.post(URL + '/search', data={'query': json.dumps(query)})
response.raise_for_status()
results = response.json()['results']
print_results(results)
# Out:
# covid per country
# ID:  datamart.url.2e70cba96c4944198f174780b4eb382c
# Score:  15.932485
# -------------------
# COVID Tracking Data (CSV) - USA States Daily
# ID:  datamart.url.8eac7911c2cb5da0b763f3d3f86a13b8
# Score:  14.701933
# -------------------
# NYC Coronavirus (COVID-19) data
# ID:  datamart.url.9a47f900c06943ecb731d6213a5b883c
# Score:  13.658955
# -------------------
# COVID-19 Hospitalizations
# ID:  datamart.socrata.data-sfgov-org.nxjg-bhem
# Score:  13.390009
# -------------------
# COVID-19 Cases Summarized by Race and Ethnicity
# ID:  datamart.socrata.data-sfgov-org.vqqm-nsqg
# Score:  13.261738
# -------------------
# NYC Coronavirus (COVID-19) from NYC Department of Health
# ID:  datamart.url.7717c2dd7eac420eb8aa85224388a9f6
# Score:  13.029905
# -------------------
# COVID-19 Tests
# ID:  datamart.socrata.data-sfgov-org.nfpa-mg4g
# Score:  12.92869
# -------------------
# COVID-19 Cases Summarized by Age Group and Gender
# ID:  datamart.socrata.data-sfgov-org.sunc-2t3k
# Score:  12.534885
# -------------------
# COVID-19 Cases Summarized by Date, Transmission and Case Disposition
# ID:  datamart.socrata.data-sfgov-org.tvq9-ec9w
# Score:  12.432392
# -------------------
# Washington State Public Library Services Affected by COVID-19
# ID:  datamart.socrata.data-wa-gov.6iab-kcxu
# Score:  12.347805
# -------------------
# covid
# ID:  datamart.url.e8ad58ccedbd437b96f4a36de3f4f8a7
# Score:  8.486753
# -------------------
# Nonpharmaceutical Interventions (NPIs) by Jataware - by city
# ID:  datamart.upload.86a1bc1c58ad4814847454b3644dd6cb
# Score:  8.187912
# -------------------
# Nonpharmaceutical Interventions (NPIs) by Jataware - by city
# ID:  datamart.upload.488278046c6c4d9eb2ac2e417b324d47
# Score:  8.187912
# -------------------
# Location for summaries and analysis of data related to n-CoV 2019, first reported in Wuhan, China
# ID:  datamart.url.c35c7e216617536eaa11e5c19a171e66
# Score:  7.2269483
# -------------------
# Coronavirus dataset
# ID:  datamart.url.279d869fd0b5593d970b85de233fdf7f
# Score:  6.5020266
# -------------------
# NYTimes-Covid19-US-counties
# ID:  datamart.url.6290ade22c615ed78c691a20abd43efd
# Score:  5.52204
# -------------------
# Novel Coronavirus (COVID-19) Cases Confirmed, US, provided by JHU CSSE
# ID:  datamart.url.1151967bde695874aad1c1a4ad2d17ff
# Score:  4.3267946
# -------------------
# Novel Coronavirus (COVID-19) Cases Confirmed, Global, provided by JHU CSSE
# ID:  datamart.url.2c01b1f81d655c85a55e5dfeb2f6d9f8
# Score:  4.3267946
# -------------------
# Novel Coronavirus (COVID-19) Cases Recovered, Global, provided by JHU CSSE
# ID:  datamart.url.2698d783449c540090e114c5eb303fe7
# Score:  4.3267946
# -------------------
# Novel Coronavirus (COVID-19) Cases Deaths, US, provided by JHU CSSE
# ID:  datamart.url.466ade356ddd58a2b3108a7a87efc099
# Score:  4.3267946
# -------------------
# Novel Coronavirus (COVID-19) Cases Deaths, Global, provided by JHU CSSE
# ID:  datamart.url.895ba633167a59c9b8db07858d427a86
# Score:  4.3267946
# -------------------
# NYTimes-Covid19-US-states
# ID:  datamart.url.61af1b9a11805beea1150aaf085c8423
# Score:  3.5615587
# -------------------

# %%
# Show the full metadata record for one dataset
result, = [r for r in results if r['id'] == 'datamart.upload.86a1bc1c58ad4814847454b3644dd6cb']
print(json.dumps(result, indent=2))
# Out:
# {
#   "id": "datamart.upload.86a1bc1c58ad4814847454b3644dd6cb",
#   "score": 8.187912,
#   "metadata": {
#     "columns": [
#       {
#         "name": "city",
#         "num_distinct_values": 429,
#         "semantic_types": [],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "state",
#         "num_distinct_values": 19,
#         "plot": {
#           "data": [
#             {
#               "bin": "AK",
#               "count": 3
#             },
#             {
#               "bin": "CT",
#               "count": 4
#             },
#             {
#               "bin": "DE",
#               "count": 4
#             },
#             {
#               "bin": "KY",
#               "count": 5
#             },
#             {
#               "bin": "ME",
#               "count": 3
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "coverage": [
#           {
#             "range": {
#               "gte": 1584835200.0,
#               "lte": 1585470592.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1583205504.0,
#               "lte": 1583972736.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1584115840.0,
#               "lte": 1584702592.0
#             }
#           }
#         ],
#         "mean": 1584586043.5116882,
#         "missing_values_ratio": 0.3100358422939068,
#         "name": "publish_date",
#         "num_distinct_values": 200,
#         "plot": {
#           "data": [
#             {
#               "count": 13,
#               "date_end": "2020-03-05T16:59:44",
#               "date_start": "2020-03-03T00:00:00"
#             },
#             {
#               "count": 5,
#               "date_end": "2020-03-08T10:01:36",
#               "date_start": "2020-03-05T16:59:44"
#             },
#             {
#               "count": 7,
#               "date_end": "2020-03-11T03:01:20",
#               "date_start": "2020-03-08T10:01:36"
#             },
#             {
#               "count": 31,
#               "date_end": "2020-03-13T20:01:04",
#               "date_start": "2020-03-11T03:01:20"
#             },
#             {
#               "count": 58,
#               "date_end": "2020-03-16T13:02:56",
#               "date_start": "2020-03-13T20:01:04"
#             },
#             {
#               "count": 117,
#               "date_end": "2020-03-19T06:02:40",
#               "date_start": "2020-03-16T13:02:56"
#             },
#             {
#               "count": 31,
#               "date_end": "2020-03-21T23:02:24",
#               "date_start": "2020-03-19T06:02:40"
#             },
#             {
#               "count": 39,
#               "date_end": "2020-03-24T16:02:08",
#               "date_start": "2020-03-21T23:02:24"
#             },
#             {
#               "count": 43,
#               "date_end": "2020-03-27T09:04:00",
#               "date_start": "2020-03-24T16:02:08"
#             },
#             {
#               "count": 41,
#               "date_end": "2020-03-30T02:03:44",
#               "date_start": "2020-03-27T09:04:00"
#             }
#           ],
#           "type": "histogram_temporal"
#         },
#         "semantic_types": [
#           "http://schema.org/DateTime"
#         ],
#         "stddev": 513767.26253528317,
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "url",
#         "num_distinct_values": 493,
#         "semantic_types": [],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "title",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "text",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "category",
#         "num_distinct_values": 9,
#         "plot": {
#           "data": [
#             {
#               "bin": "cases",
#               "count": 1
#             },
#             {
#               "bin": "lockdown",
#               "count": 10
#             },
#             {
#               "bin": "quarantine",
#               "count": 8
#             },
#             {
#               "bin": "school_business_closure",
#               "count": 4
#             },
#             {
#               "bin": "social_distance",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "coverage": [
#           {
#             "range": {
#               "gte": 178.0,
#               "lte": 146758.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1854698.0,
#               "lte": 2084749.0
#             }
#           },
#           {
#             "range": {
#               "gte": 280082.0,
#               "lte": 1011696.0
#             }
#           }
#         ],
#         "mean": 54504.0376344086,
#         "name": "population",
#         "plot": {
#           "data": [
#             {
#               "bin_end": 208474.9,
#               "bin_start": 0.0,
#               "count": 530
#             },
#             {
#               "bin_end": 416949.8,
#               "bin_start": 208474.9,
#               "count": 18
#             },
#             {
#               "bin_end": 625424.7,
#               "bin_start": 416949.8,
#               "count": 2
#             },
#             {
#               "bin_end": 833899.6,
#               "bin_start": 625424.7,
#               "count": 5
#             },
#             {
#               "bin_end": 1042374.5,
#               "bin_start": 833899.6,
#               "count": 1
#             },
#             {
#               "bin_end": 1250849.4,
#               "bin_start": 1042374.5,
#               "count": 0
#             },
#             {
#               "bin_end": 1459324.3,
#               "bin_start": 1250849.4,
#               "count": 0
#             },
#             {
#               "bin_end": 1667799.2,
#               "bin_start": 1459324.3,
#               "count": 0
#             },
#             {
#               "bin_end": 1876274.0999999999,
#               "bin_start": 1667799.2,
#               "count": 1
#             },
#             {
#               "bin_end": 2084749.0,
#               "bin_start": 1876274.0999999999,
#               "count": 1
#             }
#           ],
#           "type": "histogram_numerical"
#         },
#         "semantic_types": [],
#         "stddev": 154148.1766282727,
#         "structural_type": "http://schema.org/Integer"
#       },
#       {
#         "mean": 36.94463136200716,
#         "name": "latitude",
#         "plot": {
#           "data": [
#             {
#               "bin_end": 28.8163,
#               "bin_start": 24.5637,
#               "count": 25
#             },
#             {
#               "bin_end": 33.0689,
#               "bin_start": 28.8163,
#               "count": 72
#             },
#             {
#               "bin_end": 37.3215,
#               "bin_start": 33.0689,
#               "count": 146
#             },
#             {
#               "bin_end": 41.5741,
#               "bin_start": 37.3215,
#               "count": 258
#             },
#             {
#               "bin_end": 45.8267,
#               "bin_start": 41.5741,
#               "count": 52
#             },
#             {
#               "bin_end": 50.079299999999996,
#               "bin_start": 45.8267,
#               "count": 2
#             },
#             {
#               "bin_end": 54.33189999999999,
#               "bin_start": 50.079299999999996,
#               "count": 0
#             },
#             {
#               "bin_end": 58.58449999999999,
#               "bin_start": 54.33189999999999,
#               "count": 0
#             },
#             {
#               "bin_end": 62.83709999999999,
#               "bin_start": 58.58449999999999,
#               "count": 1
#             },
#             {
#               "bin_end": 67.0897,
#               "bin_start": 62.83709999999999,
#               "count": 2
#             }
#           ],
#           "type": "histogram_numerical"
#         },
#         "semantic_types": [
#           "http://schema.org/latitude"
#         ],
#         "stddev": 4.592741270022868,
#         "structural_type": "http://schema.org/Float"
#       },
#       {
#         "mean": -98.0607971326166,
#         "name": "longitude",
#         "plot": {
#           "data": [
#             {
#               "bin_end": -148.934,
#               "bin_start": -157.8725,
#               "count": 1
#             },
#             {
#               "bin_end": -139.9955,
#               "bin_start": -148.934,
#               "count": 2
#             },
#             {
#               "bin_end": -131.057,
#               "bin_start": -139.9955,
#               "count": 0
#             },
#             {
#               "bin_end": -122.1185,
#               "bin_start": -131.057,
#               "count": 28
#             },
#             {
#               "bin_end": -113.17999999999999,
#               "bin_start": -122.1185,
#               "count": 122
#             },
#             {
#               "bin_end": -104.2415,
#               "bin_start": -113.17999999999999,
#               "count": 54
#             },
#             {
#               "bin_end": -95.303,
#               "bin_start": -104.2415,
#               "count": 19
#             },
#             {
#               "bin_end": -86.36449999999999,
#               "bin_start": -95.303,
#               "count": 165
#             },
#             {
#               "bin_end": -77.42599999999999,
#               "bin_start": -86.36449999999999,
#               "count": 151
#             },
#             {
#               "bin_end": -68.4875,
#               "bin_start": -77.42599999999999,
#               "count": 16
#             }
#           ],
#           "type": "histogram_numerical"
#         },
#         "semantic_types": [
#           "http://schema.org/longitude"
#         ],
#         "stddev": 15.837849701298603,
#         "structural_type": "http://schema.org/Float"
#       }
#     ],
#     "date": "2020-04-09T18:36:50.958540Z",
#     "description": "\"Nonpharmaceutical Interventions,\r\n or NPIs, are policy actions taken by communities to mitigate ...",
#     "filename": "Jataware-City-NPIs.csv",
#     "id": "datamart.upload.86a1bc1c58ad4814847454b3644dd6cb",
#     "materialize": {
#       "date": "2020-04-09T18:36:38.507936Z",
#       "identifier": "datamart.upload"
#     },
#     "name": "Nonpharmaceutical Interventions (NPIs) by Jataware - by city",
#     "nb_profiled_rows": 558,
#     "nb_rows": 558,
#     "sample": "city,state,publish_date,url,title,text,category,population,latitude,longitude\nArcadia,CA,3/21/20 17:49,https://abc7.com/6035930,Coronavirus: Arcadia neighborhood outraged over Edison's planned power outage amid stay-at-home orders,EMBED >More News Videos Members of President Donald Trump's economic team convene Friday on Capitol Hill to launch negotiations with...,shelter_in_place,58799,34.1342,-118.0373\nCarson,CA,,https://www.nevadaappeal.com/news/carson-city-declares-state-of-emergency-due-to-coronavirus/,Carson City declares State of Emergency due to coronavirus,\"Aerial View of Carson City, Nevada looking north.\n\nGetty\n\nA message from Carson City Public Works: As we all closely monitor the rapidly...\",state_of_emergency,92735,33.8374,-118.2559\nYuba City,CA,,https://www.appeal-democrat.com/news/urgent/yuba-city-declares-local-emergency-due-to-coronavirus/article_6fd64f4c-6d79-11ea-a3d0-7f88fd6...,Yuba City declares local emergency due to coronavirus,\"Marysville, CA (95901)\n\nToday\n\nCloudy skies this morning will become partly cloudy this afternoon. High 62F. Winds SSE at 5 to 10...\",state_of_emergency,120186,39.1357,-121.6381\nGlendale,CO,3/20/20 0:00,https://www.latimes.com/socal/glendale-news-press/news/story/2020-03-20/tn-gnp-me-glendale-follows-safer-at-home-order,\"Coronavirus: Glendale follows L.A. County\u2019s \u2018Safer at Home\u2019 order, requiring the closure of more businesses\",\"For at least the next month, Glendale residents have been ordered to stay at home and leave only for essential needs, following a...\",shelter_in_place,5158,39.7036,-104.9352\nBoca Raton,FL,3/17/20 19:25,https://www.bocamag.com/coronavirus-boca-state-of-emergency/,Coronavirus: City of Boca Raton Declares State of Emergency,The City of Boca Raton has declared a local state of emergency in response to the ongoing coronavirus pandemic. A new set of mandatory...,state_of_emergency,98150,26.3749,-80.1077\nCoconut Creek,FL,3/21/20 0:00,https://miami.cbslocal.com/2020/03/21/coronavirus-prompts-coconut-creek-to-enact-nightly-curfew/,Coronavirus Prompts Coconut Creek To Enact Nightly Curfew,\"\n\n\n\nFORT LAUDERDALE (CBSMiami) \u2013 Due to the coronavirus pandemic, the City of Coconut Creek is joining a handful of other cities in...\",lockdown,61010,26.2802,-80.1842\nNorth Port,FL,3/17/20 0:00,https://www.heraldtribune.com/news/20200317/coronavirus-florida-north-port-declares-state-of-emergency,Coronavirus Florida: North Port declares state of emergency,\"Commissioners looking into receiving public comment electronically and hosting virtual meetings.\n\nThis content is being provided for...\",state_of_emergency,195992,27.0577,-82.1975\nHoward,GA,3/14/20 10:11,https://www.msgr.com/article/putnam-county-sheriff-howard-sills-issues-statement-coronavirus-after-president-issues,Putnam County Sheriff Howard Sills issues statement on Coronavirus after President issues national emergency,\"Putnam County Sheriff Howard Sills releases statement after national emergency issued due to Coronavirus pandemic\n\n-- No test kits...\",state_of_emergency,0,32.5982,-84.3786\nNorcross,GA,,https://www.ajc.com/news/local/norcross-declares-state-emergency-due-coronavirus/wfU0yXtBc3tbjjQh2gx1rO/,Norcross declares state of emergency due to coronavirus,\"The city of Norcross has declared a state of emergency due to the coronavirus pandemic.\n\nThere are no known cases within city limits,...\",state_of_emergency,16845,33.9379,-84.2065\nForest Park,IL,3/18/20 0:00,https://www.chicagotribune.com/suburbs/oak-park/ct-oak-mayors-response-covid-19-tl-0326-20200318-tpwctduzjbblra65stygyk3gmy-story.html,\"Oak Park issues shelter-in-place order to slow COVID-19 spread as River Forest, Forest Park leaders urge residents to comply as well\",\"\u201cWe are urging people to stay home and stay out of reach of other people,\u201d Abu-Taleb said. \u201cI\u2019m prepared to order people to shelter in...\",shelter_in_place,13951,41.8683,-87.8157\nMarseilles,I ...
#     "size": 1874173,
#     "source": "upload",
#     "spatial_coverage": [
#       {
#         "lat": "latitude",
#         "lon": "longitude",
#         "ranges": [
#           {
#             "range": {
#               "coordinates": [
#                 [
#                   -122.8651,
#                   41.0803
#                 ],
#                 [
#                   -104.7389,
#                   33.3881
#                 ]
#               ],
#               "type": "envelope"
#             }
#           },
#           {
#             "range": {
#               "coordinates": [
#                 [
#                   -95.5977,
#                   42.3686
#                 ],
#                 [
#                   -75.3104,
#                   37.7171
#                 ]
#               ],
#               "type": "envelope"
#             }
#           },
#           {
#             "range": {
#               "coordinates": [
#                 [
#                   -92.5715,
#                   34.2466
#                 ],
#                 [
#                   -80.1842,
#                   26.1505
#                 ]
#               ],
#               "type": "envelope"
#             }
#           }
#         ]
#       }
#     ],
#     "version": "v0.5.7-16-g0e70d36"
#   },
#   "augmentation": {
#     "type": "none",
#     "left_columns": [],
#     "left_columns_names": [],
#     "right_columns": [],
#     "right_columns_names": []
#   },
#   "supplied_id": null,
#   "supplied_resource_id": null,
#   "d3m_dataset_description": {
#     "about": {
#       "datasetID": "datamart.upload.86a1bc1c58ad4814847454b3644dd6cb",
#       "datasetName": "Nonpharmaceutical Interventions (NPIs) by Jataware - by city",
#       "license": "unknown",
#       "approximateSize": "1874173 B",
#       "datasetSchemaVersion": "4.0.0",
#       "redacted": false,
#       "datasetVersion": "1.0",
#       "description": "\"Nonpharmaceutical Interventions,\r\n or NPIs, are policy actions taken by communities to mitigate ..."
#     },
#     "dataResources": [
#       {
#         "resID": "learningData",
#         "resPath": "tables/learningData.csv",
#         "resType": "table",
#         "resFormat": {
#           "text/csv": [
#             "csv"
#           ]
#         },
#         "isCollection": false,
#         "columns": [
#           {
#             "colIndex": 0,
#             "colName": "city",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 1,
#             "colName": "state",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 2,
#             "colName": "publish_date",
#             "colType": "dateTime",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 3,
#             "colName": "url",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 4,
#             "colName": "title",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 5,
#             "colName": "text",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 6,
#             "colName": "category",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 7,
#             "colName": "population",
#             "colType": "integer",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 8,
#             "colName": "latitude",
#             "colType": "real",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 9,
#             "colName": "longitude",
#             "colType": "real",
#             "role": [
#               "attribute"
#             ]
#           }
#         ]
#       }
#     ]
#   }
# }

# %% [markdown]
# ```json
# {
#   "id": "datamart.upload.86a1bc1c58ad4814847454b3644dd6cb",
#   "score": 8.27132,                             # Score
#   "metadata": {
#     "id": "datamart.upload.86a1bc1c58ad4814847454b3644dd6cb",
#
#                                                 # General information about the dataset
#     "name": "Nonpharmaceutical Interventions (NPIs) by Jataware - by city",
#     "description": "\"Nonpharmaceutical Interventions,\r\n or NPIs, are policy actions taken by communities to mitigate ...",
#     "filename": "Jataware-City-NPIs.csv",
#     "size": 1874173,
#     "nb_rows": 558,
#     "source": "upload",
#
#     "materialize": {                            # Materialization information, e.g. plugin providing this dataset
#       "date": "2020-04-09T18:36:38.507936Z",
#       "identifier": "datamart.upload"
#     },
#     "date": "2020-04-09T18:36:50.958540Z",      # Date and version of profiling
#     "version": "v0.5.7-16-g0e70d36",
#     "nb_profiled_rows": 558,
#     "columns": [                                # Information about each column, profiled automatically
#       {
#         "name": "city",
#         "num_distinct_values": 429,
#         "semantic_types": [],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "state",
#         "structural_type": "http://schema.org/Text",  # String
#         "semantic_types": [
#           "http://schema.org/Enumeration"             # Recognized as categorical data, 19 categories
#         ],
#         "num_distinct_values": 19
#       },
#       {
#         "name": "publish_date",
#         "missing_values_ratio": 0.3100358422939068,   # 31% of missing values
#         "structural_type": "http://schema.org/Text",  # String
#         "semantic_types": [
#           "http://schema.org/DateTime"                # Recognized as dates
#         ],
#         "num_distinct_values": 200,
#         "mean": 1584586043.5116882,                   # Numerical distribution (of the interpreted timestamp)
#         "stddev": 513767.26253528317,
#         "coverage": [
#           {"range": {"gte": 1584835200.0, "lte": 1585470592.0}},
#           {"range": {"gte": 1583205504.0, "lte": 1583972736.0}},
#           {"range": {"gte": 1584115840.0, "lte": 1584702592.0}}
#         ]
#       },
#       {
#         "name": "url",
#         "structural_type": "http://schema.org/Text",  # String with no special meaning for profiler
#         "semantic_types": [],
#         "num_distinct_values": 493
#       },
#       {
#         "name": "title",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ]
#       },
#       {
#         "name": "text",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ]
#       },
#       {
#         "name": "category",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"              # Recognized as categorical data, 9 categories
#         ],
#         "num_distinct_values": 9
#       },
#       {
#         "name": "population",
#         "structural_type": "http://schema.org/Integer",  # Integers
#         "semantic_types": [],
#         "mean": 54504.0376344086,                       # Numerical distribution
#         "stddev": 154148.1766282727,
#         "coverage": [
#           {"range": {"gte": 178.0, "lte": 146758.0}},
#           {"range": {"gte": 1854698.0, "lte": 2084749.0}},
#           {"range": {"gte": 280082.0, "lte": 1011696.0}}
#         ]
#       },
#       {
#         "name": "latitude",
#         "structural_type": "http://schema.org/Float",  # Floating point detected as latitude coordinate
#         "semantic_types": [
#           "http://schema.org/latitude"
#         ],
#         "mean": 36.94463136200716,
#         "stddev": 4.592741270022868
#       },
#       {
#         "name": "longitude",
#         "structural_type": "http://schema.org/Float",  # Floating point detected as longitude coordinate
#         "semantic_types": [
#           "http://schema.org/longitude"
#         ],
#         "mean": -98.0607971326166,
#         "stddev": 15.837849701298603
#       }
#     ],
#     "spatial_coverage": [
#       {
#         "lat": "latitude",          # This is a simple case but the system can pair more complicated
#         "lon": "longitude",         # column names and deal with abbreviations
#         "ranges": [                 # Computed bounding boxes
#           {"range": {"coordinates": [[-122.8651, 41.0803], [-104.7389, 33.3881]], "type": "envelope"}},
#           {"range": {"coordinates": [[-95.5977, 42.3686], [-75.3104, 37.7171]], "type": "envelope"}},
#           {"range": {"coordinates": [[-92.5715, 34.2466], [-80.1842, 26.1505]], "type": "envelope"}}
#         ]
#       }
#     ]
#   },
#   "augmentation": {                   # Augmentation information (if providing an input dataset, see below)
#     "type": "none",
#     "left_columns": [],
#     "left_columns_names": [],
#     "right_columns": [],
#     "right_columns_names": []
#   },
#   "supplied_id": null,
#   "supplied_resource_id": null,
#   "d3m_dataset_description": {...}     # Metadata in D3M format
# }
# ```

# %%
# Let's download the dataset
response = requests.get(URL + '/download/' + result['id'])
response.raise_for_status()
# It's a CSV, load it
pandas.read_csv(io.BytesIO(response.content)).head()
# Out:
#           city state   publish_date  \
# 0  Albertville    AL   3/17/20 0:00
# 1   Birmingham    AL  3/24/20 18:08
# 2         Boaz    AL   3/24/20 0:00
# 3     Carolina    AL   3/27/20 0:00
# 4      Clanton    AL   3/17/20 0:00
#
#                                                  url  \
# 0  https://www.gadsdentimes.com/news/20200317/alb...
# 1  https://www.al.com/news/2020/03/woodfin-propos...
# 2  https://www.gadsdentimes.com/news/20200324/boa...
# 3  https://www.cnbc.com/2020/03/27/north-carolina...
# 4  https://www.clantonadvertiser.com/2020/03/17/j...
#
#                                                title  \
# 0         Albertville declares coronavirus emergency
# 1  Shelter-in-place order enacted in Birmingham t...
# 2        Boaz declares state of emergency over virus
# 3  North Carolina Gov. Roy Cooper orders resident...
# 4  Jemison Council approves COVID-19 response mea...
#
#                                                 text            category  \
# 0  The Albertville City Council on Monday declare...  state_of_emergency
# 1  The Birmingham City Council approved an ordina...    shelter_in_place
# 2  The Boaz City Council on Monday declared a sta...  state_of_emergency
# 3  Governor Roy Cooper, D-NC address the crowd du...    shelter_in_place
# 4  By JOYANNA LOVE/ Senior Staff Writer\n\nThe Ci...                None
#
#    population  latitude  longitude
# 0       37220   34.2634   -86.2107
# 1      744189   33.5277   -86.7987
# 2        9652   34.1985   -86.1529
# 3         295   31.2337   -86.5227
# 4        5876   32.8439   -86.6230

# %%
# Can download in other formats, such as D3M's custom format
response = requests.get(URL + '/download/' + result['id'] + '?format=d3m&format_need_d3mindex=1')
response.raise_for_status()
# D3M format is a directory, so we get a ZIP
zip_ = zipfile.ZipFile(io.BytesIO(response.content), 'r')
print(zip_.namelist())
# Open the CSV
pandas.read_csv(zip_.open('tables/learningData.csv')).head()
# Note that a 'd3mIndex' column was generated, D3M tools require it for machine-learning workflows
# (optional via format options, here 'need_d3mindex')
# Out:
# ['datasetDoc.json', 'tables/learningData.csv']
#    d3mIndex         city state   publish_date  \
# 0         0  Albertville    AL   3/17/20 0:00
# 1         1   Birmingham    AL  3/24/20 18:08
# 2         2         Boaz    AL   3/24/20 0:00
# 3         3     Carolina    AL   3/27/20 0:00
# 4         4      Clanton    AL   3/17/20 0:00
#
#                                                  url  \
# 0  https://www.gadsdentimes.com/news/20200317/alb...
# 1  https://www.al.com/news/2020/03/woodfin-propos...
# 2  https://www.gadsdentimes.com/news/20200324/boa...
# 3  https://www.cnbc.com/2020/03/27/north-carolina...
# 4  https://www.clantonadvertiser.com/2020/03/17/j...
#
#                                                title  \
# 0         Albertville declares coronavirus emergency
# 1  Shelter-in-place order enacted in Birmingham t...
# 2        Boaz declares state of emergency over virus
# 3  North Carolina Gov. Roy Cooper orders resident...
# 4  Jemison Council approves COVID-19 response mea...
#
#                                                 text            category  \
# 0  The Albertville City Council on Monday declare...  state_of_emergency
# 1  The Birmingham City Council approved an ordina...    shelter_in_place
# 2  The Boaz City Council on Monday declared a sta...  state_of_emergency
# 3  Governor Roy Cooper, D-NC address the crowd du...    shelter_in_place
# 4  By JOYANNA LOVE/ Senior Staff Writer\n\nThe Ci...                None
#
#    population  latitude  longitude
# 0       37220   34.2634   -86.2107
# 1      744189   33.5277   -86.7987
# 2        9652   34.1985   -86.1529
# 3         295   31.2337   -86.5227
# 4        5876   32.8439   -86.6230

# %%
# Ask server for datasets related to this result
response = requests.post(URL + '/search', data={'data_id': result['id']})
response.raise_for_status()
results_related = response.json()['results']
print_results(results_related)
# Notice the proposed augmentations (unions or joins)
# Out:
# Parking Signs / Street Space Permit Photos
# ID:  datamart.socrata.data-sfgov-org.pigs-fac7
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['DateAdded']]
# -------------------
# Nonpharmaceutical Interventions (NPIs) by Jataware - by city
# ID:  datamart.upload.488278046c6c4d9eb2ac2e417b324d47
# Score:  0.8
# Augmentation: union
# Left Columns: [['city'], ['url'], ['title'], ['text'], ['state'], ['category'], ['publish_date'], ['population']]
# Right Columns: [['city'], ['url'], ['title'], ['text'], ['state'], ['category'], ['publish_date'], ['population']]
# -------------------
# Office of The Comptroller: Police Retirement System Holdings Data
# ID:  datamart.socrata.data-cityofnewyork-us.dy3p-ay2d
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Maturity Date']]
# -------------------
# Special Vaccine Locations
# ID:  datamart.socrata.data-cityofchicago-org.9a77-69d3
# Score:  0.5
# Augmentation: union
# Left Columns: [['city'], ['url'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['city'], ['url'], ['state'], ['latitude'], ['longitude']]
# -------------------
# [Deprecated] Form 700 Schedule A2
# ID:  datamart.socrata.data-sfgov-org.j82c-uj4d
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date Disposed']]
# -------------------
# San Francisco Department of Public Health Flu Shot Locations 2013
# ID:  datamart.socrata.data-sfgov-org.yg87-cd6v
# Score:  0.5
# Augmentation: union
# Left Columns: [['city'], ['url'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['city'], ['url'], ['state'], ['latitude'], ['longitude']]
# -------------------
# Active Projects - Public Buildings
# ID:  datamart.socrata.data-cityofnewyork-us.g9ub-hrve
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Projected Construction Completion ']]
# -------------------
# Volunteer Opportunities and Finding Organizations
# ID:  datamart.socrata.data-cityofnewyork-us.shpd-5q9m
# Score:  0.5
# Augmentation: union
# Left Columns: [['city'], ['title'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['Title'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Forestry Inspections
# ID:  datamart.socrata.data-cityofnewyork-us.4pt5-3vv4
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['ReinspectionDate']]
# -------------------
# State University of New York (SUNY) Campus Locations with Websites, Enrollment and Select Program Offerings
# ID:  datamart.socrata.data-ny-gov.3cij-nwhw
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude1'], ['Longitude1']]
# -------------------
# Use of ARRA Stimulus Funds
# ID:  datamart.socrata.data-cityofnewyork-us.ivix-m77e
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Contract End Date']]
# -------------------
# New York City Council Discretionary Funding
# ID:  datamart.socrata.data-cityofnewyork-us.4d7f-74pe
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# LinkNYC Kiosk Status (Historical)
# ID:  datamart.socrata.data-cityofnewyork-us.quxm-hmyr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['GENERATED ON']]
# -------------------
# Chicago Public Schools - High School Progress Report (2013-2014)
# ID:  datamart.socrata.data-cityofchicago-org.2m8w-izji
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Multiple Dwelling Registrations
# ID:  datamart.socrata.data-cityofnewyork-us.tesw-yqqr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['RegistrationEndDate']]
# -------------------
# DOB NOW: Build – Job Application Filings
# ID:  datamart.socrata.data-cityofnewyork-us.w9ak-ipjd
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Civil Service List Certification
# ID:  datamart.socrata.data-cityofnewyork-us.a9md-ynri
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Cert Expiration Date']]
# -------------------
# TLC Approved LabCorp Patient Services Drug Test Locations (Dataset)
# ID:  datamart.socrata.data-cityofnewyork-us.pe54-wf39
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Dig Ticket Notifications
# ID:  datamart.socrata.data-cityofchicago-org.cygx-ui4j
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['DIGDATE']]
# -------------------
# Tourism Grants
# ID:  datamart.socrata.data-cityofnewyork-us.rma9-fm39
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Dig Ticket Notifications
# ID:  datamart.socrata.data-cityofchicago-org.cygx-ui4j
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EXPIRATIONDATE']]
# -------------------
# Food Inspections
# ID:  datamart.socrata.data-cityofchicago-org.4ijn-s7e5
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Dig Ticket Notifications
# ID:  datamart.socrata.data-cityofchicago-org.cygx-ui4j
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Notice History (Created)']]
# -------------------
# New York City Council Discretionary Funding (2013)
# ID:  datamart.socrata.data-cityofnewyork-us.q2ni-ztsb
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Dig Ticket Notifications
# ID:  datamart.socrata.data-cityofchicago-org.cygx-ui4j
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['LASTSTATUSTIME']]
# -------------------
# Alternative Fuel Locations
# ID:  datamart.socrata.data-cityofchicago-org.f7f2-ggz5
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Traffic Signal and All-Way Stop Study Requests
# ID:  datamart.socrata.data-cityofnewyork-us.w76s-c5u4
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['ReEvaluationDate']]
# -------------------
# WDFW-Hatcheries
# ID:  datamart.socrata.data-wa-gov.hjdc-v2n4
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Traffic Signal and All-Way Stop Study Requests
# ID:  datamart.socrata.data-cityofnewyork-us.w76s-c5u4
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['TentativeSignalInstallDate']]
# -------------------
# License Applications
# ID:  datamart.socrata.data-cityofnewyork-us.ptev-4hud
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# SFEC Form 3610b - City Officer Behested Payment - Filings
# ID:  datamart.socrata.data-sfgov-org.7vmk-cq9e
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['DateSigned']]
# -------------------
# Chicago Early Learning Programs
# ID:  datamart.socrata.data-cityofchicago-org.ck29-hb9r
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Issued State Facility Air Permits
# ID:  datamart.socrata.data-ny-gov.2wgt-bc53
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EXPIRE DATE']]
# -------------------
# DARP-ROTOW Enrollment Status of Active Tow Truck Companies
# ID:  datamart.socrata.data-cityofnewyork-us.q5u8-89nv
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# World Bank (IBRD) Bonds (1947-Present)
# ID:  datamart.socrata.finances-worldbank-org.3fps-tcuv
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Maturity Date']]
# -------------------
# TLC Driver Education 24 Hour Course Providers (Dataset)
# ID:  datamart.socrata.data-cityofnewyork-us.wzur-rhz9
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Electric Vehicle Population Size History
# ID:  datamart.socrata.data-wa-gov.d886-d5q2
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date']]
# -------------------
# 2003 Campaign Contributions
# ID:  datamart.socrata.data-cityofnewyork-us.s79c-jgrm
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Health Care Provider Credential Data
# ID:  datamart.socrata.data-wa-gov.qxh8-f4bd
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['ExpirationDate']]
# -------------------
# Avenue NYC CFY17-CFY19
# ID:  datamart.socrata.data-cityofnewyork-us.qjvp-rnsx
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Asbestos Control Program (ACP7)
# ID:  datamart.socrata.data-cityofnewyork-us.vq35-j9qm
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['START_DATE']]
# -------------------
# Capital Grant Awards 2014
# ID:  datamart.socrata.data-cityofnewyork-us.9umc-3b2y
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Appeals Filed In 2017
# ID:  datamart.socrata.data-cityofnewyork-us.7xq6-k6zy
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Expiration']]
# -------------------
# Wastewater Treatment Plants
# ID:  datamart.socrata.data-ny-gov.2v6p-juki
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Public Design Commission Monthly Design Review
# ID:  datamart.socrata.data-cityofnewyork-us.tfrc-rjtr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['DATE']]
# -------------------
# Chicago Microlending Institute (CMI) Microloans
# ID:  datamart.socrata.data-cityofchicago-org.dpkg-upyz
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Transportation Department Permits
# ID:  datamart.socrata.data-cityofchicago-org.pubx-yq2d
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['APPLICATIONEXPIREDATE']]
# -------------------
# DYCD Program Sites
# ID:  datamart.socrata.data-cityofnewyork-us.ebkm-iyma
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# L&I Contractor License Data - Insurance
# ID:  datamart.socrata.data-wa-gov.ciwg-agsx
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['CancelDate']]
# -------------------
# Transportation Sites
# ID:  datamart.socrata.data-cityofnewyork-us.hg3c-2jsy
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------

# %%
# Add a keyword filter
query = {
    'keywords': ['coronanet'],
}
response = requests.post(URL + '/search', data={'query': json.dumps(query), 'data_id': result['id']})
response.raise_for_status()
results_related = response.json()['results']
print_results(results_related)
# Out:
# CoronaNet Database BETA Version 1.0 (core)
# ID:  datamart.url.de434a1d1d7342deb13439c02ac39926
# Score:  9.1313925
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['date_announced']]
# -------------------
# Parking Signs / Street Space Permit Photos
# ID:  datamart.socrata.data-sfgov-org.pigs-fac7
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['DateAdded']]
# -------------------
# Office of The Comptroller: Police Retirement System Holdings Data
# ID:  datamart.socrata.data-cityofnewyork-us.dy3p-ay2d
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Maturity Date']]
# -------------------
# [Deprecated] Form 700 Schedule A2
# ID:  datamart.socrata.data-sfgov-org.j82c-uj4d
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date Disposed']]
# -------------------
# Active Projects - Public Buildings
# ID:  datamart.socrata.data-cityofnewyork-us.g9ub-hrve
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Projected Construction Completion ']]
# -------------------
# Forestry Inspections
# ID:  datamart.socrata.data-cityofnewyork-us.4pt5-3vv4
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['ReinspectionDate']]
# -------------------
# Use of ARRA Stimulus Funds
# ID:  datamart.socrata.data-cityofnewyork-us.ivix-m77e
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Contract End Date']]
# -------------------
# LinkNYC Kiosk Status (Historical)
# ID:  datamart.socrata.data-cityofnewyork-us.quxm-hmyr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['GENERATED ON']]
# -------------------
# Multiple Dwelling Registrations
# ID:  datamart.socrata.data-cityofnewyork-us.tesw-yqqr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['RegistrationEndDate']]
# -------------------
# Civil Service List Certification
# ID:  datamart.socrata.data-cityofnewyork-us.a9md-ynri
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Cert Expiration Date']]
# -------------------
# Dig Ticket Notifications
# ID:  datamart.socrata.data-cityofchicago-org.cygx-ui4j
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['DIGDATE']]
# -------------------
# Dig Ticket Notifications
# ID:  datamart.socrata.data-cityofchicago-org.cygx-ui4j
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EXPIRATIONDATE']]
# -------------------
# Dig Ticket Notifications
# ID:  datamart.socrata.data-cityofchicago-org.cygx-ui4j
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Notice History (Created)']]
# -------------------
# Dig Ticket Notifications
# ID:  datamart.socrata.data-cityofchicago-org.cygx-ui4j
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['LASTSTATUSTIME']]
# -------------------
# Traffic Signal and All-Way Stop Study Requests
# ID:  datamart.socrata.data-cityofnewyork-us.w76s-c5u4
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['ReEvaluationDate']]
# -------------------
# Traffic Signal and All-Way Stop Study Requests
# ID:  datamart.socrata.data-cityofnewyork-us.w76s-c5u4
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['TentativeSignalInstallDate']]
# -------------------
# SFEC Form 3610b - City Officer Behested Payment - Filings
# ID:  datamart.socrata.data-sfgov-org.7vmk-cq9e
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['DateSigned']]
# -------------------
# Issued State Facility Air Permits
# ID:  datamart.socrata.data-ny-gov.2wgt-bc53
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EXPIRE DATE']]
# -------------------
# World Bank (IBRD) Bonds (1947-Present)
# ID:  datamart.socrata.finances-worldbank-org.3fps-tcuv
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Maturity Date']]
# -------------------
# Electric Vehicle Population Size History
# ID:  datamart.socrata.data-wa-gov.d886-d5q2
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date']]
# -------------------
# Health Care Provider Credential Data
# ID:  datamart.socrata.data-wa-gov.qxh8-f4bd
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['ExpirationDate']]
# -------------------
# Asbestos Control Program (ACP7)
# ID:  datamart.socrata.data-cityofnewyork-us.vq35-j9qm
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['START_DATE']]
# -------------------
# Appeals Filed In 2017
# ID:  datamart.socrata.data-cityofnewyork-us.7xq6-k6zy
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Expiration']]
# -------------------
# Public Design Commission Monthly Design Review
# ID:  datamart.socrata.data-cityofnewyork-us.tfrc-rjtr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['DATE']]
# -------------------
# Transportation Department Permits
# ID:  datamart.socrata.data-cityofchicago-org.pubx-yq2d
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['APPLICATIONEXPIREDATE']]
# -------------------
# L&I Contractor License Data - Insurance
# ID:  datamart.socrata.data-wa-gov.ciwg-agsx
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['CancelDate']]
# -------------------
# L&I Contractor License Data - Insurance
# ID:  datamart.socrata.data-wa-gov.ciwg-agsx
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['LastUpdateDate']]
# -------------------
# Location for summaries and analysis of data related to n-CoV 2019, first reported in Wuhan, China
# ID:  datamart.url.c35c7e216617536eaa11e5c19a171e66
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['date_onset_symptoms']]
# -------------------
# FundFinder_Programs
# ID:  datamart.socrata.data-wa-gov.n5j5-n3nw
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Application Closed (Yr. 2)']]
# -------------------
# Existing Buildings Energy Performance Ordinance Report
# ID:  datamart.socrata.data-sfgov-org.j2j3-acqj
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Energy Audit Due Date']]
# -------------------
# SFEC Form 114.5 - Behested Contributions Received by Certain Committees - Filings
# ID:  datamart.socrata.data-sfgov-org.hyuc-khdi
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['End Date']]
# -------------------
# Real Property Taxes
# ID:  datamart.socrata.data-baltimorecity-gov.27w9-urtv
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['AsOfDate']]
# -------------------
# Alternative Fuel Locations
# ID:  datamart.socrata.data-cityofchicago-org.f7f2-ggz5
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date Last Confirmed']]
# -------------------
# License Applications
# ID:  datamart.socrata.data-cityofnewyork-us.ptev-4hud
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Temp Op Letter Expiration']]
# -------------------
# Parking Signs / Street Space Permits
# ID:  datamart.socrata.data-sfgov-org.sftu-nd43
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['DateTimeEntered']]
# -------------------
# Parking Signs / Street Space Permits
# ID:  datamart.socrata.data-sfgov-org.sftu-nd43
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['UpdatedOn']]
# -------------------
# Parking Signs / Street Space Permits
# ID:  datamart.socrata.data-sfgov-org.sftu-nd43
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['StartDate']]
# -------------------
# Residential Projects With Inclusionary Requirements
# ID:  datamart.socrata.data-sfgov-org.nj3x-rw36
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Actual/Estimated Completion Date']]
# -------------------
# Appeals Filed In 2018
# ID:  datamart.socrata.data-cityofnewyork-us.9vaq-mvvx
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Expiration']]
# -------------------
# Solid Waste Management Facilities
# ID:  datamart.socrata.data-ny-gov.2fni-raj8
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Expiration Date']]
# -------------------
# Currently Licensed Wildlife Rehabilitators
# ID:  datamart.socrata.data-ny-gov.p5wx-nivw
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['License Expiration Date']]
# -------------------
# Bureau of Fire Prevention - Certificates of Fitness
# ID:  datamart.socrata.data-cityofnewyork-us.pdiy-9ae5
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EXPIRES_ON']]
# -------------------
# Environmental Remediation Sites
# ID:  datamart.socrata.data-ny-gov.c6ci-rzpg
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Project Completion Date']]
# -------------------
# Trade Waste Hauler Licensees
# ID:  datamart.socrata.data-cityofnewyork-us.867j-5pgi
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EXPIRATION DATE']]
# -------------------
# IBRD Statement Of Loans - Historical Data
# ID:  datamart.socrata.finances-worldbank-org.zucq-nrc3
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['First Repayment Date']]
# -------------------
# IBRD Statement Of Loans - Historical Data
# ID:  datamart.socrata.finances-worldbank-org.zucq-nrc3
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Last Repayment Date']]
# -------------------
# IBRD Statement Of Loans - Historical Data
# ID:  datamart.socrata.finances-worldbank-org.zucq-nrc3
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Closed Date (Most Recent)']]
# -------------------
# City University of New York (CUNY) Programs: Beginning Fall 2008
# ID:  datamart.socrata.data-ny-gov.28gk-bu58
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['DATE CLOSED']]
# -------------------
# MIGA Issued Projects
# ID:  datamart.socrata.finances-worldbank-org.cg7w-bf4s
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Project Expiration Date']]
# -------------------
# Street Closures due to construction activities by Block
# ID:  datamart.socrata.data-cityofnewyork-us.i6b5-j7bu
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['WORK_END_DATE']]
# -------------------

# %%
result_related, = [r for r in results_related if r['id'] == 'datamart.socrata.data-cityofnewyork-us.g9ub-hrve']
print(json.dumps(result_related, indent=2))
# Out:
# {
#   "id": "datamart.socrata.data-cityofnewyork-us.g9ub-hrve",
#   "score": 1.0,
#   "metadata": {
#     "columns": [
#       {
#         "name": "Project ID",
#         "num_distinct_values": 320,
#         "semantic_types": [],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "Description",
#         "num_distinct_values": 307,
#         "semantic_types": [],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "Client Agency",
#         "num_distinct_values": 16,
#         "plot": {
#           "data": [
#             {
#               "bin": "CORRECTIONS",
#               "count": 1
#             },
#             {
#               "bin": "ENVIRONMENTAL PROTECTION",
#               "count": 5
#             },
#             {
#               "bin": "FIRE",
#               "count": 2
#             },
#             {
#               "bin": "HPD",
#               "count": 2
#             },
#             {
#               "bin": "UNKNOWN",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "Division",
#         "num_distinct_values": 1,
#         "plot": {
#           "data": [
#             {
#               "bin": "Public Buildings",
#               "count": 320
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "Phase",
#         "num_distinct_values": 6,
#         "plot": {
#           "data": [
#             {
#               "bin": "Closeout",
#               "count": 2
#             },
#             {
#               "bin": "Construction",
#               "count": 103
#             },
#             {
#               "bin": "Initiation",
#               "count": 12
#             },
#             {
#               "bin": "NA",
#               "count": 10
#             },
#             {
#               "bin": "Procurement",
#               "count": 53
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "coverage": [
#           {
#             "range": {
#               "gte": 1696636800.0,
#               "lte": 1778803200.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1577750400.0,
#               "lte": 1631836800.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1642636800.0,
#               "lte": 1690761600.0
#             }
#           }
#         ],
#         "mean": 1647005400.0,
#         "name": "Projected Construction Completion ",
#         "num_distinct_values": 251,
#         "plot": {
#           "data": [
#             {
#               "count": 2,
#               "date_end": "2019-03-10T07:13:04",
#               "date_start": "2017-11-16T00:00:00"
#             },
#             {
#               "count": 44,
#               "date_end": "2020-07-01T14:24:00",
#               "date_start": "2019-03-10T07:13:04"
#             },
#             {
#               "count": 94,
#               "date_end": "2021-10-23T21:34:56",
#               "date_start": "2020-07-01T14:24:00"
#             },
#             {
#               "count": 95,
#               "date_end": "2023-02-15T04:48:00",
#               "date_start": "2021-10-23T21:34:56"
#             },
#             {
#               "count": 71,
#               "date_end": "2024-06-08T12:01:04",
#               "date_start": "2023-02-15T04:48:00"
#             },
#             {
#               "count": 11,
#               "date_end": "2025-09-30T19:12:00",
#               "date_start": "2024-06-08T12:01:04"
#             },
#             {
#               "count": 1,
#               "date_end": "2027-01-23T02:22:56",
#               "date_start": "2025-09-30T19:12:00"
#             },
#             {
#               "count": 1,
#               "date_end": "2028-05-16T09:36:00",
#               "date_start": "2027-01-23T02:22:56"
#             },
#             {
#               "count": 0,
#               "date_end": "2029-09-07T16:49:04",
#               "date_start": "2028-05-16T09:36:00"
#             },
#             {
#               "count": 1,
#               "date_end": "2030-12-31T00:00:00",
#               "date_start": "2029-09-07T16:49:04"
#             }
#           ],
#           "type": "histogram_temporal"
#         },
#         "semantic_types": [
#           "http://schema.org/DateTime"
#         ],
#         "stddev": 46809507.65192886,
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "Scope",
#         "num_distinct_values": 299,
#         "semantic_types": [],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "Dollar Amount",
#         "num_distinct_values": 6,
#         "plot": {
#           "data": [
#             {
#               "bin": "$100M to 500M",
#               "count": 2
#             },
#             {
#               "bin": "$10M to 30M",
#               "count": 55
#             },
#             {
#               "bin": "$1M or less",
#               "count": 52
#             },
#             {
#               "bin": "$1M to 3M",
#               "count": 91
#             },
#             {
#               "bin": "$30M to 100M",
#               "count": 25
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "Status",
#         "num_distinct_values": 1,
#         "plot": {
#           "data": [
#             {
#               "bin": "Active",
#               "count": 320
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       }
#     ],
#     "date": "2020-03-26T23:11:58.256930Z",
#     "description": "List of currently active buildings projects including description and high level schedule and bud...",
#     "id": "datamart.socrata.data-cityofnewyork-us.g9ub-hrve",
#     "materialize": {
#       "date": "2020-03-23T22:11:01.213976Z",
#       "direct_url": "https://data.cityofnewyork.us/api/views/g9ub-hrve/rows.csv?accessType=DOWNLOAD",
#       "identifier": "datamart.socrata",
#       "socrata_domain": "data.cityofnewyork.us",
#       "socrata_id": "g9ub-hrve",
#       "socrata_updated": "2020-02-08T00:38:36.000Z"
#     },
#     "name": "Active Projects - Public Buildings",
#     "nb_profiled_rows": 320,
#     "nb_rows": 320,
#     "sample": "Project ID,Description,Client Agency,Division,Phase,Projected Construction Completion ,Scope,Dollar Amount,Status\nE14-0003A,DCAS - BRONX FAMILY CRIMINAL COURT-ENERGY UPGRADE,DCAS,Public Buildings,Closeout,11/27/2019,This is a secondary project ID which relates to  E14-0003. This  secondary ID (E14-0003A)  will only track the Bronx Family and Criminal...,$3M to 10M,Active\nHH112CWFR,COMMONWEALTH AVENUE FIRE SAFETY SYSTEM,HOMELESS SERVICES,Public Buildings,Construction,04/23/2020,Commonwealth Avenue; Fire Safety System,$1M to 3M,Active\nHH112FWFA,FT. WASHINGTON - FIRE ALARM,HOMELESS SERVICES,Public Buildings,Procurement,07/15/2022,HH112FWFA: Fort Washington Armory - Fire Alarm Upgrade,$3M to 10M,Active\nHH112PJBO,PAMOJA - BOILER,HOMELESS SERVICES,Public Buildings,Design,12/02/2022,Boiler replacement.,$3M to 10M,Active\nHH112SWFA,SCHWARTZ WARDS ISLAND FIRE SAFETY,HOMELESS SERVICES,Public Buildings,Design,08/20/2021,The purpose of the project is to upgrade the existing fire alarm system. The current system does not comply with Code and has had...,$1M to 3M,Active\nHH115JCFB,JENNIE CLARK RESIDENCE - FIRE ALARM UPGRADE,HOMELESS SERVICES,Public Buildings,Construction,09/15/2020,JENNIE CLARK RESIDENCE - FIRE ALARM UPGRADE,$1M to 3M,Active\nHWQF030,HARPER ST  WASTE WATER AND STORM WATER CONVEYANCES,TRANSPORTATION,Public Buildings,Initiation,12/22/2022,Design and install a new waste water and Strom water conveyance system .,$3M to 10M,Active\nLBM13LDHC,LEONARD HVAC REPLACEMENT,LIBRARIES-BPL,Public Buildings,Design,06/28/2022,HVAC replacement and new BMS,$1M to 3M,Active\nLBP18WWBR,WALT WHITMAN BRANCH RENOVATION,LIBRARIES-BPL,Public Buildings,Initiation,03/31/2023,WALT WHITMAN BRANCH RENOVATION,$3M to 10M,Active\nLNCA13HAM,HAMILTON FISH: REHABILITATION,LIBRARIES-NYPL,Public Buildings,Design,07/21/2022,\"Exterior and interior renovations, new HVAC, Fire Alarm.and new boiler\",$3M to 10M,Active\nLNCA13MLB,MUHLENBERG: Elevator,LIBRARIES-NYPL,Public Buildings,Design,01/24/2022,\"Replace existing deteriorated elevator with higher capacity and improved ventilation, and clear existing multiple violations .\",$1M or less,Active\nLNCA15MOT,Window Replacement,LIBRARIES-NYPL,Public Buildings,Procurement,04/20/2021,Window Replacement at Mott Haven Branch,$3M to 10M,Active\nLQARVEXPN,Arverne Library - Replacement facility,LIBRARIES-QBPL,Public Buildings,Design,10/15/2024,Addition to existing library building.,$3M to 10M,Active\nLQQVHVAC,QUEENS VILLAGE - HVAC,LIBRARIES-QBPL,Public Buildings,Design,07/09/2022,HVAC replacement,$1M to 3M,Active\nPO79FDBNX,\"BRONX FRONT DESK REPLACEMENT 42ND, 44TH, 52ND, 108TH\",POLICE,Public Buildings,Procurement,07/14/2021,\"TO PROVIDE FOR THE FRONT DESK REPLACEMENT AT THE 42ND, 44TH, 52ND AND 108TH PCT IN THE BRONX\",$1M to 3M,Active\nPV209-SEC,JCM - Jewish Childrens Museum Security Cameras,CULTURAL AFFAIRS,Public Buildings,Construction,12/30/2022,Jewish Childrens Museum Security Cameras. $171K (OcL 22) and $128K (OcL 29) transferred from 126 PV467-EMR DCLA Emergency funding and...,$1M or less,Active\nPV266-EXT,MIN - Mind-Builders Exterior Renovation,CULTURAL AFFAIRS,Public Buildings,Construction,04/22/2020,\"Exterior renovation: \r\nFa\u00e7ade restoration, including brick repointing and replacement as req'd, and window replacement.  Fa\u00e7ade Area:...\",$1M to 3M,Active\nPW348-73,FUEL TANK REPLACEMENT,DCAS,Public Buildings,Construction,04/04/2022,FUEL TANK REPLACEMENT,$10M to 30M,Active\nPW348-74,FUEL TANK REPLACEMENT,DCAS,Public Buildings,Construction,10/14/2021,\"The scope of work consists of providing all necessary construction management, design, and\r\nr.onstruction services required to perform...\",$30M to 100M,Active\nTLCWOOD,TLC - NEW OFFICE FACILITY - 24-55 BQE WEST,DCAS,Public Buildings,Procurement,02/19/2024,\"Design and construction of new adminstration wing to replace existing administration wing, new parking, provide new inspection lane...\",$30M to 100M,Active\n",
#     "size": 110655,
#     "source": "data.cityofnewyork.us",
#     "version": "v0.5.5-117-gd03c3a9"
#   },
#   "augmentation": {
#     "type": "join",
#     "left_columns": [
#       [
#         2
#       ]
#     ],
#     "right_columns": [
#       [
#         5
#       ]
#     ],
#     "left_columns_names": [
#       [
#         "publish_date"
#       ]
#     ],
#     "right_columns_names": [
#       [
#         "Projected Construction Completion "
#       ]
#     ]
#   },
#   "supplied_id": null,
#   "supplied_resource_id": null,
#   "d3m_dataset_description": {
#     "about": {
#       "datasetID": "datamart.socrata.data-cityofnewyork-us.g9ub-hrve",
#       "datasetName": "Active Projects - Public Buildings",
#       "license": "unknown",
#       "approximateSize": "110655 B",
#       "datasetSchemaVersion": "4.0.0",
#       "redacted": false,
#       "datasetVersion": "1.0",
#       "description": "List of currently active buildings projects including description and high level schedule and bud..."
#     },
#     "dataResources": [
#       {
#         "resID": "learningData",
#         "resPath": "tables/learningData.csv",
#         "resType": "table",
#         "resFormat": {
#           "text/csv": [
#             "csv"
#           ]
#         },
#         "isCollection": false,
#         "columns": [
#           {
#             "colIndex": 0,
#             "colName": "Project ID",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 1,
#             "colName": "Description",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 2,
#             "colName": "Client Agency",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 3,
#             "colName": "Division",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 4,
#             "colName": "Phase",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 5,
#             "colName": "Projected Construction Completion ",
#             "colType": "dateTime",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 6,
#             "colName": "Scope",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 7,
#             "colName": "Dollar Amount",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 8,
#             "colName": "Status",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           }
#         ]
#       }
#     ]
#   }
# }

# %%
# Perform the augmentation, by just sending the JSON result again as the 'task'
response = requests.post(
    URL + '/augment', 
    files={
        'data_id': io.BytesIO(result['id'].encode('ascii')),
        'task': ('task.json', json.dumps(result_related), 'application/json'),
    },
)
response.raise_for_status()

# %%
# In D3M format by default (ZIP)
zip_ = zipfile.ZipFile(io.BytesIO(response.content), 'r')
print(zip_.namelist())
# Open the CSV
pandas.read_csv(zip_.open('tables/learningData.csv')).head()
# Out:
# ['datasetDoc.json', 'tables/learningData.csv']
#           city state   publish_date  \
# 0  Albertville    AL   3/17/20 0:00
# 1   Birmingham    AL  3/24/20 18:08
# 2         Boaz    AL   3/24/20 0:00
# 3     Carolina    AL   3/27/20 0:00
# 4      Clanton    AL   3/17/20 0:00
#
#                                                  url  \
# 0  https://www.gadsdentimes.com/news/20200317/alb...
# 1  https://www.al.com/news/2020/03/woodfin-propos...
# 2  https://www.gadsdentimes.com/news/20200324/boa...
# 3  https://www.cnbc.com/2020/03/27/north-carolina...
# 4  https://www.clantonadvertiser.com/2020/03/17/j...
#
#                                                title  \
# 0         Albertville declares coronavirus emergency
# 1  Shelter-in-place order enacted in Birmingham t...
# 2        Boaz declares state of emergency over virus
# 3  North Carolina Gov. Roy Cooper orders resident...
# 4  Jemison Council approves COVID-19 response mea...
#
#                                                 text            category  \
# 0  The Albertville City Council on Monday declare...  state_of_emergency
# 1  The Birmingham City Council approved an ordina...    shelter_in_place
# 2  The Boaz City Council on Monday declared a sta...  state_of_emergency
# 3  Governor Roy Cooper, D-NC address the crowd du...    shelter_in_place
# 4  By JOYANNA LOVE/ Senior Staff Writer\n\nThe Ci...                None
#
#    population  latitude  longitude Project ID Description Client Agency  \
# 0       37220   34.2634   -86.2107        NaN         NaN           NaN
# 1      744189   33.5277   -86.7987        NaN         NaN           NaN
# 2        9652   34.1985   -86.1529        NaN         NaN           NaN
# 3         295   31.2337   -86.5227        NaN         NaN           NaN
# 4        5876   32.8439   -86.6230        NaN         NaN           NaN
#
#   Division Phase Scope Dollar Amount Status
# 0      NaN   NaN   NaN           NaN    NaN
# 1      NaN   NaN   NaN           NaN    NaN
# 2      NaN   NaN   NaN           NaN    NaN
# 3      NaN   NaN   NaN           NaN    NaN
# 4      NaN   NaN   NaN           NaN    NaN

# %%
result_related, = [r for r in results_related if r['id'] == 'datamart.url.de434a1d1d7342deb13439c02ac39926']
print(json.dumps(result_related, indent=2))
# Out:
# {
#   "id": "datamart.url.de434a1d1d7342deb13439c02ac39926",
#   "score": 9.1313925,
#   "metadata": {
#     "columns": [
#       {
#         "coverage": [
#           {
#             "range": {
#               "gte": 163130.0,
#               "lte": 3302534.0
#             }
#           },
#           {
#             "range": {
#               "gte": 4149972.0,
#               "lte": 7036378.0
#             }
#           },
#           {
#             "range": {
#               "gte": 7478282.0,
#               "lte": 9859255.0
#             }
#           }
#         ],
#         "mean": 5155566.8963898,
#         "name": "record_id",
#         "plot": {
#           "data": [
#             {
#               "bin_end": 1004379.4,
#               "bin_start": 5036.0,
#               "count": 2065
#             },
#             {
#               "bin_end": 2003722.8,
#               "bin_start": 1004379.4,
#               "count": 1506
#             },
#             {
#               "bin_end": 3003066.2,
#               "bin_start": 2003722.8,
#               "count": 1507
#             },
#             {
#               "bin_end": 4002409.6,
#               "bin_start": 3003066.2,
#               "count": 948
#             },
#             {
#               "bin_end": 5001753.0,
#               "bin_start": 4002409.6,
#               "count": 1330
#             },
#             {
#               "bin_end": 6001096.4,
#               "bin_start": 5001753.0,
#               "count": 6273
#             },
#             {
#               "bin_end": 7000439.8,
#               "bin_start": 6001096.4,
#               "count": 1398
#             },
#             {
#               "bin_end": 7999783.2,
#               "bin_start": 7000439.8,
#               "count": 1383
#             },
#             {
#               "bin_end": 8999126.6,
#               "bin_start": 7999783.2,
#               "count": 1384
#             },
#             {
#               "bin_end": 9998470.0,
#               "bin_start": 8999126.6,
#               "count": 2002
#             }
#           ],
#           "type": "histogram_numerical"
#         },
#         "semantic_types": [
#           "http://schema.org/identifier"
#         ],
#         "stddev": 2662806.633862587,
#         "structural_type": "http://schema.org/Integer"
#       },
#       {
#         "name": "entry_type",
#         "num_distinct_values": 3,
#         "plot": {
#           "data": [
#             {
#               "bin": "Correction to Existing Entry (type in Record ID in text box)",
#               "count": 1137
#             },
#             {
#               "bin": "New Entry",
#               "count": 15291
#             },
#             {
#               "bin": "Update on Existing Entry (type in Record ID in text box)",
#               "count": 3377
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "event_description",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "type",
#         "num_distinct_values": 16,
#         "plot": {
#           "data": [
#             {
#               "bin": "Curfew",
#               "count": 172
#             },
#             {
#               "bin": "New Task Force or Bureau",
#               "count": 145
#             },
#             {
#               "bin": "Public Awareness Campaigns",
#               "count": 243
#             },
#             {
#               "bin": "Restriction of Non-Essential Government Services",
#               "count": 104
#             },
#             {
#               "bin": "Social Distancing",
#               "count": 248
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "country",
#         "num_distinct_values": 183,
#         "plot": {
#           "data": [
#             {
#               "bin": "Georgia",
#               "count": 1
#             },
#             {
#               "bin": "Mauritius",
#               "count": 1
#             },
#             {
#               "bin": "Montenegro",
#               "count": 1
#             },
#             {
#               "bin": "Nicaragua",
#               "count": 1
#             },
#             {
#               "bin": "Norway",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "init_country_level",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "province",
#         "num_distinct_values": 210,
#         "plot": {
#           "data": [
#             {
#               "bin": "Antioquia",
#               "count": 1
#             },
#             {
#               "bin": "Calabria",
#               "count": 1
#             },
#             {
#               "bin": "Narino",
#               "count": 1
#             },
#             {
#               "bin": "Neuquen",
#               "count": 1
#             },
#             {
#               "bin": "Valle del Cauca",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "missing_values_ratio": 0.18343852562484222,
#         "name": "target_country",
#         "num_distinct_values": 212,
#         "plot": {
#           "data": [
#             {
#               "bin": "Guadeloupe",
#               "count": 3
#             },
#             {
#               "bin": "Martinique",
#               "count": 3
#             },
#             {
#               "bin": "Puerto Rico",
#               "count": 3
#             },
#             {
#               "bin": "Saint Martin",
#               "count": 3
#             },
#             {
#               "bin": "Virgin Islands",
#               "count": 3
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "missing_values_ratio": 0.1813683413279475,
#         "name": "target_geog_level",
#         "num_distinct_values": 5,
#         "plot": {
#           "data": [
#             {
#               "bin": "A geographical or administrative unit within a country",
#               "count": 542
#             },
#             {
#               "bin": "All countries",
#               "count": 618
#             },
#             {
#               "bin": "One or more countries and one or more regional groupings",
#               "count": 9013
#             },
#             {
#               "bin": "One or more countries, but not all countries",
#               "count": 4505
#             },
#             {
#               "bin": "One or more regional groupings",
#               "count": 1535
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "missing_values_ratio": 0.18480181772279727,
#         "name": "target_who_what",
#         "num_distinct_values": 13,
#         "plot": {
#           "data": [
#             {
#               "bin": "All Citizens (Citizen Residents + Citizen Travelers)",
#               "count": 57
#             },
#             {
#               "bin": "Citizen Residents",
#               "count": 24
#             },
#             {
#               "bin": "Citizen Travelers",
#               "count": 141
#             },
#             {
#               "bin": "Foreign Residents (Foreign Nationals Residing in the Country)",
#               "count": 72
#             },
#             {
#               "bin": "Health-Infrastructure",
#               "count": 2
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "coverage": [
#           {
#             "range": {
#               "gte": 1585708800.0,
#               "lte": 1585833344.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1585877760.0,
#               "lte": 1586002432.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1585407488.0,
#               "lte": 1585644160.0
#             }
#           }
#         ],
#         "mean": 1585807791.613027,
#         "name": "recorded_date",
#         "num_distinct_values": 4329,
#         "plot": {
#           "data": [
#             {
#               "count": 312,
#               "date_end": "2020-03-28T23:15:12",
#               "date_start": "2020-03-28T04:33:04"
#             },
#             {
#               "count": 657,
#               "date_end": "2020-03-29T17:55:12",
#               "date_start": "2020-03-28T23:15:12"
#             },
#             {
#               "count": 278,
#               "date_end": "2020-03-30T12:37:20",
#               "date_start": "2020-03-29T17:55:12"
#             },
#             {
#               "count": 528,
#               "date_end": "2020-03-31T07:19:28",
#               "date_start": "2020-03-30T12:37:20"
#             },
#             {
#               "count": 787,
#               "date_end": "2020-04-01T02:01:36",
#               "date_start": "2020-03-31T07:19:28"
#             },
#             {
#               "count": 2589,
#               "date_end": "2020-04-01T20:41:36",
#               "date_start": "2020-04-01T02:01:36"
#             },
#             {
#               "count": 7017,
#               "date_end": "2020-04-02T15:23:44",
#               "date_start": "2020-04-01T20:41:36"
#             },
#             {
#               "count": 3351,
#               "date_end": "2020-04-03T10:05:52",
#               "date_start": "2020-04-02T15:23:44"
#             },
#             {
#               "count": 3006,
#               "date_end": "2020-04-04T04:45:52",
#               "date_start": "2020-04-03T10:05:52"
#             },
#             {
#               "count": 1280,
#               "date_end": "2020-04-04T23:28:00",
#               "date_start": "2020-04-04T04:45:52"
#             }
#           ],
#           "type": "histogram_temporal"
#         },
#         "semantic_types": [
#           "http://schema.org/DateTime"
#         ],
#         "stddev": 128239.25179990109,
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "missing_values_ratio": 0.18813430951779853,
#         "name": "target_direction",
#         "num_distinct_values": 3,
#         "plot": {
#           "data": [
#             {
#               "bin": "Inbound",
#               "count": 12805
#             },
#             {
#               "bin": "Inbound/Outbound",
#               "count": 2813
#             },
#             {
#               "bin": "Outbound",
#               "count": 461
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "travel_mechanism",
#         "num_distinct_values": 83,
#         "plot": {
#           "data": [
#             {
#               "bin": "All kinds of transport (all below except visa restrictions),Ferries",
#               "count": 1
#             },
#             {
#               "bin": "All kinds of transport (all below except visa restrictions),Flights,Land Border,Buses",
#               "count": 1
#             },
#             {
#               "bin": "Flights,Land Border,Buses",
#               "count": 1
#             },
#             {
#               "bin": "Flights,Land Border,Ferries",
#               "count": 1
#             },
#             {
#               "bin": "Flights,Land Border,Trains,Buses,Seaports,Cruises,Ferries",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "compliance",
#         "num_distinct_values": 18,
#         "plot": {
#           "data": [
#             {
#               "bin": "Mandatory with Exceptions (Please list exceptions in the text entry),Voluntary/Recommended but No Penalties",
#               "count": 2
#             },
#             {
#               "bin": "Mandatory with Fines,Mandatory (Unspecified/Implied),Mandatory with Exceptions (Please list exceptions in the text entry)",
#               "count": 2
#             },
#             {
#               "bin": "Mandatory with Legal Penalties (Jail Time),Mandatory (Unspecified/Implied)",
#               "count": 3
#             },
#             {
#               "bin": "Mandatory with Legal Penalties (Jail Time),Mandatory with Fines,Mandatory (Unspecified/Implied)",
#               "count": 2
#             },
#             {
#               "bin": "Mandatory with Legal Penalties (Jail Time),Voluntary/Recommended but No Penalties",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "enforcer",
#         "num_distinct_values": 83,
#         "plot": {
#           "data": [
#             {
#               "bin": "Military,Municipal Government",
#               "count": 1
#             },
#             {
#               "bin": "Ministry/Department of Health,Municipal Government,Police",
#               "count": 1
#             },
#             {
#               "bin": "National Government,Military,Police,Other (Please specify in the text box)",
#               "count": 1
#             },
#             {
#               "bin": "National Government,Military,Provincial/State Government,Municipal Government",
#               "count": 1
#             },
#             {
#               "bin": "National Government,Ministry/Department of Health,Military,Municipal Government,Police",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "coverage": [
#           {
#             "range": {
#               "gte": 1582502400.0,
#               "lte": 1584144000.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1579564800.0,
#               "lte": 1581292800.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1584316800.0,
#               "lte": 1585612800.0
#             }
#           }
#         ],
#         "mean": 1583947284.5847008,
#         "name": "date_announced",
#         "num_distinct_values": 91,
#         "plot": {
#           "data": [
#             {
#               "bin": "2020-01-01",
#               "count": 2
#             },
#             {
#               "bin": "2020-01-05",
#               "count": 1
#             },
#             {
#               "bin": "2020-01-15",
#               "count": 1
#             },
#             {
#               "bin": "2020-01-17",
#               "count": 2
#             },
#             {
#               "bin": "2020-01-19",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration",
#           "http://schema.org/DateTime"
#         ],
#         "stddev": 1481930.2278423472,
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "link",
#         "num_distinct_values": 2770,
#         "semantic_types": [],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "ISO_A3",
#         "num_distinct_values": 183,
#         "plot": {
#           "data": [
#             {
#               "bin": "GEO",
#               "count": 1
#             },
#             {
#               "bin": "MNE",
#               "count": 1
#             },
#             {
#               "bin": "MUS",
#               "count": 1
#             },
#             {
#               "bin": "NIC",
#               "count": 1
#             },
#             {
#               "bin": "NOR",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "ISO_A2",
#         "num_distinct_values": 182,
#         "plot": {
#           "data": [
#             {
#               "bin": "GE",
#               "count": 1
#             },
#             {
#               "bin": "ME",
#               "count": 1
#             },
#             {
#               "bin": "MU",
#               "count": 1
#             },
#             {
#               "bin": "NI",
#               "count": 1
#             },
#             {
#               "bin": "NO",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "severity_index_5perc",
#         "num_distinct_values": 1687,
#         "plot": {
#           "data": [
#             {
#               "bin": "-0.17607845425497554",
#               "count": 1
#             },
#             {
#               "bin": "-0.23065010504234879",
#               "count": 1
#             },
#             {
#               "bin": "-0.2543723380205066",
#               "count": 1
#             },
#             {
#               "bin": "-0.35969837858415116",
#               "count": 1
#             },
#             {
#               "bin": "-1.8432626846101894",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "severity_index_median",
#         "num_distinct_values": 1687,
#         "plot": {
#           "data": [
#             {
#               "bin": "-0.0013977880417586006",
#               "count": 1
#             },
#             {
#               "bin": "-0.03814633831656086",
#               "count": 1
#             },
#             {
#               "bin": "-0.06489383818450245",
#               "count": 1
#             },
#             {
#               "bin": "-0.17883254501011642",
#               "count": 1
#             },
#             {
#               "bin": "-1.3975077951808923",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "severity_index_95perc",
#         "num_distinct_values": 1687,
#         "plot": {
#           "data": [
#             {
#               "bin": "-0.9980936498729596",
#               "count": 1
#             },
#             {
#               "bin": "0.017835107567576582",
#               "count": 1
#             },
#             {
#               "bin": "0.12141187192924632",
#               "count": 1
#             },
#             {
#               "bin": "0.1481604732460865",
#               "count": 1
#             },
#             {
#               "bin": "0.21105732254769038",
#               "count": 1
#             }
#           ],
#           "type": "histogram_categorical"
#         },
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "structural_type": "http://schema.org/Text"
#       }
#     ],
#     "date": "2020-04-14T04:23:55.657675Z",
#     "description": "This file contains variables from the CoronaNet government response project, representing nationa...",
#     "id": "datamart.url.de434a1d1d7342deb13439c02ac39926",
#     "materialize": {
#       "date": "2020-04-09T21:11:59.240611Z",
#       "direct_url": "https://coronanet-project.org/data/coronanet_release.csv",
#       "identifier": "datamart.url"
#     },
#     "name": "CoronaNet Database BETA Version 1.0 (core)",
#     "nb_profiled_rows": 19805,
#     "nb_rows": 19805,
#     "sample": "record_id,entry_type,event_description,type,country,init_country_level,province,target_country,target_geog_level,target_who_what,recorded_date,target_direction,travel_mechanism,compliance,enforcer,date_announced,link,ISO_A3,ISO_A2,severity_index_5perc,severity_index_median,severity_index_95perc\n5799402,New Entry,\"Trinidad and Tobago expands travel restrictions to five additional countries (Italy, South Korea, Singapore, Japan, Iran), starting...\",External Border Restrictions,Trinidad and Tobago,\"No, it is at the national level\",NA,Iran,\"One or more countries, but not all countries\",All Travelers (Citizen Travelers + Foreign Travelers ),2020-03-31T06:53:21Z,Inbound,All kinds of transport (all below except visa restrictions),Mandatory (Unspecified/Implied),\"National Government,Ministry/Department of Health,Other (Please specify in the text box)\",2020-02-27,https://www.opm.gov.tt/trinidad-and-tobago-expands-travel-restrictions-to-five-additional-countries/,TTO,TT,-0.662425108681021,-0.44906255849001786,-0.2567344436195524\n5107295,New Entry,\"Trinidad and Tobago announces that pilots are obligated to complete forms, in which they have report an incident on board an aircraft of...\",Health Monitoring,Tonga,\"No, it is at the national level\",NA,Korea,One or more regional groupings,All Travelers (Citizen Travelers + Foreign Travelers ),2020-03-31T07:57:33Z,Inbound,Flights,Mandatory (Unspecified/Implied),\"National Government,Ministry/Department of Health,Provincial/State Government,Other (Please specify in the text box)\",2020-01-21,https://antiguaobserver.com/trinidad-swine-flu-claims-its-39th-victim/,TON,TO,-1.5141790022835726,-1.1535222275193044,-0.8608117895298436\n5726644,Update on Existing Entry (type in Record ID in text box),\"St. Vincent & the Grenadines: \"\"Therefore, all travellers from the following countries will be quarantined for 14 days:\n1. China\n2....\",Quarantine,Saint Vincent and the Grenadines,\"No, it is at the national level\",NA,Iran,One or more countries and one or more regional groupings,All (Travelers + Residents),2020-04-01T11:23:23Z,Inbound,All kinds of transport (all below except visa restrictions),Mandatory (Unspecified/Implied),Ministry/Department of Health,2020-03-25,http://www.gov.vc/images/pdf_documents/HEOC_COVID_19_Advisory_Canada_Quarantine-25_03_2020.pdf,VCT,VC,-0.42699465060223013,-0.22799762210967894,-0.044514006592995946\n5726644,Update on Existing Entry (type in Record ID in text box),\"St. Vincent & the Grenadines: \"\"Therefore, all travellers from the following countries will be quarantined for 14 days:\n1. China\n2....\",Quarantine,Saint Vincent and the Grenadines,\"No, it is at the national level\",NA,South Korea,One or more countries and one or more regional groupings,All (Travelers + Residents),2020-04-01T11:23:23Z,Inbound,All kinds of transport (all below except visa restrictions),Mandatory (Unspecified/Implied),Ministry/Department of Health,2020-03-25,http://www.gov.vc/images/pdf_documents/HEOC_COVID_19_Advisory_Canada_Quarantine-25_03_2020.pdf,VCT,VC,-0.42699465060223013,-0.22799762210967894,-0.044514006592995946\n5726644,Update on Existing Entry (type in Record ID in text box),\"St. Vincent & the Grenadines: \"\"Therefore, all travellers from the following countries will be quarantined for 14 days:\n1. China\n2....\",Quarantine,Saint Vincent and the Grenadines,\"No, it is at the national level\",NA,Macedonia,One or more countries and one or more regional groupings,All (Travelers + Residents),2020-04-01T11:23:23Z,Inbound,All kinds of transport (all below except visa restrictions),Mandatory (Unspecified/Implied),Ministry/Department of Health,2020-03-25,http://www.gov.vc/images/pdf_documents/HEOC_COVID_19_Advisory_Canada_Quarantine-25_03_2020.pdf,VCT,VC,-0.42699465060223013,-0.22799762210967894,-0.044514006592995946\n420035,Update on Existing Entry (type in Record ID in text box),\"St. Vincents & the Grenadines: \"\"All persons previously instructed to be  ...
#     "size": 15148290,
#     "source": "upload",
#     "version": "v0.5.7-122-gc41d96b"
#   },
#   "augmentation": {
#     "type": "join",
#     "left_columns": [
#       [
#         2
#       ]
#     ],
#     "right_columns": [
#       [
#         15
#       ]
#     ],
#     "left_columns_names": [
#       [
#         "publish_date"
#       ]
#     ],
#     "right_columns_names": [
#       [
#         "date_announced"
#       ]
#     ]
#   },
#   "supplied_id": null,
#   "supplied_resource_id": null,
#   "d3m_dataset_description": {
#     "about": {
#       "datasetID": "datamart.url.de434a1d1d7342deb13439c02ac39926",
#       "datasetName": "CoronaNet Database BETA Version 1.0 (core)",
#       "license": "unknown",
#       "approximateSize": "15148290 B",
#       "datasetSchemaVersion": "4.0.0",
#       "redacted": false,
#       "datasetVersion": "1.0",
#       "description": "This file contains variables from the CoronaNet government response project, representing nationa..."
#     },
#     "dataResources": [
#       {
#         "resID": "learningData",
#         "resPath": "tables/learningData.csv",
#         "resType": "table",
#         "resFormat": {
#           "text/csv": [
#             "csv"
#           ]
#         },
#         "isCollection": false,
#         "columns": [
#           {
#             "colIndex": 0,
#             "colName": "record_id",
#             "colType": "integer",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 1,
#             "colName": "entry_type",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 2,
#             "colName": "event_description",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 3,
#             "colName": "type",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 4,
#             "colName": "country",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 5,
#             "colName": "init_country_level",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 6,
#             "colName": "province",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 7,
#             "colName": "target_country",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 8,
#             "colName": "target_geog_level",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 9,
#             "colName": "target_who_what",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 10,
#             "colName": "recorded_date",
#             "colType": "dateTime",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 11,
#             "colName": "target_direction",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 12,
#             "colName": "travel_mechanism",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 13,
#             "colName": "compliance",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 14,
#             "colName": "enforcer",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 15,
#             "colName": "date_announced",
#             "colType": "dateTime",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 16,
#             "colName": "link",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 17,
#             "colName": "ISO_A3",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 18,
#             "colName": "ISO_A2",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 19,
#             "colName": "severity_index_5perc",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 20,
#             "colName": "severity_index_median",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 21,
#             "colName": "severity_index_95perc",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           }
#         ]
#       }
#     ]
#   }
# }

# %%
# Perform the augmentation, by just sending the JSON result again as the 'task'
response = requests.post(
    URL + '/augment', 
    files={
        'data_id': io.BytesIO(result['id'].encode('ascii')),
        'task': ('task.json', json.dumps(result_related), 'application/json'),
    },
)
response.raise_for_status()

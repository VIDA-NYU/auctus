# %%
import io
import json
import pandas
from pprint import pprint
import requests
import zipfile

# %%
# Pretty-print results
def print_results(results):
    if not results:
        return
    for result in results:
        print(result['metadata']['name'])
        print('ID: ', result['id'])
        print('Score: ', result['score'])
        # Print augmentation information if provided
        if 'augmentation' in result and result['augmentation']['type'] != 'none':
            aug_type = result['augmentation']['type']
            print('Augmentation: %s' % aug_type)
            print("Left Columns: %s" %
                  str(result['augmentation']['left_columns_names']))
            print("Right Columns: %s" %
                  str(result['augmentation']['right_columns_names']))
            
        print("-------------------")

# %%
URL = 'https://auctus.vida-nyu.org/api/v1'

# %%
# REST API documentation: https://docs.auctus.vida-nyu.org/rest/
# Query and result schemas: https://docs.auctus.vida-nyu.org/schemas.html

# %%
# Search for COVID data via keywords
query = {
    'keywords': ['covid'],
}
response = requests.post(URL + '/search', data={'query': json.dumps(query)})
response.raise_for_status()
results = response.json()['results']
print_results(results)
# Out:
# covid per country
# ID:  datamart.url.2e70cba96c4944198f174780b4eb382c
# Score:  15.198877
# -------------------
# COVID Tracking Data (CSV) - USA States Daily
# ID:  datamart.url.8eac7911c2cb5da0b763f3d3f86a13b8
# Score:  14.029125
# -------------------
# NYC Coronavirus (COVID-19) data
# ID:  datamart.url.9a47f900c06943ecb731d6213a5b883c
# Score:  13.022732
# -------------------
# COVID-19 Hospitalizations
# ID:  datamart.socrata.data-sfgov-org.nxjg-bhem
# Score:  12.757772
# -------------------
# COVID-19 Cases Summarized by Race and Ethnicity
# ID:  datamart.socrata.data-sfgov-org.vqqm-nsqg
# Score:  12.647821
# -------------------
# NYC Coronavirus (COVID-19) from NYC Department of Health
# ID:  datamart.url.7717c2dd7eac420eb8aa85224388a9f6
# Score:  12.42898
# -------------------
# COVID-19 Tests
# ID:  datamart.socrata.data-sfgov-org.nfpa-mg4g
# Score:  12.316138
# -------------------
# COVID-19 Cases Summarized by Age Group and Gender
# ID:  datamart.socrata.data-sfgov-org.sunc-2t3k
# Score:  11.9533415
# -------------------
# COVID-19 Cases Summarized by Date, Transmission and Case Disposition
# ID:  datamart.socrata.data-sfgov-org.tvq9-ec9w
# Score:  11.85697
# -------------------
# Washington State Public Library Services Affected by COVID-19
# ID:  datamart.socrata.data-wa-gov.6iab-kcxu
# Score:  11.778544
# -------------------
# covid
# ID:  datamart.url.e8ad58ccedbd437b96f4a36de3f4f8a7
# Score:  8.067858
# -------------------
# Nonpharmaceutical Interventions (NPIs) by Jataware - by city
# ID:  datamart.upload.488278046c6c4d9eb2ac2e417b324d47
# Score:  7.829133
# -------------------
# Nonpharmaceutical Interventions (NPIs) by Jataware - by city
# ID:  datamart.upload.86a1bc1c58ad4814847454b3644dd6cb
# Score:  7.829133
# -------------------
# Location for summaries and analysis of data related to n-CoV 2019, first reported in Wuhan, China
# ID:  datamart.url.c35c7e216617536eaa11e5c19a171e66
# Score:  6.9102316
# -------------------
# Coronavirus dataset
# ID:  datamart.url.279d869fd0b5593d970b85de233fdf7f
# Score:  6.21526
# -------------------
# NYTimes-Covid19-US-counties
# ID:  datamart.url.6290ade22c615ed78c691a20abd43efd
# Score:  5.2764072
# -------------------
# Novel Coronavirus (COVID-19) Cases Deaths, Global, provided by JHU CSSE
# ID:  datamart.url.895ba633167a59c9b8db07858d427a86
# Score:  4.110666
# -------------------
# Novel Coronavirus (COVID-19) Cases Confirmed, US, provided by JHU CSSE
# ID:  datamart.url.1151967bde695874aad1c1a4ad2d17ff
# Score:  4.110666
# -------------------
# Novel Coronavirus (COVID-19) Cases Confirmed, Global, provided by JHU CSSE
# ID:  datamart.url.2c01b1f81d655c85a55e5dfeb2f6d9f8
# Score:  4.110666
# -------------------
# Novel Coronavirus (COVID-19) Cases Recovered, Global, provided by JHU CSSE
# ID:  datamart.url.2698d783449c540090e114c5eb303fe7
# Score:  4.110666
# -------------------
# Novel Coronavirus (COVID-19) Cases Deaths, US, provided by JHU CSSE
# ID:  datamart.url.466ade356ddd58a2b3108a7a87efc099
# Score:  4.110666
# -------------------
# NYTimes-Covid19-US-states
# ID:  datamart.url.61af1b9a11805beea1150aaf085c8423
# Score:  3.4004421
# -------------------

# %%
# Show the full metadata record for one dataset
result, = [r for r in results if r['id'] == 'datamart.upload.86a1bc1c58ad4814847454b3644dd6cb']
print(json.dumps(result, indent=2))
# Out:
# {
#   "id": "datamart.upload.86a1bc1c58ad4814847454b3644dd6cb",
#   "score": 7.829133,
#   "metadata": {
#     "name": "Nonpharmaceutical Interventions (NPIs) by Jataware - by city",
#     "source": "upload",
#     "description": "\"Nonpharmaceutical Interventions,\r\n or NPIs, are policy actions taken by communities to mitigate ...",
#     "date": "2020-04-28T19:50:19.509205Z",
#     "size": 1874173,
#     "nb_rows": 558,
#     "nb_profiled_rows": 558,
#     "columns": [
#       {
#         "name": "city",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [],
#         "num_distinct_values": 429
#       },
#       {
#         "name": "state",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 19,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "AK",
#               "count": 3
#             },
#             {
#               "bin": "CT",
#               "count": 4
#             },
#             {
#               "bin": "DE",
#               "count": 4
#             },
#             {
#               "bin": "KY",
#               "count": 5
#             },
#             {
#               "bin": "ME",
#               "count": 3
#             }
#           ]
#         }
#       },
#       {
#         "name": "publish_date",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/DateTime"
#         ],
#         "missing_values_ratio": 0.3100358422939068,
#         "num_distinct_values": 200,
#         "mean": 1584586043.5116882,
#         "stddev": 513767.26253528317,
#         "coverage": [
#           {
#             "range": {
#               "gte": 1584835200.0,
#               "lte": 1585470592.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1583205504.0,
#               "lte": 1583972736.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1584115840.0,
#               "lte": 1584702592.0
#             }
#           }
#         ],
#         "temporal_resolution": "minute",
#         "plot": {
#           "type": "histogram_temporal",
#           "data": [
#             {
#               "count": 13,
#               "date_start": "2020-03-03T00:00:00",
#               "date_end": "2020-03-05T16:59:44"
#             },
#             {
#               "count": 5,
#               "date_start": "2020-03-05T16:59:44",
#               "date_end": "2020-03-08T10:01:36"
#             },
#             {
#               "count": 7,
#               "date_start": "2020-03-08T10:01:36",
#               "date_end": "2020-03-11T03:01:20"
#             },
#             {
#               "count": 31,
#               "date_start": "2020-03-11T03:01:20",
#               "date_end": "2020-03-13T20:01:04"
#             },
#             {
#               "count": 58,
#               "date_start": "2020-03-13T20:01:04",
#               "date_end": "2020-03-16T13:02:56"
#             },
#             {
#               "count": 117,
#               "date_start": "2020-03-16T13:02:56",
#               "date_end": "2020-03-19T06:02:40"
#             },
#             {
#               "count": 31,
#               "date_start": "2020-03-19T06:02:40",
#               "date_end": "2020-03-21T23:02:24"
#             },
#             {
#               "count": 39,
#               "date_start": "2020-03-21T23:02:24",
#               "date_end": "2020-03-24T16:02:08"
#             },
#             {
#               "count": 43,
#               "date_start": "2020-03-24T16:02:08",
#               "date_end": "2020-03-27T09:04:00"
#             },
#             {
#               "count": 41,
#               "date_start": "2020-03-27T09:04:00",
#               "date_end": "2020-03-30T02:03:44"
#             }
#           ]
#         }
#       },
#       {
#         "name": "url",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [],
#         "num_distinct_values": 493
#       },
#       {
#         "name": "title",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ]
#       },
#       {
#         "name": "text",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ]
#       },
#       {
#         "name": "category",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 9,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "cases",
#               "count": 1
#             },
#             {
#               "bin": "lockdown",
#               "count": 10
#             },
#             {
#               "bin": "quarantine",
#               "count": 8
#             },
#             {
#               "bin": "school_business_closure",
#               "count": 4
#             },
#             {
#               "bin": "social_distance",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "population",
#         "structural_type": "http://schema.org/Integer",
#         "semantic_types": [],
#         "mean": 54504.0376344086,
#         "stddev": 154148.1766282727,
#         "plot": {
#           "type": "histogram_numerical",
#           "data": [
#             {
#               "count": 530,
#               "bin_start": 0.0,
#               "bin_end": 208474.9
#             },
#             {
#               "count": 18,
#               "bin_start": 208474.9,
#               "bin_end": 416949.8
#             },
#             {
#               "count": 2,
#               "bin_start": 416949.8,
#               "bin_end": 625424.7
#             },
#             {
#               "count": 5,
#               "bin_start": 625424.7,
#               "bin_end": 833899.6
#             },
#             {
#               "count": 1,
#               "bin_start": 833899.6,
#               "bin_end": 1042374.5
#             },
#             {
#               "count": 0,
#               "bin_start": 1042374.5,
#               "bin_end": 1250849.4
#             },
#             {
#               "count": 0,
#               "bin_start": 1250849.4,
#               "bin_end": 1459324.3
#             },
#             {
#               "count": 0,
#               "bin_start": 1459324.3,
#               "bin_end": 1667799.2
#             },
#             {
#               "count": 1,
#               "bin_start": 1667799.2,
#               "bin_end": 1876274.0999999999
#             },
#             {
#               "count": 1,
#               "bin_start": 1876274.0999999999,
#               "bin_end": 2084749.0
#             }
#           ]
#         },
#         "coverage": [
#           {
#             "range": {
#               "gte": 178.0,
#               "lte": 146758.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1854698.0,
#               "lte": 2084749.0
#             }
#           },
#           {
#             "range": {
#               "gte": 280082.0,
#               "lte": 1011696.0
#             }
#           }
#         ]
#       },
#       {
#         "name": "latitude",
#         "structural_type": "http://schema.org/Float",
#         "semantic_types": [
#           "http://schema.org/latitude"
#         ],
#         "mean": 36.94463136200716,
#         "stddev": 4.592741270022868,
#         "plot": {
#           "type": "histogram_numerical",
#           "data": [
#             {
#               "count": 25,
#               "bin_start": 24.5637,
#               "bin_end": 28.8163
#             },
#             {
#               "count": 72,
#               "bin_start": 28.8163,
#               "bin_end": 33.0689
#             },
#             {
#               "count": 146,
#               "bin_start": 33.0689,
#               "bin_end": 37.3215
#             },
#             {
#               "count": 258,
#               "bin_start": 37.3215,
#               "bin_end": 41.5741
#             },
#             {
#               "count": 52,
#               "bin_start": 41.5741,
#               "bin_end": 45.8267
#             },
#             {
#               "count": 2,
#               "bin_start": 45.8267,
#               "bin_end": 50.079299999999996
#             },
#             {
#               "count": 0,
#               "bin_start": 50.079299999999996,
#               "bin_end": 54.33189999999999
#             },
#             {
#               "count": 0,
#               "bin_start": 54.33189999999999,
#               "bin_end": 58.58449999999999
#             },
#             {
#               "count": 1,
#               "bin_start": 58.58449999999999,
#               "bin_end": 62.83709999999999
#             },
#             {
#               "count": 2,
#               "bin_start": 62.83709999999999,
#               "bin_end": 67.0897
#             }
#           ]
#         }
#       },
#       {
#         "name": "longitude",
#         "structural_type": "http://schema.org/Float",
#         "semantic_types": [
#           "http://schema.org/longitude"
#         ],
#         "mean": -98.0607971326166,
#         "stddev": 15.837849701298603,
#         "plot": {
#           "type": "histogram_numerical",
#           "data": [
#             {
#               "count": 1,
#               "bin_start": -157.8725,
#               "bin_end": -148.934
#             },
#             {
#               "count": 2,
#               "bin_start": -148.934,
#               "bin_end": -139.9955
#             },
#             {
#               "count": 0,
#               "bin_start": -139.9955,
#               "bin_end": -131.057
#             },
#             {
#               "count": 28,
#               "bin_start": -131.057,
#               "bin_end": -122.1185
#             },
#             {
#               "count": 122,
#               "bin_start": -122.1185,
#               "bin_end": -113.17999999999999
#             },
#             {
#               "count": 54,
#               "bin_start": -113.17999999999999,
#               "bin_end": -104.2415
#             },
#             {
#               "count": 19,
#               "bin_start": -104.2415,
#               "bin_end": -95.303
#             },
#             {
#               "count": 165,
#               "bin_start": -95.303,
#               "bin_end": -86.36449999999999
#             },
#             {
#               "count": 151,
#               "bin_start": -86.36449999999999,
#               "bin_end": -77.42599999999999
#             },
#             {
#               "count": 16,
#               "bin_start": -77.42599999999999,
#               "bin_end": -68.4875
#             }
#           ]
#         }
#       }
#     ],
#     "spatial_coverage": [
#       {
#         "lat": "latitude",
#         "lon": "longitude",
#         "ranges": [
#           {
#             "range": {
#               "type": "envelope",
#               "coordinates": [
#                 [
#                   -122.8651,
#                   41.0803
#                 ],
#                 [
#                   -104.7389,
#                   33.3881
#                 ]
#               ]
#             }
#           },
#           {
#             "range": {
#               "type": "envelope",
#               "coordinates": [
#                 [
#                   -95.5977,
#                   42.3686
#                 ],
#                 [
#                   -75.3104,
#                   37.7171
#                 ]
#               ]
#             }
#           },
#           {
#             "range": {
#               "type": "envelope",
#               "coordinates": [
#                 [
#                   -92.5715,
#                   34.2466
#                 ],
#                 [
#                   -80.1842,
#                   26.1505
#                 ]
#               ]
#             }
#           }
#         ]
#       }
#     ],
#     "sample": "city,state,publish_date,url,title,text,category,population,latitude,longitude\nArcadia,CA,3/21/20 17:49,https://abc7.com/6035930,Coronavirus: Arcadia neighborhood outraged over Edison's planned power outage amid stay-at-home orders,EMBED >More News Videos Members of President Donald Trump's economic team convene Friday on Capitol Hill to launch negotiations with...,shelter_in_place,58799,34.1342,-118.0373\nCarson,CA,,https://www.nevadaappeal.com/news/carson-city-declares-state-of-emergency-due-to-coronavirus/,Carson City declares State of Emergency due to coronavirus,\"Aerial View of Carson City, Nevada looking north.\n\nGetty\n\nA message from Carson City Public Works: As we all closely monitor the rapidly...\",state_of_emergency,92735,33.8374,-118.2559\nYuba City,CA,,https://www.appeal-democrat.com/news/urgent/yuba-city-declares-local-emergency-due-to-coronavirus/article_6fd64f4c-6d79-11ea-a3d0-7f88fd6...,Yuba City declares local emergency due to coronavirus,\"Marysville, CA (95901)\n\nToday\n\nCloudy skies this morning will become partly cloudy this afternoon. High 62F. Winds SSE at 5 to 10...\",state_of_emergency,120186,39.1357,-121.6381\nGlendale,CO,3/20/20 0:00,https://www.latimes.com/socal/glendale-news-press/news/story/2020-03-20/tn-gnp-me-glendale-follows-safer-at-home-order,\"Coronavirus: Glendale follows L.A. County\u2019s \u2018Safer at Home\u2019 order, requiring the closure of more businesses\",\"For at least the next month, Glendale residents have been ordered to stay at home and leave only for essential needs, following a...\",shelter_in_place,5158,39.7036,-104.9352\nBoca Raton,FL,3/17/20 19:25,https://www.bocamag.com/coronavirus-boca-state-of-emergency/,Coronavirus: City of Boca Raton Declares State of Emergency,The City of Boca Raton has declared a local state of emergency in response to the ongoing coronavirus pandemic. A new set of mandatory...,state_of_emergency,98150,26.3749,-80.1077\nCoconut Creek,FL,3/21/20 0:00,https://miami.cbslocal.com/2020/03/21/coronavirus-prompts-coconut-creek-to-enact-nightly-curfew/,Coronavirus Prompts Coconut Creek To Enact Nightly Curfew,\"\n\n\n\nFORT LAUDERDALE (CBSMiami) \u2013 Due to the coronavirus pandemic, the City of Coconut Creek is joining a handful of other cities in...\",lockdown,61010,26.2802,-80.1842\nNorth Port,FL,3/17/20 0:00,https://www.heraldtribune.com/news/20200317/coronavirus-florida-north-port-declares-state-of-emergency,Coronavirus Florida: North Port declares state of emergency,\"Commissioners looking into receiving public comment electronically and hosting virtual meetings.\n\nThis content is being provided for...\",state_of_emergency,195992,27.0577,-82.1975\nHoward,GA,3/14/20 10:11,https://www.msgr.com/article/putnam-county-sheriff-howard-sills-issues-statement-coronavirus-after-president-issues,Putnam County Sheriff Howard Sills issues statement on Coronavirus after President issues national emergency,\"Putnam County Sheriff Howard Sills releases statement after national emergency issued due to Coronavirus pandemic\n\n-- No test kits...\",state_of_emergency,0,32.5982,-84.3786\nNorcross,GA,,https://www.ajc.com/news/local/norcross-declares-state-emergency-due-coronavirus/wfU0yXtBc3tbjjQh2gx1rO/,Norcross declares state of emergency due to coronavirus,\"The city of Norcross has declared a state of emergency due to the coronavirus pandemic.\n\nThere are no known cases within city limits,...\",state_of_emergency,16845,33.9379,-84.2065\nForest Park,IL,3/18/20 0:00,https://www.chicagotribune.com/suburbs/oak-park/ct-oak-mayors-response-covid-19-tl-0326-20200318-tpwctduzjbblra65stygyk3gmy-story.html,\"Oak Park issues shelter-in-place order to slow COVID-19 spread as River Forest, Forest Park leaders urge residents to comply as well\",\"\u201cWe are urging people to stay home and stay out of reach of other people,\u201d Abu-Taleb said. \u201cI\u2019m prepared to order people to shelter in...\",shelter_in_place,13951,41.8683,-87.8157\nMarseilles,I ...
#     "materialize": {
#       "date": "2020-04-09T18:36:38.507936Z",
#       "identifier": "datamart.upload"
#     },
#     "version": "v0.5.7-179-ged84ca4",
#     "id": "datamart.upload.86a1bc1c58ad4814847454b3644dd6cb"
#   },
#   "augmentation": {
#     "type": "none",
#     "left_columns": [],
#     "left_columns_names": [],
#     "right_columns": [],
#     "right_columns_names": []
#   },
#   "supplied_id": null,
#   "supplied_resource_id": null,
#   "d3m_dataset_description": {
#     "about": {
#       "datasetID": "datamart.upload.86a1bc1c58ad4814847454b3644dd6cb",
#       "datasetName": "Nonpharmaceutical Interventions (NPIs) by Jataware - by city",
#       "license": "unknown",
#       "approximateSize": "1874173 B",
#       "datasetSchemaVersion": "4.0.0",
#       "redacted": false,
#       "datasetVersion": "1.0",
#       "description": "\"Nonpharmaceutical Interventions,\r\n or NPIs, are policy actions taken by communities to mitigate ..."
#     },
#     "dataResources": [
#       {
#         "resID": "learningData",
#         "resPath": "tables/learningData.csv",
#         "resType": "table",
#         "resFormat": {
#           "text/csv": [
#             "csv"
#           ]
#         },
#         "isCollection": false,
#         "columns": [
#           {
#             "colIndex": 0,
#             "colName": "city",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 1,
#             "colName": "state",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 2,
#             "colName": "publish_date",
#             "colType": "dateTime",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 3,
#             "colName": "url",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 4,
#             "colName": "title",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 5,
#             "colName": "text",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 6,
#             "colName": "category",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 7,
#             "colName": "population",
#             "colType": "integer",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 8,
#             "colName": "latitude",
#             "colType": "real",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 9,
#             "colName": "longitude",
#             "colType": "real",
#             "role": [
#               "attribute"
#             ]
#           }
#         ]
#       }
#     ]
#   }
# }

# %% [markdown]
# ```json
# {
#   "id": "datamart.upload.86a1bc1c58ad4814847454b3644dd6cb",
#   "score": 8.27132,                             # Score
#   "metadata": {
#     "id": "datamart.upload.86a1bc1c58ad4814847454b3644dd6cb",
#
#                                                 # General information about the dataset
#     "name": "Nonpharmaceutical Interventions (NPIs) by Jataware - by city",
#     "description": "\"Nonpharmaceutical Interventions,\r\n or NPIs, are policy actions taken by communities to mitigate ...",
#     "filename": "Jataware-City-NPIs.csv",
#     "size": 1874173,
#     "nb_rows": 558,
#     "source": "upload",
#
#     "materialize": {                            # Materialization information, e.g. plugin providing this dataset
#       "date": "2020-04-09T18:36:38.507936Z",
#       "identifier": "datamart.upload"
#     },
#     "date": "2020-04-09T18:36:50.958540Z",      # Date and version of profiling
#     "version": "v0.5.7-16-g0e70d36",
#     "nb_profiled_rows": 558,
#     "columns": [                                # Information about each column, profiled automatically
#       {
#         "name": "city",
#         "num_distinct_values": 429,
#         "semantic_types": [],
#         "structural_type": "http://schema.org/Text"
#       },
#       {
#         "name": "state",
#         "structural_type": "http://schema.org/Text",  # String
#         "semantic_types": [
#           "http://schema.org/Enumeration"             # Recognized as categorical data, 19 categories
#         ],
#         "num_distinct_values": 19
#       },
#       {
#         "name": "publish_date",
#         "missing_values_ratio": 0.3100358422939068,   # 31% of missing values
#         "structural_type": "http://schema.org/Text",  # String
#         "semantic_types": [
#           "http://schema.org/DateTime"                # Recognized as dates
#         ],
#         "num_distinct_values": 200,
#         "mean": 1584586043.5116882,                   # Numerical distribution (of the interpreted timestamp)
#         "stddev": 513767.26253528317,
#         "coverage": [
#           {"range": {"gte": 1584835200.0, "lte": 1585470592.0}},
#           {"range": {"gte": 1583205504.0, "lte": 1583972736.0}},
#           {"range": {"gte": 1584115840.0, "lte": 1584702592.0}}
#         ]
#       },
#       {
#         "name": "url",
#         "structural_type": "http://schema.org/Text",  # String with no special meaning for profiler
#         "semantic_types": [],
#         "num_distinct_values": 493
#       },
#       {
#         "name": "title",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ]
#       },
#       {
#         "name": "text",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ]
#       },
#       {
#         "name": "category",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"              # Recognized as categorical data, 9 categories
#         ],
#         "num_distinct_values": 9
#       },
#       {
#         "name": "population",
#         "structural_type": "http://schema.org/Integer",  # Integers
#         "semantic_types": [],
#         "mean": 54504.0376344086,                       # Numerical distribution
#         "stddev": 154148.1766282727,
#         "coverage": [
#           {"range": {"gte": 178.0, "lte": 146758.0}},
#           {"range": {"gte": 1854698.0, "lte": 2084749.0}},
#           {"range": {"gte": 280082.0, "lte": 1011696.0}}
#         ]
#       },
#       {
#         "name": "latitude",
#         "structural_type": "http://schema.org/Float",  # Floating point detected as latitude coordinate
#         "semantic_types": [
#           "http://schema.org/latitude"
#         ],
#         "mean": 36.94463136200716,
#         "stddev": 4.592741270022868
#       },
#       {
#         "name": "longitude",
#         "structural_type": "http://schema.org/Float",  # Floating point detected as longitude coordinate
#         "semantic_types": [
#           "http://schema.org/longitude"
#         ],
#         "mean": -98.0607971326166,
#         "stddev": 15.837849701298603
#       }
#     ],
#     "spatial_coverage": [
#       {
#         "lat": "latitude",          # This is a simple case but the system can pair more complicated
#         "lon": "longitude",         # column names and deal with abbreviations
#         "ranges": [                 # Computed bounding boxes
#           {"range": {"coordinates": [[-122.8651, 41.0803], [-104.7389, 33.3881]], "type": "envelope"}},
#           {"range": {"coordinates": [[-95.5977, 42.3686], [-75.3104, 37.7171]], "type": "envelope"}},
#           {"range": {"coordinates": [[-92.5715, 34.2466], [-80.1842, 26.1505]], "type": "envelope"}}
#         ]
#       }
#     ]
#   },
#   "augmentation": {                   # Augmentation information (if providing an input dataset, see below)
#     "type": "none",
#     "left_columns": [],
#     "left_columns_names": [],
#     "right_columns": [],
#     "right_columns_names": []
#   },
#   "supplied_id": null,
#   "supplied_resource_id": null,
#   "d3m_dataset_description": {...}     # Metadata in D3M format
# }
# ```

# %%
# Let's download the dataset
response = requests.get(URL + '/download/' + result['id'])
response.raise_for_status()
# It's a CSV, load it
pandas.read_csv(io.BytesIO(response.content)).head()
# Out:
#           city state   publish_date  \
# 0  Albertville    AL   3/17/20 0:00
# 1   Birmingham    AL  3/24/20 18:08
# 2         Boaz    AL   3/24/20 0:00
# 3     Carolina    AL   3/27/20 0:00
# 4      Clanton    AL   3/17/20 0:00
#
#                                                  url  \
# 0  https://www.gadsdentimes.com/news/20200317/alb...
# 1  https://www.al.com/news/2020/03/woodfin-propos...
# 2  https://www.gadsdentimes.com/news/20200324/boa...
# 3  https://www.cnbc.com/2020/03/27/north-carolina...
# 4  https://www.clantonadvertiser.com/2020/03/17/j...
#
#                                                title  \
# 0         Albertville declares coronavirus emergency
# 1  Shelter-in-place order enacted in Birmingham t...
# 2        Boaz declares state of emergency over virus
# 3  North Carolina Gov. Roy Cooper orders resident...
# 4  Jemison Council approves COVID-19 response mea...
#
#                                                 text            category  \
# 0  The Albertville City Council on Monday declare...  state_of_emergency
# 1  The Birmingham City Council approved an ordina...    shelter_in_place
# 2  The Boaz City Council on Monday declared a sta...  state_of_emergency
# 3  Governor Roy Cooper, D-NC address the crowd du...    shelter_in_place
# 4  By JOYANNA LOVE/ Senior Staff Writer\n\nThe Ci...                None
#
#    population  latitude  longitude
# 0       37220   34.2634   -86.2107
# 1      744189   33.5277   -86.7987
# 2        9652   34.1985   -86.1529
# 3         295   31.2337   -86.5227
# 4        5876   32.8439   -86.6230

# %%
# Can download in other formats, such as D3M's custom format
response = requests.get(URL + '/download/' + result['id'] + '?format=d3m&format_need_d3mindex=1')
response.raise_for_status()
# D3M format is a directory, so we get a ZIP
zip_ = zipfile.ZipFile(io.BytesIO(response.content), 'r')
print(zip_.namelist())
# Open the CSV
pandas.read_csv(zip_.open('tables/learningData.csv')).head()
# Note that a 'd3mIndex' column was generated, D3M tools require it for machine-learning workflows
# (optional via format options, here 'need_d3mindex')
# Out:
# ['datasetDoc.json', 'tables/learningData.csv']
#    d3mIndex         city state   publish_date  \
# 0         0  Albertville    AL   3/17/20 0:00
# 1         1   Birmingham    AL  3/24/20 18:08
# 2         2         Boaz    AL   3/24/20 0:00
# 3         3     Carolina    AL   3/27/20 0:00
# 4         4      Clanton    AL   3/17/20 0:00
#
#                                                  url  \
# 0  https://www.gadsdentimes.com/news/20200317/alb...
# 1  https://www.al.com/news/2020/03/woodfin-propos...
# 2  https://www.gadsdentimes.com/news/20200324/boa...
# 3  https://www.cnbc.com/2020/03/27/north-carolina...
# 4  https://www.clantonadvertiser.com/2020/03/17/j...
#
#                                                title  \
# 0         Albertville declares coronavirus emergency
# 1  Shelter-in-place order enacted in Birmingham t...
# 2        Boaz declares state of emergency over virus
# 3  North Carolina Gov. Roy Cooper orders resident...
# 4  Jemison Council approves COVID-19 response mea...
#
#                                                 text            category  \
# 0  The Albertville City Council on Monday declare...  state_of_emergency
# 1  The Birmingham City Council approved an ordina...    shelter_in_place
# 2  The Boaz City Council on Monday declared a sta...  state_of_emergency
# 3  Governor Roy Cooper, D-NC address the crowd du...    shelter_in_place
# 4  By JOYANNA LOVE/ Senior Staff Writer\n\nThe Ci...                None
#
#    population  latitude  longitude
# 0       37220   34.2634   -86.2107
# 1      744189   33.5277   -86.7987
# 2        9652   34.1985   -86.1529
# 3         295   31.2337   -86.5227
# 4        5876   32.8439   -86.6230

# %%
# Ask server for datasets related to this result
response = requests.post(URL + '/search', data={'data_id': result['id']})
response.raise_for_status()
results_related = response.json()['results']
print_results(results_related)
# Notice the proposed augmentations (unions or joins)
# Out:
# L&I Contractor License Data - General
# ID:  datamart.socrata.data-wa-gov.m8qx-ubtq
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['LicenseExpirationDate']]
# -------------------
# Nonpharmaceutical Interventions (NPIs) by Jataware - by city
# ID:  datamart.upload.488278046c6c4d9eb2ac2e417b324d47
# Score:  0.8
# Augmentation: union
# Left Columns: [['city'], ['url'], ['title'], ['text'], ['state'], ['category'], ['publish_date'], ['population']]
# Right Columns: [['city'], ['url'], ['title'], ['text'], ['state'], ['category'], ['publish_date'], ['population']]
# -------------------
# L&I Contractor License Data - General
# ID:  datamart.socrata.data-wa-gov.m8qx-ubtq
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['ContractorLicenseSuspendDate']]
# -------------------
# Special Vaccine Locations
# ID:  datamart.socrata.data-cityofchicago-org.9a77-69d3
# Score:  0.5
# Augmentation: union
# Left Columns: [['city'], ['url'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['city'], ['url'], ['state'], ['latitude'], ['longitude']]
# -------------------
# Envista Projects for Utility Excavation and Paving
# ID:  datamart.socrata.data-sfgov-org.sf93-6dmr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['start_date']]
# -------------------
# San Francisco Department of Public Health Flu Shot Locations 2013
# ID:  datamart.socrata.data-sfgov-org.yg87-cd6v
# Score:  0.5
# Augmentation: union
# Left Columns: [['city'], ['url'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['city'], ['url'], ['state'], ['latitude'], ['longitude']]
# -------------------
# Envista Projects for Utility Excavation and Paving
# ID:  datamart.socrata.data-sfgov-org.sf93-6dmr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['end_date']]
# -------------------
# Volunteer Opportunities and Finding Organizations
# ID:  datamart.socrata.data-cityofnewyork-us.shpd-5q9m
# Score:  0.5
# Augmentation: union
# Left Columns: [['city'], ['title'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['Title'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Envista Projects for Utility Excavation and Paving
# ID:  datamart.socrata.data-sfgov-org.sf93-6dmr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['create_date']]
# -------------------
# State University of New York (SUNY) Campus Locations with Websites, Enrollment and Select Program Offerings
# ID:  datamart.socrata.data-ny-gov.3cij-nwhw
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude1'], ['Longitude1']]
# -------------------
# Envista Projects for Utility Excavation and Paving
# ID:  datamart.socrata.data-sfgov-org.sf93-6dmr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['modify_date']]
# -------------------
# New York City Council Discretionary Funding
# ID:  datamart.socrata.data-cityofnewyork-us.4d7f-74pe
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Agency Contracts Fiscal Year 2018
# ID:  datamart.socrata.data-wa-gov.3f3v-gugf
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Contract Effective End Date']]
# -------------------
# Chicago Public Schools - High School Progress Report (2013-2014)
# ID:  datamart.socrata.data-cityofchicago-org.2m8w-izji
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Agency Contracts Fiscal Year 2018
# ID:  datamart.socrata.data-wa-gov.3f3v-gugf
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Period of Performance End Date']]
# -------------------
# DOB NOW: Build – Job Application Filings
# ID:  datamart.socrata.data-cityofnewyork-us.w9ak-ipjd
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Contracts
# ID:  datamart.socrata.data-cityofchicago-org.rsxa-ify5
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['End Date']]
# -------------------
# TLC Approved LabCorp Patient Services Drug Test Locations (Dataset)
# ID:  datamart.socrata.data-cityofnewyork-us.pe54-wf39
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Legally Operating Businesses
# ID:  datamart.socrata.data-cityofnewyork-us.w7w3-xahh
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['License Expiration Date']]
# -------------------
# Tourism Grants
# ID:  datamart.socrata.data-cityofnewyork-us.rma9-fm39
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Utility Base Rate Change  - Delivery Rates Beginning 1998
# ID:  datamart.socrata.data-ny-gov.ddrw-g9a6
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date Effective']]
# -------------------
# Food Inspections
# ID:  datamart.socrata.data-cityofchicago-org.4ijn-s7e5
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Lobbyist Data - Expenditures - Hosting
# ID:  datamart.socrata.data-cityofchicago-org.pvm2-bd2i
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['PERIOD_END']]
# -------------------
# New York City Council Discretionary Funding (2013)
# ID:  datamart.socrata.data-cityofnewyork-us.q2ni-ztsb
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Lobbyist Data - Expenditures - Hosting
# ID:  datamart.socrata.data-cityofchicago-org.pvm2-bd2i
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['CREATED_DATE']]
# -------------------
# Alternative Fuel Locations
# ID:  datamart.socrata.data-cityofchicago-org.f7f2-ggz5
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Civil Service List (Terminated)
# ID:  datamart.socrata.data-cityofnewyork-us.qu8g-sxqf
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Anniversary Date']]
# -------------------
# WDFW-Hatcheries
# ID:  datamart.socrata.data-wa-gov.hjdc-v2n4
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# SFEC Form 124 - Contributions Made by Business Entities - Filings
# ID:  datamart.socrata.data-sfgov-org.tsy6-7xfs
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date Signed']]
# -------------------
# License Applications
# ID:  datamart.socrata.data-cityofnewyork-us.ptev-4hud
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# SFEC Form 124 - Contributions Made by Business Entities - Filings
# ID:  datamart.socrata.data-sfgov-org.tsy6-7xfs
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date Threshold Reached']]
# -------------------
# Chicago Early Learning Programs
# ID:  datamart.socrata.data-cityofchicago-org.ck29-hb9r
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# 2012 SFO Customer Survey
# ID:  datamart.socrata.data-sfgov-org.ckai-dve4
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Q18ZIP']]
# -------------------
# DARP-ROTOW Enrollment Status of Active Tow Truck Companies
# ID:  datamart.socrata.data-cityofnewyork-us.q5u8-89nv
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# [Testing] SFMTA - Enforced Temporary Tow Zones
# ID:  datamart.socrata.data-sfgov-org.6r5h-j298
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EndDate']]
# -------------------
# TLC Driver Education 24 Hour Course Providers (Dataset)
# ID:  datamart.socrata.data-cityofnewyork-us.wzur-rhz9
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Large Utility Excavation Permits
# ID:  datamart.socrata.data-sfgov-org.i926-ujnc
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Permit_Start_Date']]
# -------------------
# 2003 Campaign Contributions
# ID:  datamart.socrata.data-cityofnewyork-us.s79c-jgrm
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Temporary Art Program
# ID:  datamart.socrata.data-cityofnewyork-us.3r2x-bnmj
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Removal']]
# -------------------
# Avenue NYC CFY17-CFY19
# ID:  datamart.socrata.data-cityofnewyork-us.qjvp-rnsx
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Department Of Health Contracts Started Or Amended During State Fiscal Year 2017
# ID:  datamart.socrata.data-wa-gov.5s66-2kbs
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['End Date']]
# -------------------
# Capital Grant Awards 2014
# ID:  datamart.socrata.data-cityofnewyork-us.9umc-3b2y
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Consumer Services Mediated Complaints
# ID:  datamart.socrata.data-cityofnewyork-us.nre2-6m2s
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Mediation Close Date']]
# -------------------
# Wastewater Treatment Plants
# ID:  datamart.socrata.data-ny-gov.2v6p-juki
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# New York State Parks Concession Contracts
# ID:  datamart.socrata.data-ny-gov.adec-zj7s
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['End Date']]
# -------------------
# Chicago Microlending Institute (CMI) Microloans
# ID:  datamart.socrata.data-cityofchicago-org.dpkg-upyz
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Appeals Filed In 2016
# ID:  datamart.socrata.data-cityofnewyork-us.7h99-xsqt
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Expiration']]
# -------------------
# DYCD Program Sites
# ID:  datamart.socrata.data-cityofnewyork-us.ebkm-iyma
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------
# Trade Waste Broker Registrants
# ID:  datamart.socrata.data-cityofnewyork-us.krx7-u82t
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EXPIRATION DATE']]
# -------------------
# Transportation Sites
# ID:  datamart.socrata.data-cityofnewyork-us.hg3c-2jsy
# Score:  0.4
# Augmentation: union
# Left Columns: [['city'], ['state'], ['latitude'], ['longitude']]
# Right Columns: [['City'], ['State'], ['Latitude'], ['Longitude']]
# -------------------

# %%
# Add a keyword filter
query = {
    'keywords': ['coronanet'],
}
response = requests.post(URL + '/search', data={'query': json.dumps(query), 'data_id': result['id']})
response.raise_for_status()
results_related = response.json()['results']
print_results(results_related)
# Out:
# CoronaNet Database BETA Version 1.0 (core)
# ID:  datamart.url.de434a1d1d7342deb13439c02ac39926
# Score:  9.797967
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['date_announced']]
# -------------------
# CoronaNet Database BETA Version 1.0 (core)
# ID:  datamart.url.de434a1d1d7342deb13439c02ac39926
# Score:  9.565694
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['date_start']]
# -------------------
# L&I Contractor License Data - General
# ID:  datamart.socrata.data-wa-gov.m8qx-ubtq
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['LicenseExpirationDate']]
# -------------------
# L&I Contractor License Data - General
# ID:  datamart.socrata.data-wa-gov.m8qx-ubtq
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['ContractorLicenseSuspendDate']]
# -------------------
# Envista Projects for Utility Excavation and Paving
# ID:  datamart.socrata.data-sfgov-org.sf93-6dmr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['start_date']]
# -------------------
# Envista Projects for Utility Excavation and Paving
# ID:  datamart.socrata.data-sfgov-org.sf93-6dmr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['end_date']]
# -------------------
# Envista Projects for Utility Excavation and Paving
# ID:  datamart.socrata.data-sfgov-org.sf93-6dmr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['create_date']]
# -------------------
# Envista Projects for Utility Excavation and Paving
# ID:  datamart.socrata.data-sfgov-org.sf93-6dmr
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['modify_date']]
# -------------------
# Agency Contracts Fiscal Year 2018
# ID:  datamart.socrata.data-wa-gov.3f3v-gugf
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Contract Effective End Date']]
# -------------------
# Agency Contracts Fiscal Year 2018
# ID:  datamart.socrata.data-wa-gov.3f3v-gugf
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Period of Performance End Date']]
# -------------------
# Contracts
# ID:  datamart.socrata.data-cityofchicago-org.rsxa-ify5
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['End Date']]
# -------------------
# Legally Operating Businesses
# ID:  datamart.socrata.data-cityofnewyork-us.w7w3-xahh
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['License Expiration Date']]
# -------------------
# Utility Base Rate Change  - Delivery Rates Beginning 1998
# ID:  datamart.socrata.data-ny-gov.ddrw-g9a6
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date Effective']]
# -------------------
# Lobbyist Data - Expenditures - Hosting
# ID:  datamart.socrata.data-cityofchicago-org.pvm2-bd2i
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['PERIOD_END']]
# -------------------
# Lobbyist Data - Expenditures - Hosting
# ID:  datamart.socrata.data-cityofchicago-org.pvm2-bd2i
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['CREATED_DATE']]
# -------------------
# Civil Service List (Terminated)
# ID:  datamart.socrata.data-cityofnewyork-us.qu8g-sxqf
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Anniversary Date']]
# -------------------
# SFEC Form 124 - Contributions Made by Business Entities - Filings
# ID:  datamart.socrata.data-sfgov-org.tsy6-7xfs
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date Signed']]
# -------------------
# SFEC Form 124 - Contributions Made by Business Entities - Filings
# ID:  datamart.socrata.data-sfgov-org.tsy6-7xfs
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Date Threshold Reached']]
# -------------------
# 2012 SFO Customer Survey
# ID:  datamart.socrata.data-sfgov-org.ckai-dve4
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Q18ZIP']]
# -------------------
# [Testing] SFMTA - Enforced Temporary Tow Zones
# ID:  datamart.socrata.data-sfgov-org.6r5h-j298
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EndDate']]
# -------------------
# Large Utility Excavation Permits
# ID:  datamart.socrata.data-sfgov-org.i926-ujnc
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Permit_Start_Date']]
# -------------------
# Temporary Art Program
# ID:  datamart.socrata.data-cityofnewyork-us.3r2x-bnmj
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Removal']]
# -------------------
# Department Of Health Contracts Started Or Amended During State Fiscal Year 2017
# ID:  datamart.socrata.data-wa-gov.5s66-2kbs
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['End Date']]
# -------------------
# Consumer Services Mediated Complaints
# ID:  datamart.socrata.data-cityofnewyork-us.nre2-6m2s
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Mediation Close Date']]
# -------------------
# New York State Parks Concession Contracts
# ID:  datamart.socrata.data-ny-gov.adec-zj7s
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['End Date']]
# -------------------
# Appeals Filed In 2016
# ID:  datamart.socrata.data-cityofnewyork-us.7h99-xsqt
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Expiration']]
# -------------------
# Trade Waste Broker Registrants
# ID:  datamart.socrata.data-cityofnewyork-us.krx7-u82t
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EXPIRATION DATE']]
# -------------------
# IDA Statement of Credits and Grants  - Latest Available Snapshot
# ID:  datamart.socrata.finances-worldbank-org.ebmi-69yj
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['First Repayment Date']]
# -------------------
# IDA Statement of Credits and Grants  - Latest Available Snapshot
# ID:  datamart.socrata.finances-worldbank-org.ebmi-69yj
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Last Repayment Date']]
# -------------------
# IDA Statement of Credits and Grants  - Latest Available Snapshot
# ID:  datamart.socrata.finances-worldbank-org.ebmi-69yj
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Closed Date (Most Recent)']]
# -------------------
# License Event Notification Service (LENS) Customers
# ID:  datamart.socrata.data-ny-gov.tt84-bydt
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Latest Driver Add Date']]
# -------------------
# License Event Notification Service (LENS) Customers
# ID:  datamart.socrata.data-ny-gov.tt84-bydt
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Latest Driver Drop Date']]
# -------------------
# Construction Demolition Registrants
# ID:  datamart.socrata.data-cityofnewyork-us.cspg-yi7g
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EXPIRATION DATE']]
# -------------------
# Historical Medallion Drivers – Passenger Assistance Trained 2017
# ID:  datamart.socrata.data-cityofnewyork-us.c4dx-tk4d
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Expiration Date']]
# -------------------
# Office of The Comptroller: Fire Department Retirement System Holdings Data
# ID:  datamart.socrata.data-cityofnewyork-us.95aa-k2ka
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Maturity Date']]
# -------------------
# NYC Office of The Comptroller: Board of Education Retirement System (BERS) Holdings Data
# ID:  datamart.socrata.data-cityofnewyork-us.fypi-ruxh
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Maturity Date']]
# -------------------
# Roadway Construction Moratoriums
# ID:  datamart.socrata.data-cityofchicago-org.ndbz-vy4e
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['EXPIRATION DATE']]
# -------------------
# DNR Project Codes for Financial Reporting
# ID:  datamart.socrata.data-wa-gov.6grp-8ghq
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['project_end_date']]
# -------------------
# Medallion Drivers – Passenger Assistance Trained
# ID:  datamart.socrata.data-cityofnewyork-us.td5q-ry6d
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Expiration Date']]
# -------------------
# Medallion Drivers – Passenger Assistance Trained
# ID:  datamart.socrata.data-cityofnewyork-us.td5q-ry6d
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Last Date Updated']]
# -------------------
# Potholes Patched
# ID:  datamart.socrata.data-cityofchicago-org.wqdh-9gek
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['REQUEST DATE']]
# -------------------
# Potholes Patched
# ID:  datamart.socrata.data-cityofchicago-org.wqdh-9gek
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['COMPLETION DATE']]
# -------------------
# TIF Status and Eligibility
# ID:  datamart.socrata.data-cityofchicago-org.3qsz-jemf
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['End Date']]
# -------------------
# Current Certified Pesticide Applicators
# ID:  datamart.socrata.data-ny-gov.c7db-kwpj
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Renewal Date']]
# -------------------
# Aircraft Parking Location Inventory at SFO
# ID:  datamart.socrata.data-sfgov-org.2ymc-znns
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['End Date']]
# -------------------
# Local Law 44 - Projects
# ID:  datamart.socrata.data-cityofnewyork-us.ucdy-byxd
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['ProjectedCompletionDate']]
# -------------------
# Office of The Comptroller: Teachers Retirement System Holdings Data
# ID:  datamart.socrata.data-cityofnewyork-us.5u2d-n46s
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Maturity Date']]
# -------------------
# Candidate Surplus Funds Latest Report
# ID:  datamart.socrata.data-wa-gov.3cbn-54c3
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['thru_date']]
# -------------------
# DART (Department Application Review and Tracking) on the Web: Beginning 1988
# ID:  datamart.socrata.data-ny-gov.mbk7-f2r2
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['Permit Expiration Date']]
# -------------------
# Campaign Finance Summary
# ID:  datamart.socrata.data-wa-gov.3h9x-7bvm
# Score:  1.0
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['election_date']]
# -------------------

# %%
# Grab a particular result
print_results([r for r in results_related if r['id'] == 'datamart.url.de434a1d1d7342deb13439c02ac39926'])
# Out:
# CoronaNet Database BETA Version 1.0 (core)
# ID:  datamart.url.de434a1d1d7342deb13439c02ac39926
# Score:  9.797967
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['date_announced']]
# -------------------
# CoronaNet Database BETA Version 1.0 (core)
# ID:  datamart.url.de434a1d1d7342deb13439c02ac39926
# Score:  9.565694
# Augmentation: join
# Left Columns: [['publish_date']]
# Right Columns: [['date_start']]
# -------------------

# %%
result_related = [r for r in results_related if r['id'] == 'datamart.url.de434a1d1d7342deb13439c02ac39926']
result_related = dict(
    result_related[0],
    augmentation=dict(
        type='join',
        left_columns=[[2]],
        right_columns=[[3]],
        left_columns_names=[['publish_date']],
        right_columns_names=[['date_announced']],
    ),
)
print(json.dumps(result_related, indent=2))
# Out:
# {
#   "id": "datamart.url.de434a1d1d7342deb13439c02ac39926",
#   "score": 9.797967,
#   "metadata": {
#     "name": "CoronaNet Database BETA Version 1.0 (core)",
#     "source": "upload",
#     "description": "This file contains variables from the CoronaNet government response project, representing nationa...",
#     "date": "2020-04-28T19:57:57.521698Z",
#     "size": 8102913,
#     "nb_rows": 11916,
#     "nb_profiled_rows": 11916,
#     "columns": [
#       {
#         "name": "record_id",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [],
#         "num_distinct_values": 11916
#       },
#       {
#         "name": "policy_id",
#         "structural_type": "http://schema.org/Integer",
#         "semantic_types": [
#           "http://schema.org/identifier"
#         ],
#         "mean": 10508657659.991272,
#         "stddev": 810688245360.868,
#         "plot": {
#           "type": "histogram_numerical",
#           "data": [
#             {
#               "count": 11914,
#               "bin_start": 5036.0,
#               "bin_end": 6258072784442.5
#             },
#             {
#               "count": 0,
#               "bin_start": 6258072784442.5,
#               "bin_end": 12516145563849.0
#             },
#             {
#               "count": 0,
#               "bin_start": 12516145563849.0,
#               "bin_end": 18774218343255.5
#             },
#             {
#               "count": 0,
#               "bin_start": 18774218343255.5,
#               "bin_end": 25032291122662.0
#             },
#             {
#               "count": 0,
#               "bin_start": 25032291122662.0,
#               "bin_end": 31290363902068.5
#             },
#             {
#               "count": 0,
#               "bin_start": 31290363902068.5,
#               "bin_end": 37548436681475.0
#             },
#             {
#               "count": 0,
#               "bin_start": 37548436681475.0,
#               "bin_end": 43806509460881.5
#             },
#             {
#               "count": 0,
#               "bin_start": 43806509460881.5,
#               "bin_end": 50064582240288.0
#             },
#             {
#               "count": 0,
#               "bin_start": 50064582240288.0,
#               "bin_end": 56322655019694.5
#             },
#             {
#               "count": 2,
#               "bin_start": 56322655019694.5,
#               "bin_end": 62580727799101.0
#             }
#           ]
#         },
#         "coverage": [
#           {
#             "range": {
#               "gte": 247843.0,
#               "lte": 4804800.0
#             }
#           },
#           {
#             "range": {
#               "gte": 62580727799101.0,
#               "lte": 62580727799101.0
#             }
#           },
#           {
#             "range": {
#               "gte": 5278826.0,
#               "lte": 9716056.0
#             }
#           }
#         ]
#       },
#       {
#         "name": "recorded_date",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/DateTime"
#         ],
#         "num_distinct_values": 6578,
#         "mean": 1586075085.2984223,
#         "stddev": 377396.45497716946,
#         "coverage": [
#           {
#             "range": {
#               "gte": 1585506432.0,
#               "lte": 1585988736.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1586564992.0,
#               "lte": 1586948736.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1586063616.0,
#               "lte": 1586501248.0
#             }
#           }
#         ],
#         "temporal_resolution": "second",
#         "plot": {
#           "type": "histogram_temporal",
#           "data": [
#             {
#               "count": 388,
#               "date_start": "2020-03-28T04:33:04",
#               "date_end": "2020-03-30T01:40:16"
#             },
#             {
#               "count": 849,
#               "date_start": "2020-03-30T01:40:16",
#               "date_end": "2020-03-31T22:49:36"
#             },
#             {
#               "count": 2606,
#               "date_start": "2020-03-31T22:49:36",
#               "date_end": "2020-04-02T19:56:48"
#             },
#             {
#               "count": 3180,
#               "date_start": "2020-04-02T19:56:48",
#               "date_end": "2020-04-04T17:06:08"
#             },
#             {
#               "count": 1065,
#               "date_start": "2020-04-04T17:06:08",
#               "date_end": "2020-04-06T14:13:20"
#             },
#             {
#               "count": 964,
#               "date_start": "2020-04-06T14:13:20",
#               "date_end": "2020-04-08T11:20:32"
#             },
#             {
#               "count": 1023,
#               "date_start": "2020-04-08T11:20:32",
#               "date_end": "2020-04-10T08:29:52"
#             },
#             {
#               "count": 656,
#               "date_start": "2020-04-10T08:29:52",
#               "date_end": "2020-04-12T05:37:04"
#             },
#             {
#               "count": 354,
#               "date_start": "2020-04-12T05:37:04",
#               "date_end": "2020-04-14T02:46:24"
#             },
#             {
#               "count": 831,
#               "date_start": "2020-04-14T02:46:24",
#               "date_end": "2020-04-15T23:53:36"
#             }
#           ]
#         }
#       },
#       {
#         "name": "date_announced",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration",
#           "http://schema.org/DateTime"
#         ],
#         "num_distinct_values": 104,
#         "mean": 1584219688.9561272,
#         "stddev": 1552634.1200539086,
#         "coverage": [
#           {
#             "range": {
#               "gte": 1582675200.0,
#               "lte": 1584662400.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1579564800.0,
#               "lte": 1582156800.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1584835200.0,
#               "lte": 1586563200.0
#             }
#           }
#         ],
#         "temporal_resolution": "day",
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "2020-01-03",
#               "count": 2
#             },
#             {
#               "bin": "2020-01-05",
#               "count": 1
#             },
#             {
#               "bin": "2020-01-15",
#               "count": 1
#             },
#             {
#               "bin": "2020-01-17",
#               "count": 1
#             },
#             {
#               "bin": "2020-01-19",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "date_start",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration",
#           "http://schema.org/DateTime"
#         ],
#         "num_distinct_values": 124,
#         "mean": 1584331693.0513594,
#         "stddev": 1629345.504406999,
#         "coverage": [
#           {
#             "range": {
#               "gte": 1584921600.0,
#               "lte": 1586908800.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1579478400.0,
#               "lte": 1582156800.0
#             }
#           },
#           {
#             "range": {
#               "gte": 1582675200.0,
#               "lte": 1584748800.0
#             }
#           }
#         ],
#         "temporal_resolution": "day",
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "2020-01-05",
#               "count": 1
#             },
#             {
#               "bin": "2020-01-17",
#               "count": 1
#             },
#             {
#               "bin": "2020-01-18",
#               "count": 1
#             },
#             {
#               "bin": "2020-01-19",
#               "count": 1
#             },
#             {
#               "bin": "2020-06-03",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "date_end",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 135,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "2020-01-30",
#               "count": 1
#             },
#             {
#               "bin": "2020-02-18",
#               "count": 1
#             },
#             {
#               "bin": "2020-02-24",
#               "count": 1
#             },
#             {
#               "bin": "2020-10-24",
#               "count": 1
#             },
#             {
#               "bin": "2022-03-13",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "entry_type",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 4,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "NA",
#               "count": 25
#             },
#             {
#               "bin": "correction",
#               "count": 634
#             },
#             {
#               "bin": "new_entry",
#               "count": 9552
#             },
#             {
#               "bin": "update",
#               "count": 1705
#             }
#           ]
#         }
#       },
#       {
#         "name": "event_description",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Text"
#         ]
#       },
#       {
#         "name": "type",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 16,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Curfew",
#               "count": 165
#             },
#             {
#               "bin": "Health Testing",
#               "count": 162
#             },
#             {
#               "bin": "Internal Border Restrictions",
#               "count": 247
#             },
#             {
#               "bin": "New Task Force or Bureau",
#               "count": 220
#             },
#             {
#               "bin": "Restriction of Non-Essential Government Services",
#               "count": 212
#             }
#           ]
#         }
#       },
#       {
#         "name": "type_sub_cat",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 36,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Hand Sanitizer",
#               "count": 12
#             },
#             {
#               "bin": "Health Volunteers",
#               "count": 19
#             },
#             {
#               "bin": "Quarantine only applies to people of certain ages. Please note the age restrictions in the text box.",
#               "count": 24
#             },
#             {
#               "bin": "Test Kits",
#               "count": 21
#             },
#             {
#               "bin": "Ventilators",
#               "count": 20
#             }
#           ]
#         }
#       },
#       {
#         "name": "type_text",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 63,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "12 days (03.19 till 03.31)",
#               "count": 2
#             },
#             {
#               "bin": "19",
#               "count": 2
#             },
#             {
#               "bin": "43",
#               "count": 2
#             },
#             {
#               "bin": "74 days",
#               "count": 2
#             },
#             {
#               "bin": "The lockdown imposed has not been uplifted since its start on March 8th.",
#               "count": 2
#             }
#           ]
#         }
#       },
#       {
#         "name": "country",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 189,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Andorra",
#               "count": 4
#             },
#             {
#               "bin": "Armenia",
#               "count": 4
#             },
#             {
#               "bin": "Belgium",
#               "count": 1
#             },
#             {
#               "bin": "Nicaragua",
#               "count": 3
#             },
#             {
#               "bin": "Zimbabwe",
#               "count": 4
#             }
#           ]
#         }
#       },
#       {
#         "name": "init_country_level",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 4,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Municipal",
#               "count": 521
#             },
#             {
#               "bin": "National",
#               "count": 8220
#             },
#             {
#               "bin": "No, it is at the national level",
#               "count": 151
#             },
#             {
#               "bin": "Yes, it is at the province/state level",
#               "count": 3024
#             }
#           ]
#         }
#       },
#       {
#         "name": "province",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 351,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Jowzjan",
#               "count": 1
#             },
#             {
#               "bin": "Luanda",
#               "count": 1
#             },
#             {
#               "bin": "Malanje",
#               "count": 1
#             },
#             {
#               "bin": "Nangarhar",
#               "count": 1
#             },
#             {
#               "bin": "Sar-e Pol",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "city",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 193,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Muhu, Saaremaa",
#               "count": 1
#             },
#             {
#               "bin": "Regency of Magelang",
#               "count": 1
#             },
#             {
#               "bin": "Reykjavik",
#               "count": 1
#             },
#             {
#               "bin": "Suzak",
#               "count": 1
#             },
#             {
#               "bin": "Taxisco, San Jacinto, La Uni\u00f3n, San Francisco Zapotitl\u00e1n, Mazatenango",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "source_file_Type",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 4,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "application/octet-stream",
#               "count": 6
#             },
#             {
#               "bin": "application/pdf",
#               "count": 10597
#             },
#             {
#               "bin": "application/x-zip-compressed",
#               "count": 517
#             },
#             {
#               "bin": "application/zip",
#               "count": 796
#             }
#           ]
#         }
#       },
#       {
#         "name": "link_type",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 3,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "C",
#               "count": 15
#             },
#             {
#               "bin": "NA",
#               "count": 11894
#             },
#             {
#               "bin": "U",
#               "count": 7
#             }
#           ]
#         }
#       },
#       {
#         "name": "target_country",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 409,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Botswana",
#               "count": 1
#             },
#             {
#               "bin": "Dominican Republic",
#               "count": 1
#             },
#             {
#               "bin": "France,Germany,Iran,Spain,United Kingdom",
#               "count": 1
#             },
#             {
#               "bin": "Iraq,Kuwait",
#               "count": 1
#             },
#             {
#               "bin": "Macedonia",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "target_geog_level",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 6,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "A geographical or administrative unit within a country",
#               "count": 1390
#             },
#             {
#               "bin": "All countries",
#               "count": 1288
#             },
#             {
#               "bin": "One or more countries and one or more regional groupings",
#               "count": 155
#             },
#             {
#               "bin": "One or more countries, but not all countries",
#               "count": 2919
#             },
#             {
#               "bin": "One or more regional groupings",
#               "count": 90
#             }
#           ]
#         }
#       },
#       {
#         "name": "target_region",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 31,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Africa,Asia,ASEAN Countries,North America,Latin America,Central America,Oceania,Middle East",
#               "count": 2
#             },
#             {
#               "bin": "Africa,Asia,ASEAN Countries,North America,Latin America,Central America,Oceania,Middle East,Other Regions (please specify below)",
#               "count": 2
#             },
#             {
#               "bin": "Europe,Asia,ASEAN Countries,Middle East",
#               "count": 2
#             },
#             {
#               "bin": "European Union (with the UK),Asia,North America",
#               "count": 2
#             },
#             {
#               "bin": "Schengen Area (with the UK),Other Regions (please specify below)",
#               "count": 2
#             }
#           ]
#         }
#       },
#       {
#         "name": "target_province",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 224,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "All regions and cities in Guyana",
#               "count": 1
#             },
#             {
#               "bin": "Metro Manila (National Capital Region)",
#               "count": 1
#             },
#             {
#               "bin": "Nationwide, with particular regards for Tokyo Prefecture; Kanagawa Prefecture; Saitama Prefecture; Chiba Prefecture; Osaka Prefecture; Hyogo Prefecture; Fukuoka Prefecture",
#               "count": 1
#             },
#             {
#               "bin": "Policy is targeted to all district capitals in Bulgaria.",
#               "count": 1
#             },
#             {
#               "bin": "Western Cape; Eastern Cape; Northern Cape; North West; Free State; KwaZulu-Natal; Gauteng; Limpopo; Mpumalanga",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "target_city",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 145,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "All cities in Sudan that have inter-city bus services.",
#               "count": 1
#             },
#             {
#               "bin": "Puerto Cort\u00e9s; Santa Cruz de Yojoa; El Triunfo",
#               "count": 1
#             },
#             {
#               "bin": "Rome",
#               "count": 1
#             },
#             {
#               "bin": "Suzak",
#               "count": 1
#             },
#             {
#               "bin": "Taxisco, San Jacinto, La Uni\u00f3n, San Francisco Zapotitl\u00e1n, Mazatenango",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "target_other",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "missing_values_ratio": 0.0003356831151393085,
#         "num_distinct_values": 1,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "NA",
#               "count": 11912
#             }
#           ]
#         }
#       },
#       {
#         "name": "target_who_what",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 14,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "All Citizens (Citizen Residents + Citizen Travelers)",
#               "count": 107
#             },
#             {
#               "bin": "All Foreign Nationals (Foreign Residents + Foreign Travelers)",
#               "count": 96
#             },
#             {
#               "bin": "Citizen Residents",
#               "count": 54
#             },
#             {
#               "bin": "Foreign Residents (Foreign Nationals Residing in the Country)",
#               "count": 22
#             },
#             {
#               "bin": "Health-Infrastructure",
#               "count": 4
#             }
#           ]
#         }
#       },
#       {
#         "name": "target_direction",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 4,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Inbound",
#               "count": 2799
#             },
#             {
#               "bin": "Inbound/Outbound",
#               "count": 1298
#             },
#             {
#               "bin": "NA",
#               "count": 7394
#             },
#             {
#               "bin": "Outbound",
#               "count": 425
#             }
#           ]
#         }
#       },
#       {
#         "name": "travel_mechanism",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 88,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "All kinds of transport (all below except visa restrictions),Flights,Land Border,Seaports",
#               "count": 1
#             },
#             {
#               "bin": "All kinds of transport (all below except visa restrictions),Flights,Land Border,Trains,Buses",
#               "count": 1
#             },
#             {
#               "bin": "All kinds of transport (all below except visa restrictions),Flights,Trains,Buses,Other (please specify)",
#               "count": 1
#             },
#             {
#               "bin": "Flights,Land Border,Trains,Buses,Seaports",
#               "count": 1
#             },
#             {
#               "bin": "Flights,Trains,Ferries",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "compliance",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 20,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Mandatory with Exceptions (Please list exceptions in the text entry),Voluntary/Recommended but No Penalties",
#               "count": 6
#             },
#             {
#               "bin": "Mandatory with Fines,Mandatory (Unspecified/Implied),Mandatory with Exceptions (Please list exceptions in the text entry)",
#               "count": 2
#             },
#             {
#               "bin": "Mandatory with Fines,Voluntary/Recommended but No Penalties",
#               "count": 1
#             },
#             {
#               "bin": "Mandatory with Legal Penalties (Jail Time),Mandatory with Fines,Mandatory (Unspecified/Implied),Voluntary/Recommended but No Penalties",
#               "count": 3
#             },
#             {
#               "bin": "Mandatory with Legal Penalties (Jail Time),Voluntary/Recommended but No Penalties",
#               "count": 5
#             }
#           ]
#         }
#       },
#       {
#         "name": "enforcer",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 91,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "Military,Provincial/State Government,Police,Other (Please specify in the text box)",
#               "count": 1
#             },
#             {
#               "bin": "National Government,Military,Provincial/State Government,Municipal Government",
#               "count": 2
#             },
#             {
#               "bin": "National Government,Ministry/Department of Health,Military,Police,Other (Please specify in the text box)",
#               "count": 1
#             },
#             {
#               "bin": "National Government,Ministry/Department of Health,Provincial/State Government,Police,Other (Please specify in the text box)",
#               "count": 1
#             },
#             {
#               "bin": "National Government,Municipal Government,Other (Please specify in the text box)",
#               "count": 1
#             }
#           ]
#         }
#       },
#       {
#         "name": "link",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [],
#         "num_distinct_values": 4572
#       },
#       {
#         "name": "ISO_A3",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 188,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "AND",
#               "count": 4
#             },
#             {
#               "bin": "ARM",
#               "count": 4
#             },
#             {
#               "bin": "BEL",
#               "count": 1
#             },
#             {
#               "bin": "NIC",
#               "count": 3
#             },
#             {
#               "bin": "ZWE",
#               "count": 4
#             }
#           ]
#         }
#       },
#       {
#         "name": "ISO_A2",
#         "structural_type": "http://schema.org/Text",
#         "semantic_types": [
#           "http://schema.org/Enumeration"
#         ],
#         "num_distinct_values": 187,
#         "plot": {
#           "type": "histogram_categorical",
#           "data": [
#             {
#               "bin": "AD",
#               "count": 4
#             },
#             {
#               "bin": "AM",
#               "count": 4
#             },
#             {
#               "bin": "BE",
#               "count": 1
#             },
#             {
#               "bin": "NI",
#               "count": 3
#             },
#             {
#               "bin": "ZW",
#               "count": 4
#             }
#           ]
#         }
#       }
#     ],
#     "sample": "record_id,policy_id,recorded_date,date_announced,date_start,date_end,entry_type,event_description,type,type_sub_cat,type_text,country,init_country_level,province,city,source_file_Type,link_type,target_country,target_geog_level,target_region,target_province,target_city,target_other,target_who_what,target_direction,travel_mechanism,compliance,enforcer,link,ISO_A3,ISO_A2\n1698247,1698247,2020-03-30T03:43:45Z,2020-03-15,2020-03-17,NA,new_entry,\"The government of Saint Lucia will not allow any non-national with a travel history within the last 14 days from Spain, Mainland France,...\",External Border Restrictions,NA,NA,Saint Lucia,National,NA,NA,application/pdf,NA,\"France,Germany,Iran,Spain,United Kingdom\",\"One or more countries, but not all countries\",NA,NA,NA,NA,Foreign Residents (Foreign Nationals Residing in the Country),Inbound,All kinds of transport (all below except visa restrictions),Voluntary/Recommended but No Penalties,National Government,http://www.govt.lc/news/saint-lucia-travel-restrictions,LCA,LC\n2995606,2995606,2020-04-03T22:23:38Z,2020-03-12,2020-03-16,2020-04-06,new_entry,\"Kyrgyzstan \"\"decided to quarantine all schools and higher education institutions of the countries for three weeks\"\" with the exception of...\",Closure of Schools,NA,NA,Kyrgyzstan,National,NA,NA,application/zip,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,Mandatory (Unspecified/Implied),Other (Please specify in the text box),NA,KGZ,KG\n3071523,3071523,2020-03-30T07:46:43Z,2020-03-08,2020-03-09,NA,new_entry,Italy is enforcing External Border Restrictions on all travelers who want to enter or leave Italy for touristic reasons after march 9.,External Border Restrictions,NA,NA,Italy,National,NA,NA,application/pdf,NA,All countries,All countries,NA,NA,NA,NA,All Travelers (Citizen Travelers + Foreign Travelers ),Inbound/Outbound,All kinds of transport (all below except visa restrictions),Mandatory with Fines,National Government,http://web.archive.org/web/20200317080625/http://www.salute.gov.it/portale/nuovocoronavirus/dettaglioFaqNuovoCoronavirus.jsp?lingua=itali...,ITA,IT\n3519923,3519923,2020-04-03T22:13:49Z,2020-01-27,2020-01-27,NA,new_entry,\"On January 27, China urged migrant workers who returned from cities to wear masks, wash hands frequently, avoid gatherings and crowded...\",Public Awareness Campaigns,NA,NA,China,National,NA,NA,application/pdf,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,Voluntary/Recommended but No Penalties,\"National Government,Ministry/Department of Health,Other (Please specify in the text box)\",https://www.hubei.gov.cn/zhuanti/2020/gzxxgzbd/zxtb/202001/t20200128_2015736.shtml,CHN,CN\n3878286,4868526,2020-04-01T19:06:30Z,2020-03-16,2020-03-15,2020-04-03,update,\"From March 20, 2020, Austria extended an earlier policy to obligating persons who want to enter Austria from Italy, Switzerland, and...\",External Border Restrictions,NA,NA,Austria,National,NA,NA,application/pdf,NA,\"Germany,Hungary,Slovenia\",\"One or more countries, but not all countries\",NA,NA,NA,NA,All (Travelers + Residents),Inbound,All kinds of transport (all below except visa restrictions),Mandatory (Unspecified/Implied),\"National Government,Ministry/Department of Health,Provincial/State Government,Municipal Government,Police\",https://www.sozialministerium.at/dam/jcr:4af6af6a-0f78-4390-a579-1561c7ff45eb/BGBLA_2020_II_104.pdf,AUT,AT\n4608248Ab,4405714,2020-04-02T04:50:52Z,2020-02-28,2020-02-28,NA,update,El Salvador is enforcing a 30-day quarantine on national passengers and foreign diplomats arriving from Iran.,Quarantine/Lockdown,Government Quarantine (i.e. quarantine at a government hotel or facility),30,El Salvador,National,NA,NA,application/pdf,NA,Iran,\"One or more countries, but not all countries\",NA,NA,NA,NA,Other,Inbound,Flights,Mandatory (Unspecified/Implied),\"National Government,Ministry/Department of Health\",https://www.reuters.com/article/us-china-health-el-salvador/el-salvador-widens-entry-restrictions-over-coronavirus-fears-idUSKCN20M356,SLV,S ...
#     "materialize": {
#       "date": "2020-04-09T21:11:59.240611Z",
#       "direct_url": "https://coronanet-project.org/data/coronanet_release.csv",
#       "identifier": "datamart.url"
#     },
#     "version": "v0.5.7-179-ged84ca4",
#     "id": "datamart.url.de434a1d1d7342deb13439c02ac39926"
#   },
#   "augmentation": {
#     "type": "join",
#     "left_columns": [
#       [
#         2
#       ]
#     ],
#     "right_columns": [
#       [
#         3
#       ]
#     ],
#     "left_columns_names": [
#       [
#         "publish_date"
#       ]
#     ],
#     "right_columns_names": [
#       [
#         "date_announced"
#       ]
#     ]
#   },
#   "supplied_id": null,
#   "supplied_resource_id": null,
#   "d3m_dataset_description": {
#     "about": {
#       "datasetID": "datamart.url.de434a1d1d7342deb13439c02ac39926",
#       "datasetName": "CoronaNet Database BETA Version 1.0 (core)",
#       "license": "unknown",
#       "approximateSize": "8102913 B",
#       "datasetSchemaVersion": "4.0.0",
#       "redacted": false,
#       "datasetVersion": "1.0",
#       "description": "This file contains variables from the CoronaNet government response project, representing nationa..."
#     },
#     "dataResources": [
#       {
#         "resID": "learningData",
#         "resPath": "tables/learningData.csv",
#         "resType": "table",
#         "resFormat": {
#           "text/csv": [
#             "csv"
#           ]
#         },
#         "isCollection": false,
#         "columns": [
#           {
#             "colIndex": 0,
#             "colName": "record_id",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 1,
#             "colName": "policy_id",
#             "colType": "integer",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 2,
#             "colName": "recorded_date",
#             "colType": "dateTime",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 3,
#             "colName": "date_announced",
#             "colType": "dateTime",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 4,
#             "colName": "date_start",
#             "colType": "dateTime",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 5,
#             "colName": "date_end",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 6,
#             "colName": "entry_type",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 7,
#             "colName": "event_description",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 8,
#             "colName": "type",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 9,
#             "colName": "type_sub_cat",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 10,
#             "colName": "type_text",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 11,
#             "colName": "country",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 12,
#             "colName": "init_country_level",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 13,
#             "colName": "province",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 14,
#             "colName": "city",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 15,
#             "colName": "source_file_Type",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 16,
#             "colName": "link_type",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 17,
#             "colName": "target_country",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 18,
#             "colName": "target_geog_level",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 19,
#             "colName": "target_region",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 20,
#             "colName": "target_province",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 21,
#             "colName": "target_city",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 22,
#             "colName": "target_other",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 23,
#             "colName": "target_who_what",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 24,
#             "colName": "target_direction",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 25,
#             "colName": "travel_mechanism",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 26,
#             "colName": "compliance",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 27,
#             "colName": "enforcer",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 28,
#             "colName": "link",
#             "colType": "string",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 29,
#             "colName": "ISO_A3",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           },
#           {
#             "colIndex": 30,
#             "colName": "ISO_A2",
#             "colType": "categorical",
#             "role": [
#               "attribute"
#             ]
#           }
#         ]
#       }
#     ]
#   }
# }

# %%
# Perform the augmentation, by just sending the JSON result again as the 'task'
response = requests.post(
    URL + '/augment', 
    files={
        'data_id': io.BytesIO(result['id'].encode('ascii')),
        'task': ('task.json', json.dumps(result_related), 'application/json'),
    },
)
response.raise_for_status()

# %%
# In D3M format by default (ZIP)
zip_ = zipfile.ZipFile(io.BytesIO(response.content), 'r')
print(zip_.namelist())
# Open the CSV
pandas.read_csv(zip_.open('tables/learningData.csv')).head()
# Out:
# ['datasetDoc.json', 'tables/learningData.csv']
#           city state   publish_date  \
# 0  Albertville    AL   3/17/20 0:00
# 1   Birmingham    AL  3/24/20 18:08
# 2         Boaz    AL   3/24/20 0:00
# 3     Carolina    AL   3/27/20 0:00
# 4      Clanton    AL   3/17/20 0:00
#
#                                                  url  \
# 0  https://www.gadsdentimes.com/news/20200317/alb...
# 1  https://www.al.com/news/2020/03/woodfin-propos...
# 2  https://www.gadsdentimes.com/news/20200324/boa...
# 3  https://www.cnbc.com/2020/03/27/north-carolina...
# 4  https://www.clantonadvertiser.com/2020/03/17/j...
#
#                                                title  \
# 0         Albertville declares coronavirus emergency
# 1  Shelter-in-place order enacted in Birmingham t...
# 2        Boaz declares state of emergency over virus
# 3  North Carolina Gov. Roy Cooper orders resident...
# 4  Jemison Council approves COVID-19 response mea...
#
#                                                 text            category  \
# 0  The Albertville City Council on Monday declare...  state_of_emergency
# 1  The Birmingham City Council approved an ordina...    shelter_in_place
# 2  The Boaz City Council on Monday declared a sta...  state_of_emergency
# 3  Governor Roy Cooper, D-NC address the crowd du...    shelter_in_place
# 4  By JOYANNA LOVE/ Senior Staff Writer\n\nThe Ci...                None
#
#    population  latitude  longitude  ... max target_other  min target_other  \
# 0       37220   34.2634   -86.2107  ...              NaN               NaN
# 1      744189   33.5277   -86.7987  ...              NaN               NaN
# 2        9652   34.1985   -86.1529  ...              NaN               NaN
# 3         295   31.2337   -86.5227  ...              NaN               NaN
# 4        5876   32.8439   -86.6230  ...              NaN               NaN
#
#                target_who_what  target_direction  travel_mechanism  \
# 0  All (Travelers + Residents)  Inbound/Outbound       Land Border
# 1  All (Travelers + Residents)  Inbound/Outbound    Not Applicable
# 2  All (Travelers + Residents)  Inbound/Outbound    Not Applicable
# 3  All (Travelers + Residents)           Inbound    Not Applicable
# 4  All (Travelers + Residents)  Inbound/Outbound       Land Border
#
#                                           compliance  \
# 0  Mandatory with Exceptions (Please list excepti...
# 1                               Mandatory with Fines
# 2                               Mandatory with Fines
# 3                    Mandatory (Unspecified/Implied)
# 4  Mandatory with Exceptions (Please list excepti...
#
#                                             enforcer  \
# 0                                           Military
# 1  National Government,Ministry/Department of Hea...
# 2  National Government,Ministry/Department of Hea...
# 3                        Municipal Government,Police
# 4                                           Military
#
#                                                 link ISO_A3 ISO_A2
# 0  https://www.dailysabah.com/opinion/op-ed/pales...    PSE     PS
# 1  http://jamaica-gleaner.com/article/lead-storie...    JAM     JM
# 2  http://jamaica-gleaner.com/article/lead-storie...    JAM     JM
# 3  http://www.dnx.news/covid19/martial-law-by-nec...    PHL     PH
# 4  https://www.dailysabah.com/opinion/op-ed/pales...    PSE     PS
#
# [5 rows x 46 columns]

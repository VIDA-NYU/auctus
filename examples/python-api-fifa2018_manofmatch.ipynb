# %% [markdown]
# # Python API for NYU's DataMart

# %% [markdown]
# This notebook showcases how to use the Python API for the NYU's DataMart system, which implements the common DataMart interface (https://gitlab.com/datadrivendiscovery/datamart-api/blob/master/datamart.py). To install it: `pip install datamart_nyu`
#
# For the augmentation, we use the FIFA 2018 Man of Match data, available here: https://gitlab.datadrivendiscovery.org/d3m/datasets/tree/master/seed_datasets_data_augmentation/DA_fifa2018_manofmatch

# %%
from d3m import container
import datamart
import datamart_nyu
import datetime
from pathlib import Path

# %%
def print_results(results):
    if not results:
        return
    for result in results:
        print(result.score())
        print(result.get_json_metadata()['metadata']['name'])
        if (result.get_augment_hint()):
            left_columns = []
            for column_ in result.get_augment_hint().left_columns:
                left_columns.append([])
                for column in column_:
                    left_columns[-1].append((column.resource_id, column.column_index))
            print("Left Columns: %s" % str(left_columns))
            right_columns = []
            for column_ in result.get_augment_hint().right_columns:
                right_columns.append([])
                for column in column_:
                    right_columns[-1].append((column.resource_id, column.column_index))
            print("Right Columns: %s" % str(right_columns))
        else:
            print(result.id())
        print("-------------------")

# %% [markdown]
# Loading the FIFA 2018 man of match data, i.e., our supplied data.

# %%
# You can change this accordingly
fifa_manofmatch_file = str(Path.home()) + '/projects/d3m/datasets/seed_datasets_data_augmentation/' +\
                       'DA_fifa2018_manofmatch/DA_fifa2018_manofmatch_dataset/datasetDoc.json'
fifa_manofmatch = container.Dataset.load('file://' + fifa_manofmatch_file)

# %%
fifa_manofmatch['learningData'].head()
# Out:
#   d3mIndex GameID        Date     Team        Opponent Ball Possession %  \
# 0        0     55  23-06-2018   Mexico  Korea Republic                59
# 1        1     40  21-06-2018  Denmark       Australia                49
# 2        2     19  17-06-2018   Mexico         Germany                40
# 3        3     31  19-06-2018  Senegal          Poland                43
# 4        4     98  30-06-2018  Uruguay        Portugal                39
#
#   Off-Target Blocked Offsides Saves Pass Accuracy % Passes  \
# 0          6       2        0     5              89    485
# 1          5       0        1     4              88    458
# 2          6       2        2     9              82    281
# 3          4       2        3     3              81    328
# 4          2       1        0     4              69    269
#
#   Distance Covered (Kms) Yellow & Red Man of the Match 1st Goal        Round  \
# 0                     97            0                1     26.0  Group Stage
# 1                    112            0                1      7.0  Group Stage
# 2                    106            0                0     35.0  Group Stage
# 3                    107            0                1     60.0  Group Stage
# 4                    106            0                1      7.0  Round of 16
#
#   PSO Goals in PSO Own goals
# 0  No            0
# 1  No            0
# 2  No            0
# 3  No            0
# 4  No            0

# %% [markdown]
# ## Searching for Datasets

# %% [markdown]
# Let's first instantiate our client:

# %%
client = datamart_nyu.RESTDatamart('https://datamart.d3m.vida-nyu.org')

# %% [markdown]
# ### Search using keywords

# %%
query = datamart.DatamartQuery(
    keywords=['soccer', 'FIFA 2018', 'sports'],  # keywords from problem definition
    variables=[]
)
cursor = client.search(query=query)

# %%
results = cursor.get_next_page()

# %%
print_results(results)
# Out:
# 40.331184
# FIFA 2018 game statistics data
# datamart.upload.8733eed7d5844bc990d1153b6957cf90
# -------------------
# 25.035423
# Summer Sports Experience
# datamart.socrata.data-cityofnewyork-us.xeg4-ic28
# -------------------
# 9.738021
# 2018 - 2019 School Locations
# datamart.socrata.data-cityofnewyork-us.9ck8-hj3u
# -------------------
# 9.2692175
# Child Support Collections
# datamart.socrata.data-cityofnewyork-us.8fhd-nzw8
# -------------------
# 9.186156
# 2018 Open Data Plan: Future Releases
# datamart.socrata.data-cityofnewyork-us.dzrn-z4d7
# -------------------
# 8.834902
# 2017 - 2018 Avg Class Size Borough MSHS
# datamart.socrata.data-cityofnewyork-us.am74-3pnv
# -------------------
# 8.745911
# Child Support Caseload
# datamart.socrata.data-cityofnewyork-us.7rf2-3gxf
# -------------------
# 8.650852
# 2018-2019 3K For All Demographic Snapshot
# datamart.socrata.data-cityofnewyork-us.suzc-ps6g
# -------------------
# 8.306905
# Appeals Closed In 2018
# datamart.socrata.data-cityofnewyork-us.uetw-jfrg
# -------------------
# 7.9615107
# 2018 Open Data Plan: Removed Datasets
# datamart.socrata.data-cityofnewyork-us.8pnf-vysd
# -------------------
# 7.8472266
# NYC Weather Data 2010-2018
# datamart.upload.a031bc4968cb4838967e4709e63a0ddc
# -------------------
# 7.821455
# 2018-2019 Demographic Snapshot by Borough
# datamart.socrata.data-cityofnewyork-us.uh2w-zjsn
# -------------------
# 7.7545795
# 2018-2019 SHSAT Admissions Test Offers By Sending School
# datamart.socrata.data-cityofnewyork-us.uf53-ree9
# -------------------
# 7.7482076
# 2017 - 2018 Graduation Outcomes Citywide
# datamart.socrata.data-cityofnewyork-us.5psr-sp96
# -------------------
# 7.7122064
# 2018 DOE High School Directory
# datamart.socrata.data-cityofnewyork-us.vw9i-7mzq
# -------------------
# 7.620807
# 2017- 2018 Class Size Report District Middle And High School Class Size Distribution
# datamart.socrata.data-cityofnewyork-us.n2rw-tynt
# -------------------
# 7.532279
# 2018-2019 Quality Review School List
# datamart.socrata.data-cityofnewyork-us.2rr4-rfvc
# -------------------
# 7.4498863
# 2018-2019 School Demographic Snapshot
# datamart.socrata.data-cityofnewyork-us.45j8-f6um
# -------------------
# 7.427675
# 2017 - 2018 Guidance Counselor Report
# datamart.socrata.data-cityofnewyork-us.kiwq-bb5k
# -------------------
# 7.394483
# Parks Special Events
# datamart.socrata.data-cityofnewyork-us.6v4b-5gp4
# -------------------

# %% [markdown]
# ### Search using data

# %%
cursor = client.search_with_data(query=None, supplied_data=fifa_manofmatch)

# %%
results = cursor.get_next_page()

# %%
print_results(results)
# Out:
# 1.0
# FIFA 2018 game statistics data
# Left Columns: [[('learningData', 13)]]
# Right Columns: [[('0', 8)]]
# -------------------
# 1.0
# Housing New York Units by Building
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 19)]]
# -------------------
# 1.0
# Recognized Shop Healthy Stores
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 1)]]
# -------------------
# 1.0
# Contractor / Sub Contractor Change Order Report
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 10)]]
# -------------------
# 1.0
# Cash Assistance Youth Engagement
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 6)]]
# -------------------
# 1.0
# City Clerk eLobbyist Data
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 14)]]
# -------------------
# 1.0
# 2005 - 2011 Graduation Outcomes - Borough - ELL
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 21)]]
# -------------------
# 1.0
# Street Construction Permits - Stipulations (Historical)
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 3)]]
# -------------------
# 1.0
# Low Income Housing Tax Credits Awarded by HPD: Project-Level (9% Awards)
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 13)]]
# -------------------
# 1.0
# Corporate Procurement Contract Awards
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 0)]]
# -------------------
# 1.0
# Parking Violations Issued - Fiscal Year 2017
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 23)]]
# -------------------
# 1.0
# Parking Violations Issued - Fiscal Year 2015
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 17)]]
# -------------------
# 1.0
# 2014 NYC Open Data Plan
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 4)]]
# -------------------
# 1.0
# Charges
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 3)]]
# -------------------
# 1.0
# SCA Disqualified Firms
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 2)]]
# -------------------
# 1.0
# DEP - Cryptosporidium And Giardia Data Set
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 1)]]
# -------------------
# 1.0
# OATH Trials Division Case Status
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 6)]]
# -------------------
# 1.0
# NYC Parks Events Listing – Event Listing
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 2)]]
# -------------------
# 1.0
# Appeals Closed In 2016
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 8)]]
# -------------------
# 1.0
# FY17 BID Trends Report Data
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 46)]]
# -------------------

# %% [markdown]
# ### Search using data and keywords

# %%
query = datamart.DatamartQuery(
    keywords=['soccer', 'FIFA 2018', 'sports'],
    variables=[]
)
cursor = client.search_with_data(query=query, supplied_data=fifa_manofmatch)

# %%
results = cursor.get_next_page()

# %%
print_results(results)
# Out:
# 1.0
# FIFA 2018 game statistics data
# Left Columns: [[('learningData', 13)]]
# Right Columns: [[('0', 8)]]
# -------------------
# 1.0
# Parking Violations Issued - Fiscal Year 2017
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 23)]]
# -------------------
# 1.0
# Parking Violations Issued - Fiscal Year 2015
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 17)]]
# -------------------
# 1.0
# Parking Violations Issued - Fiscal Year 2019
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 17)]]
# -------------------
# 1.0
# Parking Violations Issued - Fiscal Year 2016
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 17)]]
# -------------------
# 1.0
# Parking Violations Issued - Fiscal Year 2018
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 17)]]
# -------------------
# 1.0
# Parking Violations Issued - Fiscal Year 2014 (August 2013 – June 2014)
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 17)]]
# -------------------
# 1.0
# Local Law 251 of 2017: NYC Open Data Plan Tracker
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 7)]]
# -------------------
# 0.9918879080973734
# 2018 Green Taxi Trip Data
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 2)]]
# -------------------
# 0.9911504451971346
# 2018 For Hire Vehicles Trip Data
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 1)]]
# -------------------
# 0.9827586206896551
# FIFA 2018 game statistics data
# Left Columns: [[('learningData', 1)]]
# Right Columns: [[('0', 0)]]
# -------------------
# 0.9823008903942692
# Appeals Filed In 2018
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 4)]]
# -------------------
# 0.9701327525403293
# 2018 Yellow Taxi Trip Data
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 1)]]
# -------------------
# 0.9646017807885383
# Appeals Closed In 2018
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 5)]]
# -------------------
# 0.8706896551724138
# Traffic Volume Counts (2014-2018)
# Left Columns: [[('learningData', 1)]]
# Right Columns: [[('0', 0)]]
# -------------------
# 0.853448275862069
# Vehicle Classification Counts (2014-2018)
# Left Columns: [[('learningData', 1)]]
# Right Columns: [[('0', 0)]]
# -------------------
# 0.7327586206896551
# 2017 - 2018 Schools NYPD Crime Data Report
# Left Columns: [[('learningData', 1)]]
# Right Columns: [[('0', 0)]]
# -------------------
# 0.7256636986857694
# Newyork Weather Data around Airport 2016-18
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 0)]]
# -------------------
# 0.7256636986857694
# Parks Special Events
# Left Columns: [[('learningData', 2)]]
# Right Columns: [[('0', 2)]]
# -------------------
# 0.5681818181818182
# FIFA 2018 game statistics data
# Left Columns: [[('learningData', 6)]]
# Right Columns: [[('0', 3)]]
# -------------------

# %% [markdown]
# ### Search using data, keywords, and data columns

# %%
query = datamart.DatamartQuery(
    keywords=['soccer', 'FIFA 2018', 'sports'],
    variables=[]
)
cursor = client.search_with_data_columns(
    query=query,
    supplied_data=fifa_manofmatch,
    data_constraints=[
        datamart.TabularVariable(
            [datamart.DatasetColumn('learningData', 1)],  # GameID
            datamart.ColumnRelationship.CONTAINS
        )
    ]
)

# %%
results = cursor.get_next_page()

# %%
print_results(results)
# Out:
# 0.9827586206896551
# FIFA 2018 game statistics data
# Left Columns: [[('learningData', 1)]]
# Right Columns: [[('0', 0)]]
# -------------------
# 0.8706896551724138
# Traffic Volume Counts (2014-2018)
# Left Columns: [[('learningData', 1)]]
# Right Columns: [[('0', 0)]]
# -------------------
# 0.853448275862069
# Vehicle Classification Counts (2014-2018)
# Left Columns: [[('learningData', 1)]]
# Right Columns: [[('0', 0)]]
# -------------------
# 0.7327586206896551
# 2017 - 2018 Schools NYPD Crime Data Report
# Left Columns: [[('learningData', 1)]]
# Right Columns: [[('0', 0)]]
# -------------------

# %% [markdown]
# ## Downloading a dataset

# %% [markdown]
# Now let's materialize the first dataset, in case the user wants to take a look at the data before augmenting it (or so that the user can augment the data him/herself).

# %%
datamart_data = results[0].download(supplied_data=None)

# %%
datamart_data['learningData'].head()
# Out:
#   GameID Goal Scored Attempts On-Target Corners Free Kicks Fouls Committed  \
# 0      0           5       13         7       6         11              22
# 1      1           0        6         0       2         25              10
# 2      2           0        8         3       0          7              12
# 3      3           1       14         4       5         13               6
# 4      4           0       13         3       5         14              22
#
#   Yellow Card Red Own goal Time
# 0           0   0
# 1           0   0
# 2           2   0
# 3           0   0
# 4           1   0            90

# %% [markdown]
# You can also give a dataset as input so that DataMart can try to return a dataset that joins well with it. Only portions of the DataMart dataset that join with the input data will be returned.

# %%
datamart_data = results[0].download(supplied_data=fifa_manofmatch)

# %%
datamart_data['learningData'].head()
# Out:
#   Red GameID Goal Scored Attempts On-Target Corners Free Kicks  \
# 0   0      0           5       13         7       6         11
# 1   0      1           0        6         0       2         25
# 2   0      2           0        8         3       0          7
# 3   0      3           1       14         4       5         13
# 4   0      4           0       13         3       5         14
#
#   Fouls Committed Yellow Card Own goal Time
# 0              22           0
# 1              10           0
# 2              12           2
# 3               6           0
# 4              22           1          90.0

# %% [markdown]
# ## Augmenting a dataset

# %% [markdown]
#  Let's try to do our augmentation for the first query result.

# %%
join_ = results[0].augment(supplied_data=fifa_manofmatch)

# %%
join_['learningData'].head()
# Out:
#   d3mIndex GameID        Date     Team        Opponent Ball Possession %  \
# 0        0     55  2018-06-23   Mexico  Korea Republic                59
# 1        1     40  2018-06-21  Denmark       Australia                49
# 2        2     19  2018-06-17   Mexico         Germany                40
# 3        3     31  2018-06-19  Senegal          Poland                43
# 4        4     98  2018-06-30  Uruguay        Portugal                39
#
#   Off-Target Blocked Offsides Saves      ...      Own goals Goal Scored  \
# 0          6       2        0     5      ...                          2
# 1          5       0        1     4      ...                          1
# 2          6       2        2     9      ...                          1
# 3          4       2        3     3      ...                          2
# 4          2       1        0     4      ...                          2
#
#   Attempts On-Target Corners Free Kicks Fouls Committed Yellow Card Red  \
# 0       13         5       5         24               7           0   0
# 1       10         5       3          5               7           2   0
# 2       12         4       1         11              15           2   0
# 3        8         2       3         11              15           2   0
# 4        6         3       2         14              13           0   0
#
#   Own goal Time
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 29 columns]

# %% [markdown]
# We can also choose which columns from the DataMart dataset that we want in the augmentation process.

# %%
join_ = results[0].augment(
    supplied_data=fifa_manofmatch,
    augment_columns=[datamart.DatasetColumn('0', 1), datamart.DatasetColumn('0', 2)]  # Goal Scored, Attempts
)

# %%
join_['learningData'].head()
# Out:
#   d3mIndex GameID        Date     Team        Opponent Ball Possession %  \
# 0        0     55  2018-06-23   Mexico  Korea Republic                59
# 1        1     40  2018-06-21  Denmark       Australia                49
# 2        2     19  2018-06-17   Mexico         Germany                40
# 3        3     31  2018-06-19  Senegal          Poland                43
# 4        4     98  2018-06-30  Uruguay        Portugal                39
#
#   Off-Target Blocked Offsides Saves   ...    Distance Covered (Kms)  \
# 0          6       2        0     5   ...                        97
# 1          5       0        1     4   ...                       112
# 2          6       2        2     9   ...                       106
# 3          4       2        3     3   ...                       107
# 4          2       1        0     4   ...                       106
#
#   Yellow & Red Man of the Match 1st Goal        Round PSO Goals in PSO  \
# 0            0                1     26.0  Group Stage  No            0
# 1            0                1      7.0  Group Stage  No            0
# 2            0                0     35.0  Group Stage  No            0
# 3            0                1     60.0  Group Stage  No            0
# 4            0                1      7.0  Round of 16  No            0
#
#   Own goals Goal Scored Attempts
# 0                     2       13
# 1                     1       10
# 2                     1       12
# 3                     2        8
# 4                     2        6
#
# [5 rows x 22 columns]

# %%
import logging
logging.root.handlers.clear()
logging.basicConfig(level=logging.INFO)

# %%
import d3m.index
import d3m.primitives

# %%
from frozendict import frozendict

def _conv(d):
    if isinstance(d, frozendict):
        return {k: _conv(v) for k, v in d.items()}
    elif isinstance(d, (list, tuple)):
        return [_conv(e) for e in d]
    else:
        return d

def print_dict(d):
    """Print function that hides 'FrozenDict' classes from the output.
    
    It just shows the FrozenDict like normal dicts.
    """
    print(_conv(d))

# %%
# List mounted D3M datasets
# !ls /d3m/data/seed_datasets_current
# Out:
# 1491_one_hundred_plants_margin
# 1491_one_hundred_plants_margin_clust
# 1567_poker_hand
# 185_baseball
# 196_autoMpg
# 22_handgeometry
# 26_radon_seed
# 27_wordLevels
# 299_libras_move
# 30_personae
# 313_spectrometer
# 31_urbansound
# 32_wikiqa
# 38_sick
# 4550_MiceProtein
# 49_facebook
# 534_cps_85_wages
# 56_sunspots
# 57_hypothyroid
# 59_umls
# 60_jester
# 66_chlorineConcentration
# 6_70_com_amazon
# 6_86_com_DBLP
# DS01876
# LL0_1100_popularkids
# LL0_186_braziltourism
# LL0_207_autoPrice
# LL0_acled
# LL0_acled_reduced
# LL1_336_MS_Geolife_transport_mode_prediction
# LL1_3476_HMDB_actio_recognition
# LL1_726_TIDY_GPS_carpool_bus_service_rating_prediction
# LL1_736_stock_market
# LL1_EDGELIST_net_nomination_seed
# LL1_net_nomination_seed
# LL1_penn_fudan_pedestrian
# uu1_datasmash
# uu2_gp_hyperparameter_estimation
# uu2_gp_hyperparameter_estimation_v2
# uu3_world_development_indicators
# uu4_SPECT

# %%
from d3m.container import Dataset
from d3m.metadata.base import ALL_ELEMENTS

# %%
# Load a dataset
dataset = Dataset.load('file:///d3m/data/seed_datasets_current/185_baseball/185_baseball_dataset/datasetDoc.json')

# %%
# Run DatasetToDataFrame primitive
from d3m.primitives.datasets import DatasetToDataFrame
hyperparams_class = DatasetToDataFrame.metadata.query()['primitive_code']['class_type_arguments']['Hyperparams']
hyperparams = hyperparams_class.defaults()
conv = DatasetToDataFrame(hyperparams=hyperparams)
res = conv.produce(inputs=dataset)
assert res.has_finished
dataframe = res.value
dataframe.head()
# Out:
#   d3mIndex        Player Number_seasons Games_played At_bats  Runs  Hits  \
# 0        0    HANK_AARON             23         3298   12364  2174  3771
# 1        1   JERRY_ADAIR             13         1165    4019   378  1022
# 2        2  SPARKY_ADAMS             13         1424    5557   844  1588
# 3        3   BOBBY_ADAMS             14         1281    4019   591  1082
# 4        4    JOE_ADCOCK             17         1959    6606   823  1832
#
#   Doubles Triples Home_runs  RBIs Walks Strikeouts Batting_average  \
# 0     624      98       755  2297  1402     1383.0           0.305
# 1     163      19        57   366   208      499.0           0.254
# 2     249      48         9   394   453      223.0           0.286
# 3     188      49        37   303   414      447.0           0.269
# 4     295      35       336  1122   594     1059.0           0.277
#
#   On_base_pct Slugging_pct Fielding_ave     Position Hall_of_Fame
# 0       0.377        0.555         0.98     Outfield            1
# 1       0.294        0.347        0.985  Second_base            0
# 2       0.343        0.353        0.974  Second_base            0
# 3        0.34        0.368        0.955   Third_base            0
# 4       0.339        0.485        0.994   First_base            0

# %%
# Show metadata for all the columns (before running Profiler)
features = dataframe.metadata.query([ALL_ELEMENTS])
num_columns = features['dimension']['length']
for i in range(num_columns):
    print_dict(dict(dataframe.metadata.query([ALL_ELEMENTS, i])))
    print()
# Out:
# {'name': 'd3mIndex', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/PrimaryKey')}
#
# {'name': 'Player', 'structural_type': <class 'str'>, 'semantic_types': ('https://metadata.datadrivendiscovery.org/types/CategoricalData', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Number_seasons', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Games_played', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'At_bats', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Runs', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Hits', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Doubles', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Triples', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Home_runs', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'RBIs', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Walks', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Strikeouts', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Batting_average', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Float', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'On_base_pct', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Float', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Slugging_pct', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Float', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Fielding_ave', 'structural_type': <class 'str'>, 'semantic_types': ('http://schema.org/Float', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Position', 'structural_type': <class 'str'>, 'semantic_types': ('https://metadata.datadrivendiscovery.org/types/CategoricalData', 'https://metadata.datadrivendiscovery.org/types/Attribute')}
#
# {'name': 'Hall_of_Fame', 'structural_type': <class 'str'>, 'semantic_types': ('https://metadata.datadrivendiscovery.org/types/CategoricalData', 'https://metadata.datadrivendiscovery.org/types/SuggestedTarget')}

# %%
# Run ISI's profiler
# Warning: it mutates the metadata in-place, don't run above cell out-of-order
from d3m.primitives.dsbox import Profiler
hyperparams_class = Profiler.metadata.query()['primitive_code']['class_type_arguments']['Hyperparams']
hyperparams = hyperparams_class.defaults()
profiler = Profiler(hyperparams=hyperparams)
res = profiler.produce(inputs=dataframe)
assert res.has_finished
profiled = res.value

# %%
# Print metadata from ISI's profiler
features = profiled.metadata.query([ALL_ELEMENTS])
num_columns = features['dimension']['length']
for i in range(num_columns):
    print_dict(profiled.metadata.query([ALL_ELEMENTS, i]))
    print()
# Out:
# {'name': 'd3mIndex', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/PrimaryKey'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 0, 'most_common_tokens': [{'name': '0', 'count': 1}, {'name': '1', 'count': 1}, {'name': '10', 'count': 1}, {'name': '100', 'count': 1}, {'name': '1000', 'count': 1}, {'name': '1001', 'count': 1}, {'name': '1002', 'count': 1}, {'name': '1003', 'count': 1}, {'name': '1004', 'count': 1}, {'name': '1005', 'count': 1}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Player', 'structural_type': <class 'str'>, 'semantic_types': ['https://metadata.datadrivendiscovery.org/types/Attribute', 'http://schema.org/Text'], 'most_common_tokens': [{'name': 'ELMER_SMITH', 'count': 2}, {'name': 'AARON_WARD', 'count': 1}, {'name': 'ABNER_DALRYMPLE', 'count': 1}, {'name': 'ADAM_COMOROSKY', 'count': 1}, {'name': 'ALAN_ASHBY', 'count': 1}, {'name': 'ALAN_BANNISTER', 'count': 1}, {'name': 'ALEX_GRAMMAS', 'count': 1}, {'name': 'ALEX_JOHNSON', 'count': 1}, {'name': 'ALEX_TREVINO', 'count': 1}, {'name': 'ALVIN_DARK', 'count': 1}]}
#
# {'name': 'Number_seasons', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 13, 'most_common_tokens': [{'name': '10', 'count': 243}, {'name': '11', 'count': 211}, {'name': '12', 'count': 183}, {'name': '13', 'count': 156}, {'name': '15', 'count': 111}, {'name': '14', 'count': 109}, {'name': '17', 'count': 84}, {'name': '16', 'count': 80}, {'name': '18', 'count': 59}, {'name': '19', 'count': 40}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Games_played', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 8, 'most_common_tokens': [{'name': '1010', 'count': 4}, {'name': '1035', 'count': 4}, {'name': '1288', 'count': 4}, {'name': '1392', 'count': 4}, {'name': '1421', 'count': 4}, {'name': '1435', 'count': 4}, {'name': '1806', 'count': 4}, {'name': '1853', 'count': 4}, {'name': '730', 'count': 4}, {'name': '813', 'count': 4}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'At_bats', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 6, 'most_common_tokens': [{'name': '1963', 'count': 3}, {'name': '2877', 'count': 3}, {'name': '4019', 'count': 3}, {'name': '4101', 'count': 3}, {'name': '4255', 'count': 3}, {'name': '4553', 'count': 3}, {'name': '4992', 'count': 3}, {'name': '1004', 'count': 2}, {'name': '1125', 'count': 2}, {'name': '1391', 'count': 2}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Runs', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 14, 'most_common_tokens': [{'name': '331', 'count': 6}, {'name': '357', 'count': 6}, {'name': '146', 'count': 5}, {'name': '163', 'count': 5}, {'name': '237', 'count': 5}, {'name': '245', 'count': 5}, {'name': '552', 'count': 5}, {'name': '562', 'count': 5}, {'name': '598', 'count': 5}, {'name': '643', 'count': 5}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Hits', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 10, 'most_common_tokens': [{'name': '972', 'count': 5}, {'name': '1064', 'count': 4}, {'name': '1103', 'count': 4}, {'name': '1122', 'count': 4}, {'name': '1252', 'count': 4}, {'name': '1415', 'count': 4}, {'name': '682', 'count': 4}, {'name': '699', 'count': 4}, {'name': '786', 'count': 4}, {'name': '813', 'count': 4}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Doubles', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 10, 'most_common_tokens': [{'name': '162', 'count': 11}, {'name': '128', 'count': 10}, {'name': '216', 'count': 10}, {'name': '91', 'count': 10}, {'name': '172', 'count': 9}, {'name': '190', 'count': 9}, {'name': '196', 'count': 9}, {'name': '71', 'count': 9}, {'name': '112', 'count': 8}, {'name': '147', 'count': 8}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Triples', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 21, 'most_common_tokens': [{'name': '12', 'count': 28}, {'name': '28', 'count': 25}, {'name': '33', 'count': 25}, {'name': '10', 'count': 24}, {'name': '11', 'count': 24}, {'name': '26', 'count': 24}, {'name': '35', 'count': 22}, {'name': '17', 'count': 21}, {'name': '23', 'count': 21}, {'name': '31', 'count': 21}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Home_runs', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 31, 'most_common_tokens': [{'name': '9', 'count': 21}, {'name': '18', 'count': 20}, {'name': '21', 'count': 20}, {'name': '22', 'count': 20}, {'name': '7', 'count': 20}, {'name': '13', 'count': 19}, {'name': '20', 'count': 19}, {'name': '27', 'count': 19}, {'name': '6', 'count': 19}, {'name': '14', 'count': 17}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'RBIs', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 16, 'most_common_tokens': [{'name': '391', 'count': 7}, {'name': '501', 'count': 7}, {'name': '591', 'count': 7}, {'name': '272', 'count': 6}, {'name': '525', 'count': 6}, {'name': '229', 'count': 5}, {'name': '230', 'count': 5}, {'name': '303', 'count': 5}, {'name': '323', 'count': 5}, {'name': '329', 'count': 5}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Walks', 'structural_type': <class 'int'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 23, 'most_common_tokens': [{'name': '190', 'count': 6}, {'name': '299', 'count': 6}, {'name': '309', 'count': 6}, {'name': '351', 'count': 6}, {'name': '369', 'count': 6}, {'name': '383', 'count': 6}, {'name': '142', 'count': 5}, {'name': '143', 'count': 5}, {'name': '164', 'count': 5}, {'name': '188', 'count': 5}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Strikeouts', 'structural_type': <class 'str'>, 'semantic_types': ['http://schema.org/Integer', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 0.9850746268656716, 'number_of_outlier_numeric_values': 23, 'most_common_tokens': [{'name': '218.0', 'count': 8}, {'name': '243.0', 'count': 7}, {'name': '453.0', 'count': 7}, {'name': '251.0', 'count': 6}, {'name': '312.0', 'count': 6}, {'name': '329.0', 'count': 6}, {'name': '345.0', 'count': 6}, {'name': '357.0', 'count': 6}, {'name': '361.0', 'count': 6}, {'name': '382.0', 'count': 6}], 'number_of_tokens_containing_numeric_char': 1320, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1320, 'ratio_of_values_containing_numeric_char': 0.9850746268656716}
#
# {'name': 'Batting_average', 'structural_type': <class 'float'>, 'semantic_types': ['http://schema.org/Float', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 8, 'most_common_tokens': [{'name': '0.271', 'count': 31}, {'name': '0.267', 'count': 30}, {'name': '0.261', 'count': 28}, {'name': '0.262', 'count': 27}, {'name': '0.254', 'count': 26}, {'name': '0.265', 'count': 25}, {'name': '0.268', 'count': 24}, {'name': '0.273', 'count': 24}, {'name': '0.257', 'count': 23}, {'name': '0.26', 'count': 23}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'On_base_pct', 'structural_type': <class 'float'>, 'semantic_types': ['http://schema.org/Float', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 8, 'most_common_tokens': [{'name': '0.323', 'count': 24}, {'name': '0.34', 'count': 24}, {'name': '0.329', 'count': 23}, {'name': '0.333', 'count': 23}, {'name': '0.316', 'count': 21}, {'name': '0.318', 'count': 21}, {'name': '0.346', 'count': 21}, {'name': '0.351', 'count': 21}, {'name': '0.319', 'count': 20}, {'name': '0.331', 'count': 20}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Slugging_pct', 'structural_type': <class 'float'>, 'semantic_types': ['http://schema.org/Float', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 8, 'most_common_tokens': [{'name': '0.351', 'count': 17}, {'name': '0.355', 'count': 15}, {'name': '0.367', 'count': 14}, {'name': '0.327', 'count': 13}, {'name': '0.343', 'count': 13}, {'name': '0.377', 'count': 13}, {'name': '0.379', 'count': 13}, {'name': '0.333', 'count': 12}, {'name': '0.358', 'count': 12}, {'name': '0.361', 'count': 12}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Fielding_ave', 'structural_type': <class 'float'>, 'semantic_types': ['http://schema.org/Float', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 33, 'most_common_tokens': [{'name': '0.984', 'count': 46}, {'name': '0.982', 'count': 41}, {'name': '0.983', 'count': 40}, {'name': '0.98', 'count': 38}, {'name': '0.981', 'count': 35}, {'name': '0.99', 'count': 35}, {'name': '0.973', 'count': 34}, {'name': '0.974', 'count': 33}, {'name': '0.985', 'count': 33}, {'name': '0.978', 'count': 32}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}
#
# {'name': 'Position', 'structural_type': <class 'str'>, 'semantic_types': ['https://metadata.datadrivendiscovery.org/types/CategoricalData', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'most_common_tokens': [{'name': 'Outfield', 'count': 492}, {'name': 'Catcher', 'count': 254}, {'name': 'Shortstop', 'count': 154}, {'name': 'Second_base', 'count': 148}, {'name': 'Third_base', 'count': 145}, {'name': 'First_base', 'count': 139}, {'name': 'Designated_hitter', 'count': 8}]}
#
# {'name': 'Hall_of_Fame', 'structural_type': <class 'int'>, 'semantic_types': ['https://metadata.datadrivendiscovery.org/types/CategoricalData', 'https://metadata.datadrivendiscovery.org/types/Attribute'], 'ratio_of_numeric_values': 1.0, 'number_of_outlier_numeric_values': 68, 'most_common_tokens': [{'name': '0', 'count': 1215}, {'name': '2', 'count': 68}, {'name': '1', 'count': 57}], 'number_of_tokens_containing_numeric_char': 1340, 'ratio_of_tokens_containing_numeric_char': 1.0, 'number_of_values_containing_numeric_char': 1340, 'ratio_of_values_containing_numeric_char': 1.0}

# %%
keys = set()
for i in range(num_columns):
    for k in profiled.metadata.query([ALL_ELEMENTS, i]):
        keys.add(k)
keys
# Out:
# {'most_common_tokens',
#  'name',
#  'number_of_outlier_numeric_values',
#  'number_of_tokens_containing_numeric_char',
#  'number_of_values_containing_numeric_char',
#  'ratio_of_numeric_values',
#  'ratio_of_tokens_containing_numeric_char',
#  'ratio_of_values_containing_numeric_char',
#  'semantic_types',
#  'structural_type'}

# %%
import sys
sys.path.insert(0, './datamart_client')

# %%
import datamart_client

# %%
datasets = datamart_client.search(keywords=['thyroid'], url='http://localhost:8002')
datasets
# Out:
# [<Dataset 'b8b6538dbb16412b8ad5b1479dfca535' score=1.0 discoverer='datamart.example.d3m'>,
#  <Dataset '47dd2bed65704757aceccdd64af76157' score=1.0 discoverer='datamart.example.d3m'>]

# %%
df = datasets[0].to_dataframe()
df.head()
# Out:
#    d3mIndex   age sex on_thyroxine query_on_thyroxine  \
# 0         0  41.0   F            f                  f
# 1         1  23.0   F            f                  f
# 2         2  46.0   M            f                  f
# 3         3  70.0   F            t                  f
# 4         4  70.0   F            f                  f
#
#   on_antithyroid_medication sick pregnant thyroid_surgery I131_treatment  \
# 0                         f    f        f               f              f
# 1                         f    f        f               f              f
# 2                         f    f        f               f              f
# 3                         f    f        f               f              f
# 4                         f    f        f               f              f
#
#      ...    TT4_measured    TT4 T4U_measured   T4U FTI_measured    FTI  \
# 0    ...               t  125.0            t  1.14            t  109.0
# ...
